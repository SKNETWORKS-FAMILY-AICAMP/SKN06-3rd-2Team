# %%
from langchain_openai import ChatOpenAI, OpenAIEmbeddings
from dotenv import load_dotenv
import config

load_dotenv()

model = ChatOpenAI(model=config.model_name)     # 평가시 사용할 llm 모델은 성능 좋은 것을 써야 좀 더 정확한 평가가 가능
embedding_model = OpenAIEmbeddings(
    model=config.embedding_name
)

# %%
from langchain_community.document_loaders import CSVLoader
from langchain_text_splitters import RecursiveCharacterTextSplitter
from langchain_chroma import Chroma

DOC_PATH = 'data/cleaned_all_restaurants.csv'

loader = CSVLoader(DOC_PATH)
splitter = RecursiveCharacterTextSplitter.from_tiktoken_encoder(
    model_name=config.model_name, chunk_size=config.chunk_size, chunk_overlap=config.chunk_overlap
)
docs = loader.load_and_split(splitter)

vector_store=Chroma(
    embedding_function=embedding_model,
    collection_name=config.collection_name,
    persist_directory=config.persist_directory
)

# %%
vector_store._collection.count()
# Out:
# 39104

# %%
docs
# Out:
# [Document(metadata={'source': 'data/cleaned_all_restaurants.csv', 'row': 0}, page_content='foodDetailTypes: 일반중식\nheaderInfo_nameKR: 홍보각\nheaderInfo_nameEN: \nheaderInfo_nameCN: 紅寶閣\nheaderInfo_bookYear: 2025\nheaderInfo_ribbonType: 3.0\ndefaultInfo_chefName: 여경래\ndefaultInfo_phone: 02-531-6479\ndefaultInfo_openHours: \ndefaultInfo_closeHours: \ndefaultInfo_openHoursWeekend: \ndefaultInfo_closeHoursWeekend: \ndefaultInfo_dayOff: 연중무휴\ndefaultInfo_app2Yn: True\nstatusInfo_parking: 가능\nstatusInfo_creditCard: y\nstatusInfo_visit: \nstatusInfo_menu: 스페셜코스(1인 15만원), 디너코스(A 12만원, B 16만원), 고법불도장(13만원), 모자새우(소 6만원, 대 10만원), 한알탕수육(소 4만8천원, 대 7만원), 특선냉채(2만8천원), 셰프특선수프(3만8천원), 셰프스페셜송이특찜(15만원)\nstatusInfo_priceRange: 10~15만원대\nstatusInfo_openDate: 2007년\nstatusInfo_businessHours: 12:00~15:00/18:00~21:30(마지막 주문 20:00)\njuso_detailAddress: 노보텔앰배서더강남서울 LL층\njuso_roadAddrPart1: 서울특별시 강남구 봉은사로 130\njuso_engAddr: 130 Bongeunsa-ro, Gangnam-gu, Seoul\njuso_bdNm: 노보텔 앰배서더 강남 서울\njuso_siNm: 서울특별시\njuso_sggNm: 강남구\njuso_emdNm: 역삼동\njuso_liNm: \njuso_rn: 동호로\njuso_buldMnnm: 130\njuso_buldSlno: 0\nreview_review: 국내 중식의 대가인 여경래 셰프가 2023년 이전하여 오픈한 중식 파인 다이닝 레스토랑. 고급스러운 분위기의 인테리어에서 정통 중식을 맛볼 수 있다. 여경래 셰프의 시그니처 메뉴인 불도장, 모자새우 등을 선보인다.\nreview_reviewSimple: 국내 중식의 대가인 여경래 셰프가 2023년 이전하여 오픈한 중식 파인 다이닝 레스토랑. 고급스러운 분위기의 인테리어에서 정통 중식을 맛볼 수 있다. 여경래 셰프의 시그니처 메뉴인 불도장, 모자새우 등을 선보인다.\nreview_readerAppraisal: \netcInfo_interior: \netcInfo_seat: 64\netcInfo_room: 6개(2, 3, 4, 6, 8, 12석)\netcInfo_head: \netcInfo_branch: \ndefaultInfo_website: https://www.instagram.com/hongbogak_official/'),
#  Document(metadata={'source': 'data/cleaned_all_restaurants.csv', 'row': 1}, page_content='foodDetailTypes: 이노베이티브퀴진, 분자요리, 이탈리아식\nheaderInfo_nameKR: 쵸이닷\nheaderInfo_nameEN: CHOI.\nheaderInfo_nameCN: \nheaderInfo_bookYear: 2025\nheaderInfo_ribbonType: 3.0\ndefaultInfo_chefName: 최현석\ndefaultInfo_phone: 02-518-0318\ndefaultInfo_openHours: 12:00\ndefaultInfo_closeHours: 22:30\ndefaultInfo_openHoursWeekend: \ndefaultInfo_closeHoursWeekend: \ndefaultInfo_dayOff: 연중무휴\ndefaultInfo_app2Yn: False\nstatusInfo_parking: 가능\nstatusInfo_creditCard: y\nstatusInfo_visit: 청담사거리 앞. 버버리코리아 옆 건물\nstatusInfo_menu: 런치코스(3코스 7만8천원, 4코스 9만8천원), 디너코스(19만8천원), 와인리스트(변동)\nstatusInfo_priceRange: 15~25만원대\nstatusInfo_openDate: 2017년\nstatusInfo_businessHours: 12:00~15:00/18:30~22:00\njuso_detailAddress: 앙스돔빌딩 3층\njuso_roadAddrPart1: 서울특별시 강남구 도산대로 457\njuso_engAddr: 457, Dosan-daero, Gangnam-gu, Seoul\njuso_bdNm: 앙스돔빌딩\njuso_siNm: 서울특별시\njuso_sggNm: 강남구\njuso_emdNm: 청담동\njuso_liNm: \njuso_rn: \njuso_buldMnnm: 457\njuso_buldSlno: 0\nreview_review: 최현석 셰프의 크리에이티브한 요리를 즐길 수 있는 레스토랑. 분자요리와 이탈리아 요리를 기반으로 한 창의적인 요리가 코스로 나온다. 생각지 못한 재기발랄한 플레이팅은 자칫 엄숙하게 느껴질 수 있는 파인다이닝에 위트로 작용한다. 메뉴는 계절이나 재료에 맞춰 주기적으로 바뀌며 요리에 걸맞은 와인을 곁들이는 와인페어링도 추천한다.\nreview_reviewSimple: 최현석 셰프의 크리에이티브한 요리를 즐길 수 있는 레스토랑. 분자요리와 이탈리아 요리를 기반으로 한 창의적인 요리가 코스로 나온다. 생각지 못한 재기발랄한 플레이팅은 자칫 엄숙하게 느껴질 수 있는 파인다이닝에 위트로 작용한다. 메뉴는 계절이나 재료에 맞춰 주기적으로 바뀌며 요리에 걸맞은 와인을 곁들이는 와인페어링도 추천한다.\nreview_readerAppraisal: “어디까지 발전할 수 있을지 진심으로 기대되는 곳.” “음식 너무나 재밌었어요.”\netcInfo_interior: \netcInfo_seat: \netcInfo_room: \netcInfo_head: \netcInfo_branch: \ndefaultInfo_website: https://www.instagram.com/choidot_official/'),
#  Document(metadata={'source': 'data/cleaned_all_restaurants.csv', 'row': 2}, page_content='foodDetailTypes: 프랑스식\nheaderInfo_nameKR: 더그린테이블\nheaderInfo_nameEN: The Green Table\nheaderInfo_nameCN: \nheaderInfo_bookYear: 2025\nheaderInfo_ribbonType: 3.0\ndefaultInfo_chefName: 김은희\ndefaultInfo_phone: 02-591-2672\ndefaultInfo_openHours: \ndefaultInfo_closeHours: \ndefaultInfo_openHoursWeekend: \ndefaultInfo_closeHoursWeekend: \ndefaultInfo_dayOff: 월, 화요일, 명절 휴무\ndefaultInfo_app2Yn: False\nstatusInfo_parking: 가능\nstatusInfo_creditCard: y\nstatusInfo_visit: 안국역 3번 출구에서 직진 후 아라리오 뮤지엄 5층에 위치\nstatusInfo_menu: 런치코스(17만원), 디너코스(27만원), 와인페어링(변동)\nstatusInfo_priceRange: 15~25만원대\nstatusInfo_openDate: 2009년\nstatusInfo_businessHours: 12:00~15:00/18:00~22:00 | 일요일 12:00~15:00/18:00~21:30\njuso_detailAddress: 아라리오 뮤지엄 5층\njuso_roadAddrPart1: 서울특별시 종로구 율곡로 83\njuso_engAddr: 83 Yulgok-ro, Jongno-gu, Seoul\njuso_bdNm: \njuso_siNm: 서울특별시\njuso_sggNm: 종로구\njuso_emdNm: 원서동\njuso_liNm: \njuso_rn: \njuso_buldMnnm: 83\njuso_buldSlno: 0\nreview_review: 김은희 셰프가 운영하는 프렌치 레스토랑. 사계절에 따라 변화하는 우리나라 식재료로 만든 프렌치 요리를 선보인다. 제철 나물, 곡물, 생선, 해산물 등을 활용한 요리에서 변화하는 식재료의 다채로움을 즐길 수 있다. 2023년 10월 원서동 아라리오 뮤지엄 인 스페이스 건물로 이전하여 새로운 모습을 보여줄 예정이다.\nreview_reviewSimple: 김은희 셰프가 운영하는 프렌치 레스토랑. 사계절에 따라 변화하는 우리나라 식재료로 만든 프렌치 요리를 선보인다. 제철 나물, 곡물, 생선, 해산물 등을 활용한 요리에서 변화하는 식재료의 다채로움을 즐길 수 있다. 2023년 10월 원서동 아라리오 뮤지엄 인 스페이스 건물로 이전하여 새로운 모습을 보여줄 예정이다.\nreview_readerAppraisal: “음식의 결 하나하나에서 섬세한 정성이 듬뿍 느껴진다. 신선한 재료들이 훌륭하게 조화를 이룬다.” “가격 대비 양과 질이 훌륭합니다. 2인 예약을 하면 별실도 가능한데, 프라이빗하고 편안한 분위기입니다.” “분위기도 너무 좋았고 맛도 클래식한 게 맘에 들었습니다.”\netcInfo_interior: \netcInfo_seat: \netcInfo_room: \netcInfo_head: \netcInfo_branch: \ndefaultInfo_website: http://thegreentable.co.kr/, https://www.instagram.com/restaurant_thegreentable/'),
#  Document(metadata={'source': 'data/cleaned_all_restaurants.csv', 'row': 3}, page_content='foodDetailTypes: 소갈비, 소고기구이, 한우오마카세\nheaderInfo_nameKR: 명월관\nheaderInfo_nameEN: \nheaderInfo_nameCN: \nheaderInfo_bookYear: 2025\nheaderInfo_ribbonType: 3.0\ndefaultInfo_chefName: \ndefaultInfo_phone: 02-6330-9050\ndefaultInfo_openHours: \ndefaultInfo_closeHours: \ndefaultInfo_openHoursWeekend: \ndefaultInfo_closeHoursWeekend: \ndefaultInfo_dayOff: 연중무휴\ndefaultInfo_app2Yn: True\nstatusInfo_parking: 가능\nstatusInfo_creditCard: y\nstatusInfo_visit: 광장동 쉐라톤그랜드워커힐 내\nstatusInfo_menu: 생등심(180g 9만8천원), 생갈비(160g 11만3천원), 한우육회(150g 6만원), 한우모둠주물럭생갈비(160g 8만5천원), 숯불불고기(200g 5만1천원), 점심특선(12만원), 한우등심정식(17만9천원), 양념갈비정식(15만5천원), 갈비탕(3만7천원), 한우갈비탕(4만2천원), 맡김차림(35만원, 50만원, 70만원)\nstatusInfo_priceRange: 15~25만원대\nstatusInfo_openDate: 1982년\nstatusInfo_businessHours: 12:00~15:00/17:30~21:00\njuso_detailAddress: 쉐라톤그랜드워커힐호텔\njuso_roadAddrPart1: 서울특별시 광진구 워커힐로 177\njuso_engAddr: 177, Walkerhill-ro, Gwangjin-gu, Seoul\njuso_bdNm: 워커힐호텔\njuso_siNm: 서울특별시\njuso_sggNm: 광진구\njuso_emdNm: 광장동\njuso_liNm: \njuso_rn: 워커힐로\njuso_buldMnnm: 177\njuso_buldSlno: 0\nreview_review: 워커힐호텔 내 한옥 분위기의 별채로 있는, 주변 경치가 아름다운 숯불구이 전문점. 좋은 참숯에 구워 먹는 고기의 질도 훌륭하다. 된장 양념으로 맛을 낸 장향갈비가 인기. 식사 메뉴인 한우갈비탕 맛이 좋기로 유명하다. 별채에서는 한우 맡김차림으로 진행된다.\nreview_reviewSimple: 워커힐호텔 내 한옥 분위기의 별채로 있는, 주변 경치가 아름다운 숯불구이 전문점. 좋은 참숯에 구워 먹는 고기의 질도 훌륭하다. 식사 메뉴인 한우갈비탕 맛이 좋기로 유명하다. 별채의 대령숙수와 진귀15품 메뉴는 한우 오마카세로 진행된다.\nreview_readerAppraisal: \netcInfo_interior: \netcInfo_seat: 300\netcInfo_room: 4개\netcInfo_head: \netcInfo_branch: \ndefaultInfo_website: https://www.walkerhill.com/grandwalkerhillseoul/dining/Myongwolgwan'),
#  Document(metadata={'source': 'data/cleaned_all_restaurants.csv', 'row': 4}, page_content='foodDetailTypes: 프랑스식\nheaderInfo_nameKR: 콘티넨탈\nheaderInfo_nameEN: Continental\nheaderInfo_nameCN: \nheaderInfo_bookYear: 2025\nheaderInfo_ribbonType: 3.0\ndefaultInfo_chefName: \ndefaultInfo_phone: 02-2230-3369\ndefaultInfo_openHours: \ndefaultInfo_closeHours: \ndefaultInfo_openHoursWeekend: \ndefaultInfo_closeHoursWeekend: \ndefaultInfo_dayOff: 연중무휴\ndefaultInfo_app2Yn: False\nstatusInfo_parking: 가능\nstatusInfo_creditCard: y\nstatusInfo_visit: 동대입구역 5번출구로 나오면 장충동 신라호텔 23층\nstatusInfo_menu: 런치코스(3코스 12만원, 4코스 14만원, 5코스 15만5천원), 디너코스(30만원)\nstatusInfo_priceRange: 25만원 이상\nstatusInfo_openDate: 1985년\nstatusInfo_businessHours: 12:00~14:30/17:30~21:30\njuso_detailAddress: 서울신라호텔 23층\njuso_roadAddrPart1: 서울특별시 중구 동호로 249\njuso_engAddr: 249, Dongho-ro, Jung-gu, Seoul\njuso_bdNm: \njuso_siNm: 서울특별시\njuso_sggNm: 중구\njuso_emdNm: 장충동2가\njuso_liNm: \njuso_rn: 동호로\njuso_buldMnnm: 249\njuso_buldSlno: 0\nreview_review: 정통 유럽 스타일의 프렌치 레스토랑으로, 40여 년의 역사를 자랑하는, 서울에서 오래된 프렌치 레스토랑으로 손꼽힌다. 국내와 전 세계 각국에서 구한 신선한 제철 식재료로 최상의 요리를 선보인다. 남산의 전경이 한눈에 보이는 전망이 훌륭하다.\nreview_reviewSimple: 정통 유럽 스타일의 프렌치 레스토랑으로, 40여 년의 역사를 자랑하는, 서울에서 오래된 프렌치 레스토랑으로 손꼽힌다. 국내와 전 세계 각국에서 구한 신선한 제철 식재료로 최상의 요리를 선보인다. 남산의 전경이 한눈에 보이는 전망이 훌륭하다.\nreview_readerAppraisal: “최고의 레스토랑이다.” “분위기가 상당히 모던하고 세련된 느낌. 재료의 질이 최상급이었고 서비스도 좋았다. 특히 소고기와 캐비아는 최고!!” “my finest restaurant. 특별한 날 함께 하고 싶은 사람과 이곳에서 함께 한다면 화룡점정. 가격이 매우 비싸나, 그 값은 한다. 전망도 매우 좋고, 물론 신라호텔 특유의 친절함이 있다.” “들어가면서 넓은 분위기에 압도당하고, 좋은 경치에 감탄하고, 섬세한 조리솜씨와 맛에 ‘아’ 소리가 나온 후, 계산서를 받아들면 ‘기절’하는 레스토랑.” “와인 메뉴에 좀 더 글라스 와인을 추가했으면 하는 바람이었다.”\netcInfo_interior: 클래식한 유럽풍\netcInfo_seat: 70석\netcInfo_room: 1개\netcInfo_head: \netcInfo_branch: \ndefaultInfo_website: https://www.shilla.net/seoul/dining/viewDining.do?contId=FRC#ad-image-0'),
#  Document(metadata={'source': 'data/cleaned_all_restaurants.csv', 'row': 5}, page_content='foodDetailTypes: 모던한식, 뉴코리안\nheaderInfo_nameKR: 밍글스\nheaderInfo_nameEN: Mingles\nheaderInfo_nameCN: \nheaderInfo_bookYear: 2025\nheaderInfo_ribbonType: 3.0\ndefaultInfo_chefName: 강민구\ndefaultInfo_phone: 02-515-7306\ndefaultInfo_openHours: \ndefaultInfo_closeHours: \ndefaultInfo_openHoursWeekend: \ndefaultInfo_closeHoursWeekend: \ndefaultInfo_dayOff: 일, 월요일 정기 휴무\ndefaultInfo_app2Yn: False\nstatusInfo_parking: 발레 파킹\nstatusInfo_creditCard: y\nstatusInfo_visit: 학동사거리에서 압구정로데오역 방향으로 직진. 버거킹에서 우회전 후 커피빈에서 좌회전\nstatusInfo_menu: 런치코스(28만원), 디너코스(34만원), 전통주페어링(17만원), 시그니처페어링(28만원)\nstatusInfo_priceRange: 25만원 이상\nstatusInfo_openDate: 2014년\nstatusInfo_businessHours: 12:00~15:00/18:00~22:00\njuso_detailAddress: 힐탑빌딩 2층\njuso_roadAddrPart1: 서울특별시 강남구 도산대로67길 19\njuso_engAddr: 19, Dosan-daero 67-gil, Gangnam-gu, Seoul\njuso_bdNm: \njuso_siNm: 서울특별시\njuso_sggNm: 강남구\njuso_emdNm: 청담동\njuso_liNm: \njuso_rn: 선릉로\njuso_buldMnnm: 19\njuso_buldSlno: 0\nreview_review: 국내외에서 이름을 드높이고 있는 강민구 셰프의 뉴코리안 레스토랑. 사찰음식과 한식 장인에게 전수받은 전통 한식 기법을 현대적으로 재해석한 한식을 맛볼 수 있다. 완벽을 지향하는 육수 내기 등 기본기를 중요시하고 있다. 실내 분위기도 모던하고 쾌적하며 서비스도 나무랄 데 없다. 2020년에 홍콩에 오픈한 한식당 한식구가 큰 인기를 끄는 등 글로벌 셰프로서의 위엄을 보여준다.\nreview_reviewSimple: 국내외에서 이름을 드높이고 있는 강민구 셰프의 뉴코리안 레스토랑. 사찰음식과 한식 장인에게 전수받은 전통 한식 기법을 현대적으로 재해석한 한식을 맛볼 수 있다. 완벽을 지향하는 육수 내기 등 기본기를 중요시하고 있다. 실내 분위기도 모던하고 쾌적하며 서비스도 나무랄 데 없다. 2020년에 홍콩에 오픈한 한식당 한식구가 큰 인기를 끄는 등 글로벌 셰프로서의 위엄을 보여준다.\nreview_readerAppraisal: “창의적인 한식에 심혈을 기울인 느낌.” “제대로 된 뉴코리안을 느낄 수 있는 곳.” “가격 대비 만족도가 높았습니다. 음식마다 고민한 흔적도 보였고요.” “가장 만족할 만한 곳. 가성비 뛰어난 런치는 예약 없이 절대 못 가는 곳이다. 한식 퓨전 요리의 맛 하나하나가 정말 최고다. 엄지 척.” “강민구 셰프님의 음식도 훌륭하지만 밍글스의 서비스 또한 일품이다.” “노부 출신 강민구 셰프의 레스토랑. 한식을 베이스로 하여 그 위에 본인만의 창의적인 스타일을 얹었다.”\netcInfo_interior: \netcInfo_seat: \netcInfo_room: \netcInfo_head: \netcInfo_branch: \ndefaultInfo_website: http://www.restaurant-mingles.com, https://www.instagram.com/mingles_restaurant/'),
#  Document(metadata={'source': 'data/cleaned_all_restaurants.csv', 'row': 6}, page_content='foodDetailTypes: 컨템포러리\nheaderInfo_nameKR: 스와니예\nheaderInfo_nameEN: SOIGNÉ\nheaderInfo_nameCN: \nheaderInfo_bookYear: 2025\nheaderInfo_ribbonType: 3.0\ndefaultInfo_chefName: 이준\ndefaultInfo_phone: 02-3477-9386\ndefaultInfo_openHours: \ndefaultInfo_closeHours: \ndefaultInfo_openHoursWeekend: \ndefaultInfo_closeHoursWeekend: \ndefaultInfo_dayOff: 월요일 휴무. 명절 휴무\ndefaultInfo_app2Yn: False\nstatusInfo_parking: 가능(신사스퀘어 주차장 이용)\nstatusInfo_creditCard: y\nstatusInfo_visit: \nstatusInfo_menu: 런치코스(21만원), 디너코스(32만원)\nstatusInfo_priceRange: 25만원 이상\nstatusInfo_openDate: 2013년\nstatusInfo_businessHours: 12:00~15:00/18:00~22:00 (마지막 주문 19:30)\njuso_detailAddress: 신사스퀘어 2층\njuso_roadAddrPart1: 서울특별시 강남구 강남대로 652\njuso_engAddr: 652 Gangnam-daero, Gangnam-gu, Seoul\njuso_bdNm: SINSA SQUARE\njuso_siNm: 서울특별시\njuso_sggNm: 강남구\njuso_emdNm: 신사동\njuso_liNm: \njuso_rn: 반포대로39길\njuso_buldMnnm: 652\njuso_buldSlno: 0\nreview_review: 프렌치에 한국적인 요소를 가미한 컨템포러리 레스토랑. 에피소드라는 이름으로 시즌별로 바뀌는 코스는 각각 특별한 주제를 가지고 있어 이준 셰프의 상상력과 표현력을 엿볼 수 있다.\nreview_reviewSimple: 프렌치에 한국적인 요소를 가미한 컨템포러리 레스토랑. 에피소드라는 이름으로 시즌별로 바뀌는 코스는 각각 특별한 주제를 가지고 있어 이준 셰프의 상상력과 표현력을 엿볼 수 있다. 2023년 2월, 서래마을을 떠나 신사동으로 이전하였다.\nreview_readerAppraisal: “와인페어링과 함께하는 만찬은 한편의 뮤지컬같다.” “창의적이고 예술가적 기질이 뛰어난 셰프가 이끄는 레스토랑.” “특히 서비스가 너무나 좋았다.” “한식을 재미있게 스토리를 담아 잘 풀어냈다.” “창의적인 접시라면 바로 스와니예의 접시. 식재료를 재해석하는 것, 담아내는 솜씨 모두 감동적이다.”\netcInfo_interior: 모던/스타일리시\netcInfo_seat: \netcInfo_room: \netcInfo_head: \netcInfo_branch: \ndefaultInfo_website: http://soignerestaurantgroup.com, https://www.instagram.com/soigneseoul/'),
#  Document(metadata={'source': 'data/cleaned_all_restaurants.csv', 'row': 7}, page_content='foodDetailTypes: 일반중식\nheaderInfo_nameKR: 다이닝마\nheaderInfo_nameEN: DINING MA\nheaderInfo_nameCN: \nheaderInfo_bookYear: 2025\nheaderInfo_ribbonType: 3.0\ndefaultInfo_chefName: \ndefaultInfo_phone: 02-518-7400\ndefaultInfo_openHours: \ndefaultInfo_closeHours: \ndefaultInfo_openHoursWeekend: \ndefaultInfo_closeHoursWeekend: \ndefaultInfo_dayOff: 일요일, 명절 당일 휴무\ndefaultInfo_app2Yn: False\nstatusInfo_parking: 발레 파킹\nstatusInfo_creditCard: y\nstatusInfo_visit: 도산공원 사거리에서 BMW 강남전시장 골목으로 진입하면 우측\nstatusInfo_menu: 옌바오츠코스(99만원), 만한전석코스(75만원), 다이닝마코스(A 29만원, B 39만원, C 55만원), 이달의코스(25만원), 샥스핀탕(M 18만원, L 24만원)\nstatusInfo_priceRange: 25만원 이상\nstatusInfo_openDate: 2019년\nstatusInfo_businessHours: 11:30~14:30(마지막 주문 14:00)/17:30~21:30(마지막 주문 21:00)\njuso_detailAddress: 유일빌딩 2층\njuso_roadAddrPart1: 서울특별시 강남구 언주로152길 8\njuso_engAddr: 8, Eonju-ro 152-gil, Gangnam-gu, Seoul\njuso_bdNm: 유일빌딩\njuso_siNm: 서울특별시\njuso_sggNm: 강남구\njuso_emdNm: 신사동\njuso_liNm: \njuso_rn: \njuso_buldMnnm: 8\njuso_buldSlno: 0\nreview_review: 중국 3대 진미로 뽑히는 샥스핀을 전문으로 하는 고급 중식당으로, 룸으로만 구성되어 있어 프라이빗하게 식사를 즐길 수 있다. 동충하초, 산삼, 자라, 제비집 등 고급 식자재를 활용하여 맛뿐만 아니라 건강까지 고려한 수준급 중식 요리를 선보인다.\nreview_reviewSimple: 중국 3대 진미로 뽑히는 샥스핀을 전문으로 하는 고급 중식당으로, 룸으로만 구성되어 있어 프라이빗하게 식사를 즐길 수 있다. 동충하초, 산삼, 자라, 제비집 등 고급 식자재를 활용하여 맛뿐만 아니라 건강까지 고려한 수준급 중식 요리를 선보인다.\nreview_readerAppraisal: \netcInfo_interior: \netcInfo_seat: \netcInfo_room: \netcInfo_head: \netcInfo_branch: \ndefaultInfo_website:'),
#  Document(metadata={'source': 'data/cleaned_all_restaurants.csv', 'row': 8}, page_content='foodDetailTypes: 모던한식\nheaderInfo_nameKR: 한국의집\nheaderInfo_nameEN: KOREA HOUSE\nheaderInfo_nameCN: \nheaderInfo_bookYear: 2025\nheaderInfo_ribbonType: 3.0\ndefaultInfo_chefName: \ndefaultInfo_phone: 02-2266-9101\ndefaultInfo_openHours: \ndefaultInfo_closeHours: \ndefaultInfo_openHoursWeekend: \ndefaultInfo_closeHoursWeekend: \ndefaultInfo_dayOff: 월요일, 명절 연휴 휴무\ndefaultInfo_app2Yn: False\nstatusInfo_parking: 가능\nstatusInfo_creditCard: y\nstatusInfo_visit: 충무로역 3번 출구에서 GS칼텍스 끼고 우회전\nstatusInfo_menu: 1957반상(8만8천원), 신선로정식(A 만찬 20만원, B 오찬 10만원), 한국의집정식(오찬 15만원, 만찬 25만원)\nstatusInfo_priceRange: 5~10만원대\nstatusInfo_openDate: 1957년\nstatusInfo_businessHours: 12:00~15:00(마지막 주문 13:00)/18:00~22:00(마지막 주문 19:30)\njuso_detailAddress: \njuso_roadAddrPart1: 서울특별시 중구 퇴계로36길 10\njuso_engAddr: 10, Toegye-ro 36-gil, Jung-gu, Seoul\njuso_bdNm: 한국의집\njuso_siNm: 서울특별시\njuso_sggNm: 중구\njuso_emdNm: 필동2가\njuso_liNm: \njuso_rn: 퇴계로\njuso_buldMnnm: 10\njuso_buldSlno: 0\nreview_review: 조선왕조 궁궁음식 기반의 전통 한식을 품격 있게 담아낸 궁중음식 파인 다이닝을 선보인다. 고즈넉하고 아름다운 한옥의 정취와 함께 제철 식재료, 궁중 진상품 등 우리 땅에서 나는 귀한 식재료들를 활용하여 계절별로 색다른 전통 한식을 만나볼 수 있다. 1957년 한국을 방문하는 외빈을 위한 영빈관의 목적으로 지어졌으며, 현재는 복합문화공간으로서 한국의 아름다운 전통문화를 보존 및 보급하고 있다. 특히 궁중 음식, 고조리서 조리법 등을 연구 및 활용하여 전통 한식을 선도 및 전파하는 데 힘쓰고 있다.\nreview_reviewSimple: 고풍스러운 한옥에서 국악과 함께 다양한 궁중요리 코스를 즐길 수 있는 곳이다. 궁중음식을 기본으로 한 전통음식을 선보이며, 김치와 장 등을 직접 담그고 김치 광과 장독대가 따로 있을 정도다. 자연송이구이, 전복구이, 대하찜, 갈비찜, 너비아니, 구절판 같은 일품 요리와 한정식과 한식 뷔페도 마련되어 있다. 원래는 박팽년의 사저가 있었던 곳으로, 일제 강점기 때는 총독부 정무총감의 관저로, 대한민국 정부 수립 후에는 귀빈관으로 사용되었다.\nreview_readerAppraisal: \netcInfo_interior: 전통 한옥을 개조\netcInfo_seat: \netcInfo_room: \netcInfo_head: \netcInfo_branch: \ndefaultInfo_website: http://www.koreahouse.or.kr/, https://www.instagram.com/koreahouse_official/'),
#  Document(metadata={'source': 'data/cleaned_all_restaurants.csv', 'row': 9}, page_content='foodDetailTypes: 가이세키\nheaderInfo_nameKR: 미토우\nheaderInfo_nameEN: \nheaderInfo_nameCN: 未到\nheaderInfo_bookYear: 2025\nheaderInfo_ribbonType: 3.0\ndefaultInfo_chefName: 김보미, 권영운\ndefaultInfo_phone: 0507-1306-9914\ndefaultInfo_openHours: \ndefaultInfo_closeHours: \ndefaultInfo_openHoursWeekend: \ndefaultInfo_closeHoursWeekend: \ndefaultInfo_dayOff: 일, 월요일 휴무\ndefaultInfo_app2Yn: False\nstatusInfo_parking: 발레 파킹\nstatusInfo_creditCard: y\nstatusInfo_visit: \nstatusInfo_menu: 미토우코스(28만원~30만원)\nstatusInfo_priceRange: 25만원 이상\nstatusInfo_openDate: 2018년\nstatusInfo_businessHours: 18:00~22:00\njuso_detailAddress: \njuso_roadAddrPart1: 서울특별시 강남구 도산대로70길 24\njuso_engAddr: 24 Dosan-daero 70-gil, Gangnam-gu, Seoul\njuso_bdNm: \njuso_siNm: 서울특별시\njuso_sggNm: 강남구\njuso_emdNm: 청담동\njuso_liNm: \njuso_rn: 논현로151길\njuso_buldMnnm: 24\njuso_buldSlno: 0\nreview_review: 일본에서 수련 후 귀국한 권영운, 김보미 오너셰프의 일본요리 전문점. 담담하면서도 화사한 일본요리의 특징을 잘 살리면서도 조금씩 한국적인 느낌을 가미한 완성도 높은 요리를 선보인다. 일본과는 다른 국내 식재료 상황을 극복하기 위해 직접 채소나 쌀을 재배하거나 토종닭을 기르고 미소를 담그는 등 갖은 노력을 아끼지 않으며 많은 미식가들과 매체로부터 높은 평가를 받고 있다.\nreview_reviewSimple: \nreview_readerAppraisal: \netcInfo_interior: \netcInfo_seat: \netcInfo_room: \netcInfo_head: \netcInfo_branch: \ndefaultInfo_website: https://www.instagram.com/mitouseoul'),
#  Document(metadata={'source': 'data/cleaned_all_restaurants.csv', 'row': 10}, page_content='foodDetailTypes: 프랑스식\nheaderInfo_nameKR: 강민철레스토랑\nheaderInfo_nameEN: KANG MINCHUL Restaurant\nheaderInfo_nameCN: \nheaderInfo_bookYear: 2025\nheaderInfo_ribbonType: 3.0\ndefaultInfo_chefName: \ndefaultInfo_phone: 02-545-2511\ndefaultInfo_openHours: \ndefaultInfo_closeHours: \ndefaultInfo_openHoursWeekend: \ndefaultInfo_closeHoursWeekend: \ndefaultInfo_dayOff: 일, 월요일 휴무\ndefaultInfo_app2Yn: False\nstatusInfo_parking: 발레 파킹\nstatusInfo_creditCard: y\nstatusInfo_visit: \nstatusInfo_menu: 런치(18만원), 디너(34만원), 와인페어링(5잔 25만원, 7잔 29만원)\nstatusInfo_priceRange: 25만원 이상\nstatusInfo_openDate: 2021년\nstatusInfo_businessHours: 12:00~14:30/18:00~22:00\njuso_detailAddress: 지하 1층\njuso_roadAddrPart1: 서울특별시 강남구 도산대로68길 18\njuso_engAddr: 18, Dosan-daero 68-gil, Gangnam-gu, Seoul\njuso_bdNm: \njuso_siNm: 서울특별시\njuso_sggNm: 강남구\njuso_emdNm: 청담동\njuso_liNm: \njuso_rn: \njuso_buldMnnm: 18\njuso_buldSlno: 0\nreview_review: 파리의 조엘 로부숑, 알랭 뒤카스, 피에르 가니에르 등 거장들의 레스토랑에서 경력을 쌓은 강민철 셰프의 파인 다이닝 레스토랑. 클래식 프렌치를 재현한 코스 요리가 펼쳐지며, 메인 디시를 중심으로 서브 디시가 함께 등장한다. 화려한 플레이팅과 퍼포먼스로 인기가 높다.\nreview_reviewSimple: 오픈하자마자 화제가 되었던 강민철 셰프의 파인 다이닝 레스토랑. 클래식 프렌치를 재현한 코스 요리가 펼쳐지며, 메인 디시를 중심으로 서브 디시가 함께 등장한다. 화려한 플레이팅과 퍼포먼스로 인기가 높다.\nreview_readerAppraisal: \netcInfo_interior: \netcInfo_seat: \netcInfo_room: \netcInfo_head: \netcInfo_branch: \ndefaultInfo_website: https://www.instagram.com/kangminchul_restaurant/'),
#  Document(metadata={'source': 'data/cleaned_all_restaurants.csv', 'row': 11}, page_content='foodDetailTypes: 소고기구이, 한우오마카세\nheaderInfo_nameKR: 벽제갈비더청담\nheaderInfo_nameEN: HANSIK BYEOK JE\nheaderInfo_nameCN: \nheaderInfo_bookYear: 2025\nheaderInfo_ribbonType: 3.0\ndefaultInfo_chefName: \ndefaultInfo_phone: 02-512-9593\ndefaultInfo_openHours: \ndefaultInfo_closeHours: \ndefaultInfo_openHoursWeekend: \ndefaultInfo_closeHoursWeekend: \ndefaultInfo_dayOff: 연중무휴\ndefaultInfo_app2Yn: False\nstatusInfo_parking: 발레 파킹\nstatusInfo_creditCard: \nstatusInfo_visit: 압구정로데오역 2번 출구에서 600미터\nstatusInfo_menu: 꽃뼈생갈비(1kg 62만원), 꽃뼈등심(1kg 42만원), 설화한우생갈비(200g 16만원), 설화한우양념갈비(200g 8만5천원), 설화한우꽃등심, 설화한우안심, 설화한우안창(각 100g 9만원), 설화한우생등심(100g 7만원), 평양냉면한우반상(3만5천원). 설화한우갈비탕반상(5만8천원)\nstatusInfo_priceRange: 25만원 이상\nstatusInfo_openDate: 2022년\nstatusInfo_businessHours: 11:30~15:00/17:30~22:00(마지막 주문 21:15)\njuso_detailAddress: 조은빌딩 1층\njuso_roadAddrPart1: 서울특별시 강남구 도산대로81길 25\njuso_engAddr: 25, Dosan-daero 81-gil, Gangnam-gu, Seoul\njuso_bdNm: \njuso_siNm: 서울특별시\njuso_sggNm: 강남구\njuso_emdNm: 청담동\njuso_liNm: \njuso_rn: \njuso_buldMnnm: 25\njuso_buldSlno: 0\nreview_review: 벽제갈비에서 운영하는 한우 다이닝 레스토랑. 인테리어뿐 아니라 기물도 고급스럽게 준비하였다. 개별룸에서 셰프가 직접 손질해서 구워주는 한우 코스를 맛볼 수 있다.\nreview_reviewSimple: 벽제갈비에서 야심차게 오픈한 한우 다이닝 레스토랑. 인테리어뿐 아니라 기물도 고급스럽게 준비하였다. 개별룸에서 셰프가 직접 손질해서 구워주는 한우 코스를 맛볼 수 있다.\nreview_readerAppraisal: \netcInfo_interior: \netcInfo_seat: \netcInfo_room: \netcInfo_head: \netcInfo_branch: \ndefaultInfo_website: https://www.instagram.com/the_bjgalbi/'),
#  Document(metadata={'source': 'data/cleaned_all_restaurants.csv', 'row': 12}, page_content='foodDetailTypes: 뉴코리안\nheaderInfo_nameKR: 솔밤\nheaderInfo_nameEN: SOLBAM\nheaderInfo_nameCN: \nheaderInfo_bookYear: 2025\nheaderInfo_ribbonType: 3.0\ndefaultInfo_chefName: 엄태준 셰프\ndefaultInfo_phone: 070-4405-7788\ndefaultInfo_openHours: \ndefaultInfo_closeHours: \ndefaultInfo_openHoursWeekend: \ndefaultInfo_closeHoursWeekend: \ndefaultInfo_dayOff: 일요일 휴무\ndefaultInfo_app2Yn: False\nstatusInfo_parking: 발레 파킹\nstatusInfo_creditCard: y\nstatusInfo_visit: \nstatusInfo_menu: 솔밤코스(35만원), 베버리지페어링(25만원)\nstatusInfo_priceRange: 25만원 이상\nstatusInfo_openDate: 2021년\nstatusInfo_businessHours: 17:30~22:30\njuso_detailAddress: 논현백영센터 2층\njuso_roadAddrPart1: 서울특별시 강남구 학동로 231\njuso_engAddr: 231 Hakdong-ro, Gangnam-gu, Seoul\njuso_bdNm: \njuso_siNm: 서울특별시\njuso_sggNm: 강남구\njuso_emdNm: 논현동\njuso_liNm: \njuso_rn: \njuso_buldMnnm: 231\njuso_buldSlno: 0\nreview_review: 한식을 기반으로한 컨템포러리 파인 다이닝. 뉴욕 일레븐매디슨파크, 서울 임프레션 등을 거친 엄태준 셰프가 독창적이고 섬세한 코스로 풀어낸다. 고동연 소믈리에의 독창적인 와인 페어링, 황세희 파티시에의 디저트까지 12코스가 조화롭게 진행된다. 솔밤은 엄셰프가 유년을 보낸 안동의 지명이다.\nreview_reviewSimple: 한식을 기반으로한 컨템포러리 파인 다이닝. 뉴욕 일레븐매디슨파크, 서울 임프레션 등을 거친 엄태준 셰프가 독창적이고 섬세한 코스로 풀어낸다. 고동연 소믈리에의 독창적인 와인 페어링, 황세희 파티시에의 디저트까지 12코스가 조화롭게 진행된다. 솔밤은 엄셰프가 유년을 보낸 안동의 지명이다.\nreview_readerAppraisal: \netcInfo_interior: \netcInfo_seat: \netcInfo_room: \netcInfo_head: \netcInfo_branch: \ndefaultInfo_website: https://www.instagram.com/solbam_restaurant/'),
#  Document(metadata={'source': 'data/cleaned_all_restaurants.csv', 'row': 13}, page_content='foodDetailTypes: 뉴코리안\nheaderInfo_nameKR: 이타닉가든\nheaderInfo_nameEN: EATANIC GARDEN\nheaderInfo_nameCN: \nheaderInfo_bookYear: 2025\nheaderInfo_ribbonType: 3.0\ndefaultInfo_chefName: 손종원\ndefaultInfo_phone: 02-727-7610\ndefaultInfo_openHours: \ndefaultInfo_closeHours: \ndefaultInfo_openHoursWeekend: \ndefaultInfo_closeHoursWeekend: \ndefaultInfo_dayOff: 월, 화요일 휴무\ndefaultInfo_app2Yn: False\nstatusInfo_parking: 발레 파킹\nstatusInfo_creditCard: y\nstatusInfo_visit: \nstatusInfo_menu: 런치코스(19만원), 디너코스(32만원)\nstatusInfo_priceRange: 25만원 이상\nstatusInfo_openDate: 2021년\nstatusInfo_businessHours: 12:00~15:00/18:00~22:00\njuso_detailAddress: 조선팰리스강남 36층\njuso_roadAddrPart1: 서울특별시 강남구 테헤란로 231\njuso_engAddr: 231, Teheran-ro, Gangnam-gu, Seoul\njuso_bdNm: 센터필드\njuso_siNm: 서울특별시\njuso_sggNm: 강남구\njuso_emdNm: 역삼동\njuso_liNm: \njuso_rn: \njuso_buldMnnm: 231\njuso_buldSlno: 0\nreview_review: 프렌치 조리법에 컨템포러리 한식을 접목한 파인 다이닝 레스토랑. 손종원 셰프의 섬세하면서도 화려한 플레이팅을 바탕으로 코스 요리를 선보인다. 와인과 전통주 페어링이 가능하며 창가 자리의 시티뷰가 좋으니 예약 시 참고할 것.\nreview_reviewSimple: \nreview_readerAppraisal: \netcInfo_interior: \netcInfo_seat: \netcInfo_room: \netcInfo_head: \netcInfo_branch: \ndefaultInfo_website: https://jpg.josunhotel.com/dining/EatanicGarden.do, https://www.instagram.com/eatanicgarden/'),
#  Document(metadata={'source': 'data/cleaned_all_restaurants.csv', 'row': 14}, page_content='foodDetailTypes: 이노베이티브퀴진, 일식, 모던차이니즈\nheaderInfo_nameKR: 코자차\nheaderInfo_nameEN: Kojacha\nheaderInfo_nameCN: \nheaderInfo_bookYear: 2025\nheaderInfo_ribbonType: 3.0\ndefaultInfo_chefName: 최유강\ndefaultInfo_phone: 010-9023-7771\ndefaultInfo_openHours: \ndefaultInfo_closeHours: \ndefaultInfo_openHoursWeekend: \ndefaultInfo_closeHoursWeekend: \ndefaultInfo_dayOff: 일요일 휴무\ndefaultInfo_app2Yn: False\nstatusInfo_parking: 가능\nstatusInfo_creditCard: y\nstatusInfo_visit: \nstatusInfo_menu: 런치코스(15만원), 디너코스(25만원)\nstatusInfo_priceRange: 25만원 이상\nstatusInfo_openDate: 2020년\nstatusInfo_businessHours: 12:00~14:30/18:00~22:00\njuso_detailAddress: \njuso_roadAddrPart1: 서울특별시 강남구 학동로97길 17\njuso_engAddr: 17, Hakdong-ro 97-gil, Gangnam-gu, Seoul\njuso_bdNm: \njuso_siNm: 서울특별시\njuso_sggNm: 강남구\njuso_emdNm: 청담동\njuso_liNm: \njuso_rn: \njuso_buldMnnm: 17\njuso_buldSlno: 0\nreview_review: 한식, 일식, 중식의 앞글자를 따서 만든 레스토랑. 신라 호텔에서 20년 가까이 경력을 쌓은 두 셰프의 노하우가 담긴 세심한 코스요리를 선보인다.\nreview_reviewSimple: 한식, 일식, 중식의 앞글자를 따서 만든 레스토랑. 신라 호텔에서 20년 가까이 경력을 쌓은 두 셰프의 노하우가 담긴 세심한 코스요리를 선보인다.\nreview_readerAppraisal: \netcInfo_interior: \netcInfo_seat: \netcInfo_room: \netcInfo_head: \netcInfo_branch: \ndefaultInfo_website: https://www.instagram.com/kojacha.official/'),
#  Document(metadata={'source': 'data/cleaned_all_restaurants.csv', 'row': 15}, page_content='foodDetailTypes: 컨템포러리\nheaderInfo_nameKR: 세븐스도어\nheaderInfo_nameEN: 7th Door\nheaderInfo_nameCN: \nheaderInfo_bookYear: 2025\nheaderInfo_ribbonType: 3.0\ndefaultInfo_chefName: 김대천\ndefaultInfo_phone: 010-9660-3011\ndefaultInfo_openHours: \ndefaultInfo_closeHours: \ndefaultInfo_openHoursWeekend: \ndefaultInfo_closeHoursWeekend: \ndefaultInfo_dayOff: 일, 월요일 휴무\ndefaultInfo_app2Yn: False\nstatusInfo_parking: 발레 파킹\nstatusInfo_creditCard: y\nstatusInfo_visit: \nstatusInfo_menu: 런치코스(18만원), 주말런치코스(21만원), 디너코스(32만원)\nstatusInfo_priceRange: 25만원 이상\nstatusInfo_openDate: 2020년\nstatusInfo_businessHours: 12:00~15:00(마지막 주문 13:00)/18:00~22:00(마지막 주문 19:00)\njuso_detailAddress: 리유빌딩 4층\njuso_roadAddrPart1: 서울특별시 강남구 학동로97길 41\njuso_engAddr: 41, Hakdong-ro 97-gil, Gangnam-gu, Seoul\njuso_bdNm: 리유빌딩\njuso_siNm: 서울특별시\njuso_sggNm: 강남구\njuso_emdNm: 청담동\njuso_liNm: \njuso_rn: \njuso_buldMnnm: 41\njuso_buldSlno: 0\nreview_review: 김대천 셰프의 발효와 숙성을 테마로 한 레스토랑. 다양한 식자재를 발효 및 숙성하여 사용하며 심도있게 코스 요리로 풀어낸다. 단맛, 쓴맛, 매운맛, 단맛, 감칠맛의 다섯 가지 맛에 6번째인 발효와 숙성, 7번째인 셰프의 손맛을 모두 맛볼 수 있는 곳이다.\nreview_reviewSimple: 김대천 셰프의 발효와 숙성을 테마로 한 레스토랑. 다양한 식자재를 발효 및 숙성하여 사용하며 심도있게 코스 요리로 풀어낸다. 단맛, 쓴맛, 매운맛, 단맛, 감칠맛의 다섯 가지 맛에 6번째인 발효와 숙성, 7번째인 셰프의 손맛을 모두 맛볼 수 있는 곳이다.\nreview_readerAppraisal: \netcInfo_interior: \netcInfo_seat: \netcInfo_room: \netcInfo_head: \netcInfo_branch: \ndefaultInfo_website: https://www.7thdoor.kr/, https://www.instagram.com/7thdoor_official/'),
#  Document(metadata={'source': 'data/cleaned_all_restaurants.csv', 'row': 16}, page_content='foodDetailTypes: 한정식, 일반한식\nheaderInfo_nameKR: 수운\nheaderInfo_nameEN: \nheaderInfo_nameCN: \nheaderInfo_bookYear: 2025\nheaderInfo_ribbonType: 3.0\ndefaultInfo_chefName: \ndefaultInfo_phone: 02-722-4310\ndefaultInfo_openHours: \ndefaultInfo_closeHours: \ndefaultInfo_openHoursWeekend: \ndefaultInfo_closeHoursWeekend: \ndefaultInfo_dayOff: 연중무휴\ndefaultInfo_app2Yn: False\nstatusInfo_parking: 가능\nstatusInfo_creditCard: y\nstatusInfo_visit: 을지로입구역에서 종각역 방향으로 직진. 종각역 3-1번 출구를 지나 우측\nstatusInfo_menu: 코스요리(향코스 8만5천원, 풍코스 11만원), 육회비빔밥, 떡갈비비빔밥(각 2만4천원), 갈비찜, 간장게장(각 12만원), 한우육회(3만8천원), 한우육전(7만원)\nstatusInfo_priceRange: 5~10만원대\nstatusInfo_openDate: 2020년\nstatusInfo_businessHours: 11:30~14:30/17:30~22:00 | 일요일 11:30~14:30/17:30~21:00\njuso_detailAddress: 센트로폴리스빌딩 2층\njuso_roadAddrPart1: 서울특별시 종로구 우정국로 26\njuso_engAddr: 26, Ujeongguk-ro, Jongno-gu, Seoul\njuso_bdNm: \njuso_siNm: 서울특별시\njuso_sggNm: 종로구\njuso_emdNm: 공평동\njuso_liNm: \njuso_rn: \njuso_buldMnnm: 26\njuso_buldSlno: 0\nreview_review: 조선시대 조리서 수운잡방을 모티브로 전통 한식을 재현하고 있다. 궁중요리나 고조리서에만 치우치지 않고 현대적인 반가 음식을 풀어내고 있는 것이 특징이다. 인테리어도 고급스러우며 한 장의 원목으로 만든 빅 테이블이 인상적이다.\nreview_reviewSimple: 조선시대 조리서 수운잡방을 모티브로 전통 한식을 재현하고 있다. 궁중요리나 고조리서에만 치우치지 않고 현대적인 반가 음식을 풀어내고 있는 것이 특징이다. 인테리어도 고급스러우며 한 장의 원목으로 만든 빅 테이블이 인상적이다.\nreview_readerAppraisal: \netcInfo_interior: \netcInfo_seat: \netcInfo_room: \netcInfo_head: \netcInfo_branch: \ndefaultInfo_website: https://www.haevichi.com/soowoon/, https://www.instagram.com/haevichidining/'),
#  Document(metadata={'source': 'data/cleaned_all_restaurants.csv', 'row': 17}, page_content="foodDetailTypes: 컨템포러리, 프랑스식\nheaderInfo_nameKR: 라망시크레\nheaderInfo_nameEN: L'Amant Secret\nheaderInfo_nameCN: \nheaderInfo_bookYear: 2025\nheaderInfo_ribbonType: 3.0\ndefaultInfo_chefName: 손종원\ndefaultInfo_phone: 02-317-4003\ndefaultInfo_openHours: \ndefaultInfo_closeHours: \ndefaultInfo_openHoursWeekend: \ndefaultInfo_closeHoursWeekend: \ndefaultInfo_dayOff: 일요일 휴무\ndefaultInfo_app2Yn: False\nstatusInfo_parking: 가능\nstatusInfo_creditCard: y\nstatusInfo_visit: 회현역 6번 출구 앞. 레스케이프 호텔 26층\nstatusInfo_menu: 런치셰프테이스팅코스(14만원), 런치와인페어링(12만원), 디너셰프테이스팅코스(22만원), 디너와인페어링(20만원)\nstatusInfo_priceRange: 25만원 이상\nstatusInfo_openDate: 2018년\nstatusInfo_businessHours: 12:00~15:00(마지막 주문 13:30)/18:00~22:00(마지막 주문 19:30)\njuso_detailAddress: 레스케이프 호텔 26층\njuso_roadAddrPart1: 서울특별시 중구 퇴계로 67\njuso_engAddr: 67, Toegye-ro, Jung-gu, Seoul\njuso_bdNm: \njuso_siNm: 서울특별시\njuso_sggNm: 중구\njuso_emdNm: 회현동1가\njuso_liNm: \njuso_rn: \njuso_buldMnnm: 67\njuso_buldSlno: 0\nreview_review: 부티크호텔 레스케이프 호텔 최상층에 자리한 컨템포러리 프렌치 레스토랑. 세련된 플레이팅의 요리를 파리에 있는 듯한 분위기에서 즐길 수 있다. 코스 구성은 계절별로 바뀐다. 요리와 어울리는 내추럴 와인을 페어링해 즐길 수도 있다. 손종원 셰프가 이타닉가든과 라망시크레 모두 책임지고 있다.\nreview_reviewSimple: 부티크호텔 레스케이프 호텔 최상층에 자리한 컨템포러리 프렌치 레스토랑. 세련된 플레이팅의 요리를 파리에 있는 듯한 분위기에서 즐길 수 있다. 코스 구성은 계절별로 바뀐다. 요리와 어울리는 내추럴 와인을 페어링해 즐길 수도 있다. 손종원 셰프가 이타닉가든과 라망시크레 모두 책임지고 있다.\nreview_readerAppraisal: “즐거운 다이닝 경험을 했습니다. 매우 만족스러웠습니다.”\netcInfo_interior: \netcInfo_seat: \netcInfo_room: \netcInfo_head: \netcInfo_branch: \ndefaultInfo_website: https://www.instagram.com/lamant_secret/"),
#  Document(metadata={'source': 'data/cleaned_all_restaurants.csv', 'row': 18}, page_content='foodDetailTypes: 모던한식\nheaderInfo_nameKR: 온지음레스토랑\nheaderInfo_nameEN: ONJIUM\nheaderInfo_nameCN: \nheaderInfo_bookYear: 2025\nheaderInfo_ribbonType: 3.0\ndefaultInfo_chefName: 조은희, 박성배\ndefaultInfo_phone: 02-6952-0024\ndefaultInfo_openHours: \ndefaultInfo_closeHours: \ndefaultInfo_openHoursWeekend: \ndefaultInfo_closeHoursWeekend: \ndefaultInfo_dayOff: 토, 일, 월요일, 공휴일 휴무\ndefaultInfo_app2Yn: False\nstatusInfo_parking: 가능\nstatusInfo_creditCard: y\nstatusInfo_visit: 통의파출소에서 청와대 방향으로 직진하면 좌측\nstatusInfo_menu: 점심코스(17만원), 저녁코스(25만원)\nstatusInfo_priceRange: 15~25만원대\nstatusInfo_openDate: 2018년\nstatusInfo_businessHours: 12:00~15:00/18:00~22:00(마지막 주문 20:00)\njuso_detailAddress: 4층\njuso_roadAddrPart1: 서울특별시 종로구 효자로 49\njuso_engAddr: 49, Hyoja-ro, Jongno-gu, Seoul\njuso_bdNm: 온지음\njuso_siNm: 서울특별시\njuso_sggNm: 종로구\njuso_emdNm: 창성동\njuso_liNm: \njuso_rn: \njuso_buldMnnm: 49\njuso_buldSlno: 0\nreview_review: 서울을 대표하는 한식 레스토랑 중의 하나로, 정통 한식에 기반한 모던 한식을 파인 다이닝으로 즐길 수 있다. 조은희 주방장과 박성배 수석 연구원이 전국 각지에서 나는 제철 식재료를 연구해 한 가지 코스로 정갈하게 풀어낸다.\nreview_reviewSimple: 서울을 대표하는 한식 레스토랑 중의 하나로, 정통 한식에 기반한 모던 한식을 파인 다이닝으로 즐길 수 있다. 조은희 주방장과 박성배 수석 연구원이 전국 각지에서 나는 제철 식재료를 연구해 한 가지 코스로 정갈하게 풀어낸다.\nreview_readerAppraisal: “한국적인 특색을 기본으로 하면서도 식상하지 않은 재미난 음식을 선보이는 곳. 맛 역시 매우 훌륭하고 서비스도 좋았음. 인생식당.”\netcInfo_interior: \netcInfo_seat: \netcInfo_room: \netcInfo_head: \netcInfo_branch: \ndefaultInfo_website: https://www.instagram.com/onjium_restaurant/'),
#  Document(metadata={'source': 'data/cleaned_all_restaurants.csv', 'row': 19}, page_content='foodDetailTypes: 컨템포러리, 프랑스식\nheaderInfo_nameKR: 무오키\nheaderInfo_nameEN: MUOKI\nheaderInfo_nameCN: \nheaderInfo_bookYear: 2025\nheaderInfo_ribbonType: 3.0\ndefaultInfo_chefName: 박무현\ndefaultInfo_phone: 0507-1314-4171\ndefaultInfo_openHours: 12:00\ndefaultInfo_closeHours: 22:00\ndefaultInfo_openHoursWeekend: \ndefaultInfo_closeHoursWeekend: \ndefaultInfo_dayOff: 일요일 휴무\ndefaultInfo_app2Yn: False\nstatusInfo_parking: 발레 파킹\nstatusInfo_creditCard: y\nstatusInfo_visit: 강남구청역 4번 출구에서 첫 번째 골목으로 좌회전. 디자인치과 옆 골목으로 직진하면 우측\nstatusInfo_menu: 런치코스(13만원), 디너코스(23만원)\nstatusInfo_priceRange: 15~25만원대\nstatusInfo_openDate: 2017년\nstatusInfo_businessHours: 12:00~15:00/18:00~22:00\njuso_detailAddress: \njuso_roadAddrPart1: 서울특별시 강남구 학동로55길 12-12\njuso_engAddr: 12-12, Hakdong-ro 55-gil, Gangnam-gu, Seoul\njuso_bdNm: \njuso_siNm: 서울특별시\njuso_sggNm: 강남구\njuso_emdNm: 청담동\njuso_liNm: \njuso_rn: 학동로55길\njuso_buldMnnm: 12\njuso_buldSlno: 12\nreview_review: 박무현 셰프의 컨템포러리한 프렌치 레스토랑. 계절에 따라 다른 테마로 준비되는 다양한 요리를 정교한 플레이팅으로 내어 준다. 탁 트인 오픈 키친과 모던한 인테리어가 돋보이며, 다이닝룸이 내려다보이는 프라이빗한 룸도 갖추고 있다.\nreview_reviewSimple: 박무현 셰프의 컨템포러리한 프렌치 레스토랑. 계절에 따라 다른 테마로 준비되는 다양한 요리를 정교한 플레이팅으로 내어 준다. 탁 트인 오픈 키친과 모던한 인테리어가 돋보이며, 다이닝룸이 내려다보이는 프라이빗한 룸도 갖추고 있다.\nreview_readerAppraisal: \netcInfo_interior: \netcInfo_seat: \netcInfo_room: \netcInfo_head: \netcInfo_branch: \ndefaultInfo_website: http://www.muoki.kr, https://www.instagram.com/muoki.seoul/'),
#  Document(metadata={'source': 'data/cleaned_all_restaurants.csv', 'row': 20}, page_content='foodDetailTypes: 모던재패니즈, 컨템포러리\nheaderInfo_nameKR: 고료리켄\nheaderInfo_nameEN: \nheaderInfo_nameCN: 小料理健\nheaderInfo_bookYear: 2025\nheaderInfo_ribbonType: 3.0\ndefaultInfo_chefName: 김건\ndefaultInfo_phone: 02-511-7809\ndefaultInfo_openHours: 18:00\ndefaultInfo_closeHours: 23:00\ndefaultInfo_openHoursWeekend: \ndefaultInfo_closeHoursWeekend: \ndefaultInfo_dayOff: 일, 월요일 휴무\ndefaultInfo_app2Yn: False\nstatusInfo_parking: 발레 파킹\nstatusInfo_creditCard: \nstatusInfo_visit: 도산공원 정문 맞은편. 오페라갤러리 옆 골목\nstatusInfo_menu: 오마카세코스(25만원)\nstatusInfo_priceRange: 15~25만원대\nstatusInfo_openDate: 2017년\nstatusInfo_businessHours: 18:00~22:00\njuso_detailAddress: 2층\njuso_roadAddrPart1: 서울특별시 강남구 언주로152길 15-3\njuso_engAddr: 15-3, Eonju-ro 152-gil, Gangnam-gu, Seoul\njuso_bdNm: \njuso_siNm: 서울특별시\njuso_sggNm: 강남구\njuso_emdNm: 신사동\njuso_liNm: \njuso_rn: 언주로174길\njuso_buldMnnm: 15\njuso_buldSlno: 3\nreview_review: 김건 셰프가 내는 컨템포러리 재패니즈 퀴진. 신선한 제철 식재료를 사용해 만든 요리를 코스로 낸다. 일식에 프렌치 또는 이탈리안 터치가 가미된 스타일의 오마카세를 맛볼 수 있다.\nreview_reviewSimple: 김건 셰프가 내는 컨템포러리 재패니즈 퀴진. 신선한 제철 식재료를 사용해 만든 요리를 코스로 낸다. 일식에 프렌치 또는 이탈리안 터치가 가미된 스타일의 오마카세를 맛볼 수 있다.\nreview_readerAppraisal: \netcInfo_interior: \netcInfo_seat: \netcInfo_room: \netcInfo_head: \netcInfo_branch: \ndefaultInfo_website:'),
#  Document(metadata={'source': 'data/cleaned_all_restaurants.csv', 'row': 21}, page_content='foodDetailTypes: 한우오마카세, 소고기구이\nheaderInfo_nameKR: 본앤브레드\nheaderInfo_nameEN: BORN&BRED\nheaderInfo_nameCN: \nheaderInfo_bookYear: 2025\nheaderInfo_ribbonType: 3.0\ndefaultInfo_chefName: \ndefaultInfo_phone: 02-2294-5005\ndefaultInfo_openHours: \ndefaultInfo_closeHours: \ndefaultInfo_openHoursWeekend: \ndefaultInfo_closeHoursWeekend: \ndefaultInfo_dayOff: 화요일 휴무\ndefaultInfo_app2Yn: True\nstatusInfo_parking: 발레 파킹\nstatusInfo_creditCard: y\nstatusInfo_visit: \nstatusInfo_menu: 3층프라이빗룸(런치 20만원, 디너 25만원), 2층캐주얼다이닝(한우모둠 200g 10만원, 300g 13만원), 지하1층맡김차림(38만원), 샤부맡김차림(2인 500g 9만9천원, 4인 1kg 19만8천원)\nstatusInfo_priceRange: 15~25만원대\nstatusInfo_openDate: 2018년\nstatusInfo_businessHours: 12:00~15:00/18:00~22:15(마지막 주문 21:15)\njuso_detailAddress: \njuso_roadAddrPart1: 서울특별시 성동구 마장로42길 1\njuso_engAddr: 1, Majang-ro 42-gil, Seongdong-gu, Seoul\njuso_bdNm: 새림약국\njuso_siNm: 서울특별시\njuso_sggNm: 성동구\njuso_emdNm: 마장동\njuso_liNm: \njuso_rn: 마장로37길\njuso_buldMnnm: 1\njuso_buldSlno: 0\nreview_review: 마장동 우시장 부근에 자리한 고급 부티크 정육점. 한우오마카세의 열풍을 일으킨 주역이다. 품질이 보장되는 소고기구이를 맛볼 수 있다. 1층과 2층은 캐주얼 다이닝으로 일반 고깃집처럼 운영되며, 3층에서는 프라이빗한 오마카세를 즐길 수 있다. 지하 1층은 소수 인원의 예약제로만 운영된다.\nreview_reviewSimple: 마장동 우시장 부근에 자리한 고급 부티크 정육점. 한우오마카세의 열풍을 일으킨 주역이다. 품질이 보장되는 소고기구이를 맛볼 수 있다. 1층과 2층은 캐주얼 다이닝으로 일반 고깃집처럼 운영되며, 3층에서는 프라이빗한 오마카세를 즐길 수 있다. 지하 1층은 소수 인원의 예약제로만 운영된다.\nreview_readerAppraisal: \netcInfo_interior: \netcInfo_seat: \netcInfo_room: \netcInfo_head: \netcInfo_branch: \ndefaultInfo_website: http://www.bandb.co.kr/, https://www.instagram.com/bornandbredkorea'),
#  Document(metadata={'source': 'data/cleaned_all_restaurants.csv', 'row': 22}, page_content='foodDetailTypes: 컨템포러리\nheaderInfo_nameKR: 알라프리마\nheaderInfo_nameEN: alla prima\nheaderInfo_nameCN: \nheaderInfo_bookYear: 2025\nheaderInfo_ribbonType: 3.0\ndefaultInfo_chefName: 김진혁\ndefaultInfo_phone: 02-511-2555\ndefaultInfo_openHours: \ndefaultInfo_closeHours: \ndefaultInfo_openHoursWeekend: \ndefaultInfo_closeHoursWeekend: \ndefaultInfo_dayOff: 화요일, 명절 휴무\ndefaultInfo_app2Yn: False\nstatusInfo_parking: 발레 파킹\nstatusInfo_creditCard: y\nstatusInfo_visit: 논현역 7번 출구에서 첫 번째 골목으로 우회전 후 학동역 방향으로 직진하면 좌측\nstatusInfo_menu: 런치코스(19만원), 디너코스(31만원)\nstatusInfo_priceRange: 25만원 이상\nstatusInfo_openDate: 2015년\nstatusInfo_businessHours: 12:00~15:00/18:00~22:00\njuso_detailAddress: \njuso_roadAddrPart1: 서울특별시 강남구 학동로17길 13\njuso_engAddr: 13, Hakdong-ro 17-gil, Gangnam-gu, Seoul\njuso_bdNm: 인본\njuso_siNm: 서울특별시\njuso_sggNm: 강남구\njuso_emdNm: 논현동\njuso_liNm: \njuso_rn: 학동로17길\njuso_buldMnnm: 13\njuso_buldSlno: 0\nreview_review: 재패니즈의 영향을 받은 컨템포러리 유로피안 레스토랑으로, 김진혁 셰프가 주방을 맡고 있다. 테이스팅 메뉴로 이루어진 코스는 수시로 구성이 바뀌어 셰프의 감각을 엿볼 수 있다. 블랙톤의 세련된 인테리어에 널찍한 공간이 쾌적한 느낌을 준다.\nreview_reviewSimple: 재패니즈의 영향을 받은 컨템포러리 유로피안 레스토랑으로, 김진혁 셰프가 주방을 맡고 있다. 테이스팅 메뉴로 이루어진 코스는 수시로 구성이 바뀌어 셰프의 감각을 엿볼 수 있다. 블랙톤의 세련된 인테리어에 널찍한 공간이 쾌적한 느낌을 준다.\nreview_readerAppraisal: “파인다이닝 입문집이였는데 생각한 대로 정말 좋은 경험이었습니다.”\netcInfo_interior: \netcInfo_seat: \netcInfo_room: \netcInfo_head: \netcInfo_branch: \ndefaultInfo_website: https://allaprima.co.kr/, https://www.instagram.com/restaurant_allaprima/'),
#  Document(metadata={'source': 'data/cleaned_all_restaurants.csv', 'row': 23}, page_content='foodDetailTypes: 모던한식\nheaderInfo_nameKR: 권숙수\nheaderInfo_nameEN: KOREAN DINING KWONSOOKSOO\nheaderInfo_nameCN: \nheaderInfo_bookYear: 2025\nheaderInfo_ribbonType: 3.0\ndefaultInfo_chefName: 권우중\ndefaultInfo_phone: 02-542-6268\ndefaultInfo_openHours: \ndefaultInfo_closeHours: \ndefaultInfo_openHoursWeekend: \ndefaultInfo_closeHoursWeekend: \ndefaultInfo_dayOff: 일, 월요일, 명절 휴무\ndefaultInfo_app2Yn: False\nstatusInfo_parking: 발레 파킹\nstatusInfo_creditCard: y\nstatusInfo_visit: 청담사거리에서 학동사거리 방향으로 직진. 순수도산점에서 우회전하면 우측\nstatusInfo_menu: 점심상(21만원, 주말&공휴일 22만5천원), 저녁미식상(34만원)\nstatusInfo_priceRange: 25만원 이상\nstatusInfo_openDate: 2015년\nstatusInfo_businessHours: 12:00~15:00/18:00~22:00(마지막 주문 20:30)\njuso_detailAddress: 이에스빌딩 4층\njuso_roadAddrPart1: 서울특별시 강남구 압구정로80길 37\njuso_engAddr: 37, Apgujeong-ro 80-gil, Gangnam-gu, Seoul\njuso_bdNm: 이에스빌딩\njuso_siNm: 서울특별시\njuso_sggNm: 강남구\njuso_emdNm: 청담동\njuso_liNm: \njuso_rn: 압구정로80길\njuso_buldMnnm: 37\njuso_buldSlno: 0\nreview_review: 한식을 양식의 형식으로 풀어낸 모던한식 스타일을 선보이는 권우중 셰프의 한식당. 직접 담근 장과 김치, 식초를 사용하여 모던하면서도 한식 전통의 맛을 잘 살리고 있다는 평을 받고 있다. 전통적인 1인 독상을 구현한 점도 독특하다. 여러 종류의 김치로 구성된 김치 카트를 선보이는 등 끊임없이 새로운 모습을 보여준다.\nreview_reviewSimple: 한식을 양식의 형식으로 풀어낸 모던한식 스타일을 선보이는 권우중 셰프의 한식당. 직접 담근 장과 김치, 식초를 사용하여 모던하면서도 한식 전통의 맛을 잘 살리고 있다는 평을 받고 있다. 전통적인 1인 독상을 구현한 점도 독특하다. 여러 종류의 김치로 구성된 김치 카트를 선보이는 등 끊임없이 새로운 모습을 보여준다.\nreview_readerAppraisal: “훌륭하고 건강한 음식들. 두 차례 밖에 가보지 못했지만 참 좋은 정감있는 곳.” “너무 맛있게 잘 먹고 왔어요. 다음에 또 올게요. 진짜 이곳은 사랑이네요.” “훌륭하고 맛있는 음식이 인상적이었습니다.” “런치 코스를 먹었는데 코스에 나오는 요리 전부 다 정갈하니 깔끔한 맛이 나서 좋았어요.”\netcInfo_interior: \netcInfo_seat: \netcInfo_room: \netcInfo_head: \netcInfo_branch: \ndefaultInfo_website: http://kwonsooksoo.com, https://www.instagram.com/kwonsooksoo/'),
#  Document(metadata={'source': 'data/cleaned_all_restaurants.csv', 'row': 24}, page_content='foodDetailTypes: 컨템포러리, 프랑스식\nheaderInfo_nameKR: 제로컴플렉스\nheaderInfo_nameEN: Zero Complex\nheaderInfo_nameCN: \nheaderInfo_bookYear: 2025\nheaderInfo_ribbonType: 3.0\ndefaultInfo_chefName: 이충후\ndefaultInfo_phone: 02-532-0876\ndefaultInfo_openHours: \ndefaultInfo_closeHours: \ndefaultInfo_openHoursWeekend: \ndefaultInfo_closeHoursWeekend: \ndefaultInfo_dayOff: 월요일 휴무\ndefaultInfo_app2Yn: False\nstatusInfo_parking: 발레 파킹\nstatusInfo_creditCard: y\nstatusInfo_visit: \nstatusInfo_menu: 런치코스(19만원), 디너코스(27만원)\nstatusInfo_priceRange: 25만원 이상\nstatusInfo_openDate: 2013년\nstatusInfo_businessHours: 12:00~15:30(마지막 주문 13:00)/18:00~22:30(마지막 주문 19:30)\njuso_detailAddress: \njuso_roadAddrPart1: 서울특별시 용산구 서빙고로59길 11-8\njuso_engAddr: 11-8 Seobinggo-ro 59-gil, Yongsan-gu, Seoul\njuso_bdNm: \njuso_siNm: 서울특별시\njuso_sggNm: 용산구\njuso_emdNm: 서빙고동\njuso_liNm: \njuso_rn: 퇴계로\njuso_buldMnnm: 11\njuso_buldSlno: 8\nreview_review: 네오비스트로를 표방하는 곳으로, 이충후 셰프의 크리에이티브한 프렌치 코스를 맛볼 수 있다. 미니멀한 인테리어에, 허브와 특수 채소를 많이 사용하여 아름다운 플레이팅을 만드는 것이 특징이다. 2023년 6월 서빙고로 이전하여 새로운 모습을 선보인다.\nreview_reviewSimple: 네오비스트로를 표방하는 곳으로, 이충후 셰프의 크리에이티브한 프렌치 코스를 맛볼 수 있다. 미니멀한 인테리어에, 허브와 특수 채소를 많이 사용하여 아름다운 플레이팅을 만드는 것이 특징이다. 2023년 6월 서빙고로 이전하여 새로운 모습을 선보인다.\nreview_readerAppraisal: “우리나라에서는 흔치 않은 스타일의 레스토랑. 고기 없이도 최상급 코스를 풀어낼 수 있는 곳. 우리나라에서 한 손에 꼽을 곳이라 생각함.” “매우 창의적이고 개성 넘치는, 그러면서도 완성도 높은 퀄리티의 음식을 내놓는 식당입니다.”\netcInfo_interior: \netcInfo_seat: \netcInfo_room: \netcInfo_head: \netcInfo_branch: \ndefaultInfo_website: https://www.instagram.com/zerocomplex_seoul'),
#  Document(metadata={'source': 'data/cleaned_all_restaurants.csv', 'row': 25}, page_content='foodDetailTypes: 이탈리아식\nheaderInfo_nameKR: 테이블포포\nheaderInfo_nameEN: Table For Four\nheaderInfo_nameCN: \nheaderInfo_bookYear: 2025\nheaderInfo_ribbonType: 3.0\ndefaultInfo_chefName: 김성운\ndefaultInfo_phone: 02-3478-0717\ndefaultInfo_openHours: \ndefaultInfo_closeHours: \ndefaultInfo_openHoursWeekend: \ndefaultInfo_closeHoursWeekend: \ndefaultInfo_dayOff: 명절 당일 휴무\ndefaultInfo_app2Yn: False\nstatusInfo_parking: 발레 파킹\nstatusInfo_creditCard: y\nstatusInfo_visit: 고속터미널역에서 이수교차로 방향으로 약 1km 직진. 장원빌라트 아파트에서 좌회전하면 좌측\nstatusInfo_menu: 런치코스(8만원), 디너코스(15만원)\nstatusInfo_priceRange: 15~25만원대\nstatusInfo_openDate: 2014년\nstatusInfo_businessHours: 12:00~15:00/18:00~22:00\njuso_detailAddress: 명빌딩 2층\njuso_roadAddrPart1: 서울특별시 서초구 사평대로14길 11\njuso_engAddr: 11, Sapyeong-daero 14-gil, Seocho-gu, Seoul\njuso_bdNm: 명빌딩\njuso_siNm: 서울특별시\njuso_sggNm: 서초구\njuso_emdNm: 반포동\njuso_liNm: \njuso_rn: 사평대로14길\njuso_buldMnnm: 11\njuso_buldSlno: 0\nreview_review: 부띠끄 블루밍에서 많은 사랑을 받았던 김성운 셰프의 레스토랑으로 이탈리안에 기반한 컨템포러리 퀴진을 선보인다. 김성운 셰프의 고향인 태안에서 가져오는 고품질의 신선한 해산물과 농산물을 사용하여 로컬&팜투테이블을 실현하고 있다. 아기자기하면서도 화려한 플레이팅이 시각적인 즐거움을 더한다.\nreview_reviewSimple: 태안 출신의 김성운 셰프가 운영하는 곳으로, 이탈리안에 기반한 섬세한 유러피언 코스 요리를 맛볼 수 있다. 태안에서 가져오는 신선한 식재료를 많이 사용하는 것이 특징. 아기자기하면서도 화려한 플레이팅이 시각적인 즐거움을 더한다.\nreview_readerAppraisal: “태안에서 공수한 훌륭한 식재료로 그 본연의 맛을 잘 이끌어낸 요리를 내는 곳. 내추럴하면서도 밸런스 있는 맛이 인상적.” “다양하고 좋은 재료로 창의적인 요리를 맛볼 수 있다.”\netcInfo_interior: \netcInfo_seat: \netcInfo_room: \netcInfo_head: \netcInfo_branch: \ndefaultInfo_website: http://tablefor4.fordining.kr/, https://www.instagram.com/table_for_four_/)'),
#  Document(metadata={'source': 'data/cleaned_all_restaurants.csv', 'row': 26}, page_content='foodDetailTypes: 프랑스식\nheaderInfo_nameKR: 파씨오네\nheaderInfo_nameEN: Passionne\nheaderInfo_nameCN: \nheaderInfo_bookYear: 2025\nheaderInfo_ribbonType: 3.0\ndefaultInfo_chefName: 이방원\ndefaultInfo_phone: 02-546-7719\ndefaultInfo_openHours: \ndefaultInfo_closeHours: \ndefaultInfo_openHoursWeekend: \ndefaultInfo_closeHoursWeekend: \ndefaultInfo_dayOff: 일요일, 명절 휴무\ndefaultInfo_app2Yn: False\nstatusInfo_parking: 발레 파킹\nstatusInfo_creditCard: y\nstatusInfo_visit: 학동사거리에서 도산공원교차로 방향으로 직진. CGV청담점에서 우회전 후 직진하면 좌측\nstatusInfo_menu: 런치코스(6만5천원), 디너코스(11만원)\nstatusInfo_priceRange: 10~15만원대\nstatusInfo_openDate: 2012년\nstatusInfo_businessHours: 12:00~15:00(마지막 주문 13:30)/18:00~22:00(마지막 주문 20:00) | 토요일 12:00~15:30(마지막 주문 13:30)/18:00~21:30(마지막 주문 19:30)\njuso_detailAddress: 2층\njuso_roadAddrPart1: 서울특별시 강남구 언주로164길 39\njuso_engAddr: 39, Eonju-ro 164-gil, Gangnam-gu, Seoul\njuso_bdNm: \njuso_siNm: 서울특별시\njuso_sggNm: 강남구\njuso_emdNm: 신사동\njuso_liNm: \njuso_rn: 언주로164길\njuso_buldMnnm: 39\njuso_buldSlno: 0\nreview_review: 프랑스에서도 손꼽히는 라르페주, 라스트랑스 등 최고급 레스토랑에서 경험을 쌓은 이방원 셰프의 모던 프렌치 레스토랑. 클래식한 프렌치 레스토랑과 차별화된 신선한 감각을 보여주고 있다. 매일 좋은 재료를 엄선해 런치, 디너 각 한 가지의 코스를 내며, 재료의 풍미를 살리는 적절한 버터, 소금의 사용이 돋보인다. 특히 채소를 다양하게 활용한 요리에 강점이 있으며, 안정적인 조리에서 나오는 기본기도 탄탄하다.\nreview_reviewSimple: 프랑스에서도 손꼽히는 라르페주, 라스트랑스 등 최고급 레스토랑에서 경험을 쌓은 이방원 셰프의 모던 프렌치 레스토랑. 클래식한 프렌치 레스토랑과 차별화된 신선한 감각을 보여주고 있다. 매일 좋은 재료를 엄선해 런치, 디너 각 한 가지의 코스를 내며, 재료의 풍미를 살리는 적절한 버터, 소금의 사용이 돋보인다. 특히 채소를 다양하게 활용한 요리에 강점이 있으며, 안정적인 조리에서 나오는 기본기도 탄탄하다.\nreview_readerAppraisal: “전반적으로 음식이 만족스러웠다. 특별한 날 방문하기에 부족함 없는 곳.” “파인 레스토랑 비기너가 주로 찾아간다면, 그것만으로도 충분히 이곳은 매우 훌륭.” “창의적이고 맛있는 프랑스 요리를 합리적인 가격에 먹을 수 있어서 아주 좋았다.” “이방원 셰프님의 실력을 마음껏 즐길 수 있는 곳. 점심에는 이 가격에 이 정도 프렌치를 즐길 수 있는 곳이 강남에 세 곳이나 될지 모르겠다.” “이방원 셰프님의 설명을 곁들인 음식은 서울에서 가성비 최고 수준을 느끼게 해준다. 전통적이면서도 지루하지 않은 음식들은 다시 가게끔 유도한다.” “재료에 충실한 요리를 내놓는 것이 강점입니다.” “단순히 맛있는 프렌치 레스토랑이 한 곳 더 생긴 정도가 아니라 우리나라 프렌치 음식의 폭이 넓어졌다는 느낌을 받는다.”\netcInfo_interior: \netcInfo_seat: \netcInfo_room:'),
#  Document(metadata={'source': 'data/cleaned_all_restaurants.csv', 'row': 26}, page_content='etcInfo_interior: \netcInfo_seat: \netcInfo_room: \netcInfo_head: \netcInfo_branch: \ndefaultInfo_website:'),
#  Document(metadata={'source': 'data/cleaned_all_restaurants.csv', 'row': 27}, page_content='foodDetailTypes: 프랑스식\nheaderInfo_nameKR: 비스트로드욘트빌\nheaderInfo_nameEN: BISTROT de YOUNTVILLE\nheaderInfo_nameCN: \nheaderInfo_bookYear: 2025\nheaderInfo_ribbonType: 3.0\ndefaultInfo_chefName: 타미리\ndefaultInfo_phone: 02-541-1550\ndefaultInfo_openHours: \ndefaultInfo_closeHours: \ndefaultInfo_openHoursWeekend: \ndefaultInfo_closeHoursWeekend: \ndefaultInfo_dayOff: 월요일, 명절 휴무\ndefaultInfo_app2Yn: False\nstatusInfo_parking: 발레 파킹\nstatusInfo_creditCard: y\nstatusInfo_visit: 학동사거리에서 압구정로데오역 방향으로 직진. 태그호이어부티크에서 우회전 후 두 번째 골목으로 좌회전\nstatusInfo_menu: 런치코스(6만5천원, 9만5천원), 디너코스(11만원, 13만원)\nstatusInfo_priceRange: 10~15만원대\nstatusInfo_openDate: 2009년\nstatusInfo_businessHours: 11:30~15:00(마지막 주문 13:30)/18:00~22:00(마지막 주문 20:00) | 토, 일요일 11:30~15:30(마지막 주문 14:00)/18:00~22:00(마지막 주문 20:00)\njuso_detailAddress: 이안빌딩 1층\njuso_roadAddrPart1: 서울특별시 강남구 선릉로158길 13-7\njuso_engAddr: 13-7, Seolleung-ro 158-gil, Gangnam-gu, Seoul\njuso_bdNm: \njuso_siNm: 서울특별시\njuso_sggNm: 강남구\njuso_emdNm: 청담동\njuso_liNm: \njuso_rn: 선릉로158길\njuso_buldMnnm: 13\njuso_buldSlno: 7\nreview_review: 편안한 분위기에서 와인과 프랑스 음식을 즐길 수 있는 곳. 클래식한 정통 프렌치 비스트로를 즐길 수 있다. 알라카르트 외에도 프리픽스 메뉴가 준비되어 있어 전채, 메인, 디저트에서 원하는 것을 선택해 주문할 수 있는 점이 매력적이다. 해산물 요리에 강점이 있으며 가격 대비 만족도도 뛰어나다.\nreview_reviewSimple: 편안한 분위기에서 와인과 프랑스 음식을 즐길 수 있는 곳. 클래식한 정통 프렌치 비스트로를 즐길 수 있다. 알라카르트 외에도 프리픽스 메뉴가 준비되어 있어 전채, 메인, 디저트에서 원하는 것을 선택해 주문할 수 있는 점이 매력적이다. 해산물 요리에 강점이 있으며 가격 대비 만족도도 뛰어나다.\nreview_readerAppraisal: “작은 프랑스 마을에 온 것 처럼 예쁜 장소와 식기들, 분위기.” “합리적인 가격에 기분 좋은 분위기와 서비스. 가격 대비 아주 만족스러운 식사를 했습니다.” “콩피와 곁들여 나오는 가니시는 가히 최고다. 샤토브리앙도 언제나 한결같은 수준을 유지하는 집.” “저녁 메뉴가 아주 훌륭.” “점심 메뉴가 가격 경쟁력이 있다고 봄.” “창의적인 음식과 정갈한 분위기가 음식 맛을 돋운다.”\netcInfo_interior: 클래식한 유럽풍\netcInfo_seat: 24석\netcInfo_room: 1개(6~7석)\netcInfo_head: \netcInfo_branch: \ndefaultInfo_website: https://www.instagram.com/yountvillebistro/'),
#  Document(metadata={'source': 'data/cleaned_all_restaurants.csv', 'row': 28}, page_content='foodDetailTypes: 모던한식\nheaderInfo_nameKR: 무궁화\nheaderInfo_nameEN: \nheaderInfo_nameCN: 無窮花\nheaderInfo_bookYear: 2025\nheaderInfo_ribbonType: 3.0\ndefaultInfo_chefName: \ndefaultInfo_phone: 02-317-7061\ndefaultInfo_openHours: \ndefaultInfo_closeHours: \ndefaultInfo_openHoursWeekend: \ndefaultInfo_closeHoursWeekend: \ndefaultInfo_dayOff: 연중무휴\ndefaultInfo_app2Yn: False\nstatusInfo_parking: 발레 파킹\nstatusInfo_creditCard: y\nstatusInfo_visit: 소공동 서울롯데호텔 본관 38층\nstatusInfo_menu: 점심코스(무궁화 16만원, 금강 17만원, 태백 19만5천원, 백록 24만원), 저녁코스(태백 19만5천원, 백록 24만원, 무궁화 33만원)\nstatusInfo_priceRange: 15~25만원대\nstatusInfo_openDate: 1980년\nstatusInfo_businessHours: 11:30~14:30/18:00~22:00(마지막 주문 13:30, 20:30)\njuso_detailAddress: 롯데호텔 본관 38층\njuso_roadAddrPart1: 서울특별시 중구 을지로 30\njuso_engAddr: 30, Eulji-ro, Jung-gu, Seoul\njuso_bdNm: 롯데호텔\njuso_siNm: 서울특별시\njuso_sggNm: 중구\njuso_emdNm: 소공동\njuso_liNm: \njuso_rn: 을지로\njuso_buldMnnm: 30\njuso_buldSlno: 0\nreview_review: 모던하게 재해석한 한정식을 코스로 선보인다. 현대적인 감각의 구절판, 뜨거운 철판에 올려나오는 한우구이 등이 대표 메뉴. 한식과 어울리는 와인과 전통주, 전통차도 준비되어 있다. 무궁화 꽃을 모티브로 한 모던한 인테리어에 38층의 전망도 훌륭하다.\nreview_reviewSimple: 모던하게 재해석한 한정식을 코스로 선보인다. 현대적인 감각의 구절판, 뜨거운 철판에 올려나오는 한우구이 등이 대표 메뉴. 한식과 어울리는 와인과 전통주, 전통차도 준비되어 있다. 무궁화 꽃을 모티브로 한 모던한 인테리어에 38층의 전망도 훌륭하다.\nreview_readerAppraisal: “멋진 뷰와 함께 한식 코스를.” “전통성을 살리면서 동시에 세련된 프레젠테이션과 슴슴한 맛으로 쉽게 질리지 않는다. 가족 모임, 외국인 접대에 좋은 곳.” “모던한 실내 분위기와 좋은 전경 속에서 전통적인 한식을 맛볼 수 있다. 서비스도 수준급이며, 와인 리스트도 나쁘지 않은 편.”\netcInfo_interior: \netcInfo_seat: 100석\netcInfo_room: 7개(2~30석)\netcInfo_head: \netcInfo_branch: \ndefaultInfo_website: https://www.lottehotel.com/seoul-hotel/ko/dining/restaurant-mugunghwa.html , https://www.instagram.com/lottehotel_seoul/'),
# ...
#  Document(metadata={'source': 'data/cleaned_all_restaurants.csv', 'row': 979}, page_content='foodDetailTypes: 생선회\nheaderInfo_nameKR: 방파제\nheaderInfo_nameEN: \nheaderInfo_nameCN: \nheaderInfo_bookYear: 2024\nheaderInfo_ribbonType: 1.0\ndefaultInfo_chefName: 홍종관\ndefaultInfo_phone: 051-753-7325\ndefaultInfo_openHours: \ndefaultInfo_closeHours: \ndefaultInfo_openHoursWeekend: \ndefaultInfo_closeHoursWeekend: \ndefaultInfo_dayOff: 월요일, 명절 당일 및 익일 휴무\ndefaultInfo_app2Yn: False\nstatusInfo_parking: 가능(유료)\nstatusInfo_creditCard: y\nstatusInfo_visit: 부산 민락동 횟집 거리 내에 위치\nstatusInfo_menu: 런치특별정식(3만원), A코스(4만원), 특코스(5만8천원), 어향코스(7만8천원), 어락코스(11만원), 수비드전복장덮밥정식(2만8천원), 물회정식, 회비빔밥정식(각 1만8천원)\nstatusInfo_priceRange: 2~5만원대\nstatusInfo_openDate: 1982년\nstatusInfo_businessHours: 11:30~15:00/17:00~22:00(마지막 주문 20:30)\njuso_detailAddress: \njuso_roadAddrPart1: 부산광역시 수영구 광안해변로294번길 24\njuso_engAddr: 24, Gwanganhaebyeon-ro 294beon-gil, Suyeong-gu, Busan\njuso_bdNm: \njuso_siNm: 부산광역시\njuso_sggNm: 수영구\njuso_emdNm: 민락동\njuso_liNm: \njuso_rn: \njuso_buldMnnm: 24\njuso_buldSlno: 0\nreview_review: 제철에 현지에서 나는 자연산 활어를 사용하는 횟집. 자연산 활어만을 취급하여 어종과 가격이 시기별로 다르며 신선하다. 해산물 요리와 생선회를 동시에 맛볼 수 있는 생선회 코스를 추천. 룸 시설이 잘되어 있어서 가족 모임이나 회식에 좋다.\nreview_reviewSimple: 제철에 현지에서 나는 자연산 활어를 사용하는 횟집. 자연산 활어만을 취급하여 어종과 가격이 시기별로 다르며 신선하다. 해산물 요리와 생선회를 동시에 맛볼 수 있는 생선회 코스를 추천. 룸 시설이 잘되어 있어서 가족 모임이나 회식에 좋다.\nreview_readerAppraisal: "40년동안 광안리에서 자연산 횟집으로 자리를 지키고 있는 맛집." “오래된 향토 음식점. 음식이 꾸밈이 없고 회가 매우 신선하다.”\netcInfo_interior: \netcInfo_seat: \netcInfo_room: \netcInfo_head: \netcInfo_branch: \ndefaultInfo_website: https://bangpaje.co.kr/, https://www.instagram.com/thebangpaje/'),
#  Document(metadata={'source': 'data/cleaned_all_restaurants.csv', 'row': 980}, page_content='foodDetailTypes: 닭백숙\nheaderInfo_nameKR: 성서제1능이버섯능이백숙\nheaderInfo_nameEN: \nheaderInfo_nameCN: \nheaderInfo_bookYear: 2024\nheaderInfo_ribbonType: 1.0\ndefaultInfo_chefName: 박정호\ndefaultInfo_phone: 0507-1361-4774\ndefaultInfo_openHours: \ndefaultInfo_closeHours: \ndefaultInfo_openHoursWeekend: \ndefaultInfo_closeHoursWeekend: \ndefaultInfo_dayOff: 명절 당일 휴무\ndefaultInfo_app2Yn: False\nstatusInfo_parking: 가능(유료)\nstatusInfo_creditCard: y\nstatusInfo_visit: \nstatusInfo_menu: 능이오리백숙(2-3인 7만9천원, 4-5인 11만8천원), 능이토종닭백숙(2-3인 6만9천원, 4-5인 11만8천원), 능계탕(1인 1만8천원), 능이모둠버섯전(1만3천원)\nstatusInfo_priceRange: 2~5만원대\nstatusInfo_openDate: 2011년\nstatusInfo_businessHours: 10:30~14:00/15:50~21:30(마지막 주문 20:30) | 토, 일요일, 공휴일 10:30~21:30(마지막 주문 20:30)\njuso_detailAddress: \njuso_roadAddrPart1: 대구광역시 달서구 달구벌대로251길 12\njuso_engAddr: 12, Dalgubeol-daero 251-gil, Dalseo-gu, Daegu\njuso_bdNm: \njuso_siNm: 대구광역시\njuso_sggNm: 달서구\njuso_emdNm: 이곡동\njuso_liNm: \njuso_rn: \njuso_buldMnnm: 12\njuso_buldSlno: 0\nreview_review: 능이버섯 백숙 요리로 몸에 좋은 보양식을 선보이는 곳. 능이버섯 향이 가득한 깔끔하고 깊은 맛의 국물이 일품이며 녹두찹쌀죽과 함께 먹으면 좋다. 유황오리, 토종닭 두 종류가 있다. 능이오리백숙은 900도가 넘는 화염처리 과정을 거쳐 불순물과 불필요한 지방을 제거하여 잡내가 없으며 토종닭은 우리나라 고유 품종 한닭을 사용한다.\nreview_reviewSimple: 능이버섯 백숙 요리로 몸에 좋은 보양식을 선보이는 곳. 능이버섯 향이 가득한 깔끔하고 깊은 맛의 국물이 일품이며 녹두찹쌀죽과 함께 먹으면 좋다. 유황오리, 토종닭 두 종류가 있다. 능이오리백숙은 900도가 넘는 화염처리 과정을 거쳐 불순물과 불필요한 지방을 제거하여 잡내가 없으며 토종닭은 우리나라 고유 품종 한닭을 사용한다.\nreview_readerAppraisal: \netcInfo_interior: \netcInfo_seat: \netcInfo_room: \netcInfo_head: \netcInfo_branch: \ndefaultInfo_website: https://www.instagram.com/god_100_sook_official/'),
#  Document(metadata={'source': 'data/cleaned_all_restaurants.csv', 'row': 981}, page_content='foodDetailTypes: 일반중식\nheaderInfo_nameKR: 백객도\nheaderInfo_nameEN: \nheaderInfo_nameCN: 佰客到\nheaderInfo_bookYear: 2024\nheaderInfo_ribbonType: 1.0\ndefaultInfo_chefName: \ndefaultInfo_phone: 051-554-5873\ndefaultInfo_openHours: \ndefaultInfo_closeHours: \ndefaultInfo_openHoursWeekend: \ndefaultInfo_closeHoursWeekend: \ndefaultInfo_dayOff: 화요일 휴무\ndefaultInfo_app2Yn: False\nstatusInfo_parking: 불가\nstatusInfo_creditCard: 불가\nstatusInfo_visit: 온천동 화인아파트와 화신아파트 사이 길로 진입하여 500미터 거리에 위치\nstatusInfo_menu: 짜장면, 우동, 짬뽕, 울면, 간짜장, 볶음밥, 짬뽕밥, 짜장밥(각 5천원), 오므라이스(6천원), 탕수육(2만원)\nstatusInfo_priceRange: 1만원 미만\nstatusInfo_openDate: \nstatusInfo_businessHours: 11:00~14:00\njuso_detailAddress: \njuso_roadAddrPart1: 부산광역시 동래구 금정마을로 70\njuso_engAddr: 70, Geumjeongmaeul-ro, Dongnae-gu, Busan\njuso_bdNm: \njuso_siNm: 부산광역시\njuso_sggNm: 동래구\njuso_emdNm: 온천동\njuso_liNm: \njuso_rn: \njuso_buldMnnm: 70\njuso_buldSlno: 0\nreview_review: 작은 노포 중국집으로, 간짜장이 맛있기로 유명하다. 단맛과 짠맛의 조화가 잘 이루어진 이 곳의 간짜장을 인생 짜장 맛집이라 하는 사람도 있다. 옛날 스타일의 탕수육도 추천할 만하다. 현금만 받으므로 미리 준비하여야 한다.\nreview_reviewSimple: 작은 노포 중국집으로, 간짜장이 맛있기로 유명하다. 단맛과 짠맛의 조화가 잘 이루어진 이 곳의 간짜장을 인생 짜장 맛집이라 하는 사람도 있다. 옛날 스타일의 탕수육도 추천할 만하다. 현금만 받으므로 미리 준비하여야 한다.\nreview_readerAppraisal: \netcInfo_interior: \netcInfo_seat: \netcInfo_room: \netcInfo_head: \netcInfo_branch: \ndefaultInfo_website:'),
#  Document(metadata={'source': 'data/cleaned_all_restaurants.csv', 'row': 982}, page_content='foodDetailTypes: 햄버거\nheaderInfo_nameKR: 라모스버거\nheaderInfo_nameEN: RAMOS BURGER\nheaderInfo_nameCN: \nheaderInfo_bookYear: 2024\nheaderInfo_ribbonType: 1.0\ndefaultInfo_chefName: 구희석\ndefaultInfo_phone: 033-252-0006\ndefaultInfo_openHours: \ndefaultInfo_closeHours: \ndefaultInfo_openHoursWeekend: \ndefaultInfo_closeHoursWeekend: \ndefaultInfo_dayOff: 연중무휴\ndefaultInfo_app2Yn: False\nstatusInfo_parking: 가능\nstatusInfo_creditCard: y\nstatusInfo_visit: \nstatusInfo_menu: 라모스버거(1만9백원), 나고야버거, 뉴욕치즈의여신, 아보카도삼바버거(각 1만2천9백원), 치즈스틱(7천9백원), 새우튀김(8천9백원)\nstatusInfo_priceRange: 1~2만원대\nstatusInfo_openDate: 2014년\nstatusInfo_businessHours: 10:00~21:00(마지막 주문 20:00) | 금, 토요일 10:00~22:00(마지막 주문 21:00)\njuso_detailAddress: \njuso_roadAddrPart1: 강원특별자치도 춘천시 옛경춘로 835\njuso_engAddr: 835, Yetgyeongchun-ro, Chuncheon-si, Gangwon-do\njuso_bdNm: \njuso_siNm: 강원특별자치도\njuso_sggNm: 춘천시\njuso_emdNm: 삼천동\njuso_liNm: \njuso_rn: \njuso_buldMnnm: 835\njuso_buldSlno: 0\nreview_review: 미군 부대 근무 경력이 있는 외조부의 비법을 전수 받아 빵, 패티, 소스 등을 직접 모두 만드는, 춘천의 오래된 수제버거 전문점. 일본 나고야 지방의 수제버거 가게에서 전수받았다고 하는 나고야버거가 인기 메뉴 중 하나다.\nreview_reviewSimple: 미군 부대 근무 경력이 있는 외조부의 비법을 전수 받아 빵, 패티, 소스 등을 직접 모두 만드는, 춘천의 오래된 수제버거 전문점. 일본 나고야 지방의 수제버거 가게에서 전수받았다고 하는 나고야버거가 인기 메뉴 중 하나다.\nreview_readerAppraisal: \netcInfo_interior: \netcInfo_seat: \netcInfo_room: \netcInfo_head: \netcInfo_branch: \ndefaultInfo_website: https://www.instagram.com/ramos_burger/'),
#  Document(metadata={'source': 'data/cleaned_all_restaurants.csv', 'row': 983}, page_content='foodDetailTypes: 소고기구이\nheaderInfo_nameKR: 마당넓은집\nheaderInfo_nameEN: \nheaderInfo_nameCN: \nheaderInfo_bookYear: 2024\nheaderInfo_ribbonType: 1.0\ndefaultInfo_chefName: \ndefaultInfo_phone: 031-763-9255\ndefaultInfo_openHours: \ndefaultInfo_closeHours: \ndefaultInfo_openHoursWeekend: \ndefaultInfo_closeHoursWeekend: \ndefaultInfo_dayOff: 연중무휴\ndefaultInfo_app2Yn: False\nstatusInfo_parking: 가능\nstatusInfo_creditCard: y\nstatusInfo_visit: \nstatusInfo_menu: 꽃등심(130g 6만5천원), 살치살(130g 6만5천원), 안창살(130g 7만8천원), 특수부위(120g 6만8천원), 육사시미(130g 6만8천원), 갈비탕(1만5천원), 뚝배기불고기(1만5천원), 멍게비빔밥(1만5천원)\nstatusInfo_priceRange: 10~15만원대\nstatusInfo_openDate: 2021년\nstatusInfo_businessHours: 11:00~22:00\njuso_detailAddress: \njuso_roadAddrPart1: 경기도 광주시 곤지암읍 광여로 817\njuso_engAddr: 817 Gwangyeo-ro, Gonjiam-eup, Gwangju-si, Gyeonggi-do\njuso_bdNm: \njuso_siNm: 경기도\njuso_sggNm: 광주시\njuso_emdNm: 곤지암읍\njuso_liNm: 건업리\njuso_rn: \njuso_buldMnnm: 817\njuso_buldSlno: 0\nreview_review: 투플러스 등급 이상의 한우만 취급하는 한우구이 전문점. 살아있는 마블링과 담백한 육질을 자랑하며, 기본 찬으로 직접 담근 김치와 나물 반찬을 내준다. 식사로 나물밥과 해물 된장도 추천 메뉴.\nreview_reviewSimple: 투플러스 등급 이상의 한우만 취급하는 한우구이 전문점. 살아있는 마블링과 담백한 육질을 자랑하며, 기본 찬으로 직접 담근 김치와 나물 반찬을 내준다. 나물밥과 해물 된장도 추천 메뉴.\nreview_readerAppraisal: \netcInfo_interior: \netcInfo_seat: \netcInfo_room: \netcInfo_head: \netcInfo_branch: \ndefaultInfo_website:'),
#  Document(metadata={'source': 'data/cleaned_all_restaurants.csv', 'row': 984}, page_content='foodDetailTypes: 한정식\nheaderInfo_nameKR: 오월식당\nheaderInfo_nameEN: owol\nheaderInfo_nameCN: \nheaderInfo_bookYear: 2024\nheaderInfo_ribbonType: 1.0\ndefaultInfo_chefName: 유종심\ndefaultInfo_phone: 070-8865-2009\ndefaultInfo_openHours: \ndefaultInfo_closeHours: \ndefaultInfo_openHoursWeekend: \ndefaultInfo_closeHoursWeekend: \ndefaultInfo_dayOff: 연중무휴\ndefaultInfo_app2Yn: False\nstatusInfo_parking: 가능\nstatusInfo_creditCard: y\nstatusInfo_visit: 서수지ic에서 10분\nstatusInfo_menu: 고등어구이반상(1만8천원), 모둠장반상(2인 이상 짝수 단위로 주문, 1인 4만원), 단호박갈비찜반상(2인 이상 짝수 단위로 주문, 1인 3만8천원), 간장게장반상(4만8천원), 양념게장반상, 보리굴비반상(각 3만2천원), 전복돌솥영양밥반상(3만원)\nstatusInfo_priceRange: 2~5만원대\nstatusInfo_openDate: 2018년\nstatusInfo_businessHours: 11:00~15:00/17:00~21:00 | 토, 일요일 11:00~21:00\njuso_detailAddress: \njuso_roadAddrPart1: 경기도 용인시 수지구 동천로 411\njuso_engAddr: 411, Dongcheon-ro, Suji-gu, Yongin-si, Gyeonggi-do\njuso_bdNm: \njuso_siNm: 경기도\njuso_sggNm: 용인시 수지구\njuso_emdNm: 동천동\njuso_liNm: \njuso_rn: \njuso_buldMnnm: 411\njuso_buldSlno: 0\nreview_review: 조용하고 고즈넉한 한옥 구조의 한식당. 정갈한 한식 반상을 선보인다. 단호박갈비찜반상이 인기 메뉴다. 기본 찬은 리필이 가능하며, 와인 리스트도 좋은 편. 바로 옆에 있는 오월다방도 함께 이용해 볼 만하다.\nreview_reviewSimple: 조용하고 고즈넉한 한옥 구조의 한식당. 정갈한 한식 반상을 선보인다. 단호박갈비찜반상이 인기 메뉴다. 기본 찬은 리필이 가능하며, 와인 리스트도 좋은 편. 바로 옆에 있는 오월다방도 함께 이용해 볼 만하다.\nreview_readerAppraisal: “엄마가 차려준 것 같은 맛있고 건강한 밥상이 좋네요.” “압도적인 한옥 분위기에 잔디마당. 주차 걱정 없고, 맛과 질, 양은 더할 나위 없이 좋습니다.”\netcInfo_interior: \netcInfo_seat: \netcInfo_room: \netcInfo_head: \netcInfo_branch: \ndefaultInfo_website: https://www.instagram.com/owol_2009/'),
#  Document(metadata={'source': 'data/cleaned_all_restaurants.csv', 'row': 985}, page_content='foodDetailTypes: 평양냉면\nheaderInfo_nameKR: 수래옥\nheaderInfo_nameEN: \nheaderInfo_nameCN: 秀來屋\nheaderInfo_bookYear: 2024\nheaderInfo_ribbonType: 1.0\ndefaultInfo_chefName: \ndefaultInfo_phone: 031-711-5758\ndefaultInfo_openHours: \ndefaultInfo_closeHours: \ndefaultInfo_openHoursWeekend: \ndefaultInfo_closeHoursWeekend: \ndefaultInfo_dayOff: 월요일 휴무\ndefaultInfo_app2Yn: False\nstatusInfo_parking: 가능\nstatusInfo_creditCard: y\nstatusInfo_visit: \nstatusInfo_menu: 전통평양냉면, 전통평양비빔냉면, 전통온면(각 1만6천원), 장국밥, 육개장(각 1만6천원), 불고기(150g 3만7천원)\nstatusInfo_priceRange: 1~2만원대\nstatusInfo_openDate: 2021년\nstatusInfo_businessHours: 11:30~15:00/17:00~21:30(마지막 주문 20:30)\njuso_detailAddress: \njuso_roadAddrPart1: 경기도 성남시 분당구 대왕판교로 275\njuso_engAddr: 275, Daewangpangyo-ro, Bundang-gu, Seongnam-si, Gyeonggi-do\njuso_bdNm: \njuso_siNm: 경기도\njuso_sggNm: 성남시 분당구\njuso_emdNm: 궁내동\njuso_liNm: \njuso_rn: \njuso_buldMnnm: 275\njuso_buldSlno: 0\nreview_review: 평양냉면만 40년 넘게 한 조리장이 운영하는 평양냉면 전문점. 한다. 육수는 한우 암소로 우려내 진하고 깊은 맛을 내며, 불판 위에 구워 먹는 불고기와 함께 곁들이기도 좋다. 오픈한 지 얼마 안되었지만 입소문을 타고 있다.\nreview_reviewSimple: 평양냉면만 40년 넘게 한 조리장이 운영하는 평양냉면 전문점. 한다. 육수는 한우 암소로 우려내 진하고 깊은 맛을 내며, 불판 위에 구워 먹는 불고기와 함께 곁들이기도 좋다. 오픈한 지 얼마 안되었지만 입소문을 타고 있다.\nreview_readerAppraisal: \netcInfo_interior: \netcInfo_seat: \netcInfo_room: \netcInfo_head: \netcInfo_branch: \ndefaultInfo_website:'),
#  Document(metadata={'source': 'data/cleaned_all_restaurants.csv', 'row': 986}, page_content='foodDetailTypes: 메밀국수, 평양냉면\nheaderInfo_nameKR: 정서진메밀면옥\nheaderInfo_nameEN: \nheaderInfo_nameCN: \nheaderInfo_bookYear: 2024\nheaderInfo_ribbonType: 1.0\ndefaultInfo_chefName: 김갑수\ndefaultInfo_phone: 032-566-3844\ndefaultInfo_openHours: \ndefaultInfo_closeHours: \ndefaultInfo_openHoursWeekend: \ndefaultInfo_closeHoursWeekend: \ndefaultInfo_dayOff: 화요일, 명절 전날 및 당일 휴무\ndefaultInfo_app2Yn: False\nstatusInfo_parking: 가능\nstatusInfo_creditCard: y\nstatusInfo_visit: \nstatusInfo_menu: 평양냉면, 비빔냉면, 냉소바, 검은콩국수(각 1만2천원), 아롱사태수육(2만3천원), 감자채전(7천원), 메밀전병(1만2천원)\nstatusInfo_priceRange: 1~2만원대\nstatusInfo_openDate: 2019년\nstatusInfo_businessHours: 11:00~21:00 | 월요일 11:00~15:30 | 동절기 11:00~15:00\njuso_detailAddress: \njuso_roadAddrPart1: 인천광역시 서구 아라로51번길 3\njuso_engAddr: 3, Ara-ro 51beon-gil, Seo-gu, Incheon\njuso_bdNm: \njuso_siNm: 인천광역시\njuso_sggNm: 서구\njuso_emdNm: 시천동\njuso_liNm: \njuso_rn: \njuso_buldMnnm: 3\njuso_buldSlno: 0\nreview_review: 매일 아침 직접 메밀을 빻아 만드는 100% 순메밀국수 전문점. 양지로 육수를 낸 슴슴한 평양냉면인 물메밀과 비빔메밀이 대표 메뉴다. 바삭하고 고소한 맛이 별미인 감자채전과 곁들여 먹는 것을 추천한다.\nreview_reviewSimple: 매일 아침 직접 메밀을 빻아 만드는 100% 순메밀국수 전문점. 양지로 육수를 낸 슴슴한 평양냉면인 물메밀과 비빔메밀이 대표 메뉴다. 바삭하고 고소한 맛이 별미인 감자채전과 곁들여 먹는 것을 추천한다.\nreview_readerAppraisal: “100% 메밀의 끝판왕!!” “경치도 좋고 맛도 좋아서 적극 추천.”\netcInfo_interior: \netcInfo_seat: \netcInfo_room: \netcInfo_head: \netcInfo_branch: \ndefaultInfo_website: https://www.instagram.com/jangwon_hongdae'),
#  Document(metadata={'source': 'data/cleaned_all_restaurants.csv', 'row': 987}, page_content='foodDetailTypes: 일반중식\nheaderInfo_nameKR: 경방루\nheaderInfo_nameEN: \nheaderInfo_nameCN: \nheaderInfo_bookYear: 2024\nheaderInfo_ribbonType: 1.0\ndefaultInfo_chefName: \ndefaultInfo_phone: 063-631-2325\ndefaultInfo_openHours: \ndefaultInfo_closeHours: \ndefaultInfo_openHoursWeekend: \ndefaultInfo_closeHoursWeekend: \ndefaultInfo_dayOff: 첫째, 셋째 주 월요일 휴무\ndefaultInfo_app2Yn: False\nstatusInfo_parking: 가능\nstatusInfo_creditCard: y\nstatusInfo_visit: \nstatusInfo_menu: 경코스(4인 3만8천원), 방코스(4인 5만원), 루코스(6인 6만원), 짜장면(8천원), 짬뽕(9천원), 우동, 간짜장(각 9천원), 볶음밥(1만원), 탕수육(소 2만3천원, 대 3만3천원)\nstatusInfo_priceRange: 1만원 미만\nstatusInfo_openDate: 1909년\nstatusInfo_businessHours: 11:00~15:00/17:00~21:00(마지막 주문 20:00)\njuso_detailAddress: \njuso_roadAddrPart1: 전라북도 남원시 광한북로 29\njuso_engAddr: 29, Gwanghanbuk-ro, Namwon-si, Jeollabuk-do\njuso_bdNm: \njuso_siNm: 전북특별자치도\njuso_sggNm: 남원시\njuso_emdNm: 금동\njuso_liNm: \njuso_rn: \njuso_buldMnnm: 29\njuso_buldSlno: 0\nreview_review: 남원에서 가장 오래된 중국집으로, 100년이 넘게 4대째 가업을 이어오고 있는 노포다. 대표 메뉴는 탕수육으로, 연근, 목이버섯 등이 들어간 소스가 부어져 나오며, 고기가 부드러우면서도 바삭하다. 짬뽕도 이곳의 추천 메뉴.\nreview_reviewSimple: 남원에서 가장 오래된 중국집으로, 100년이 넘게 4대째 가업을 이어오고 있는 노포다. 대표 메뉴는 탕수육으로, 연근, 목이버섯 등이 들어간 소스가 부어져 나오며, 고기가 부드러우면서도 바삭하다. 짬뽕도 이곳의 추천 메뉴.\nreview_readerAppraisal: \netcInfo_interior: \netcInfo_seat: \netcInfo_room: \netcInfo_head: \netcInfo_branch: \ndefaultInfo_website:'),
#  Document(metadata={'source': 'data/cleaned_all_restaurants.csv', 'row': 988}, page_content='foodDetailTypes: 닭구이\nheaderInfo_nameKR: 새밭골농장\nheaderInfo_nameEN: \nheaderInfo_nameCN: \nheaderInfo_bookYear: 2024\nheaderInfo_ribbonType: 1.0\ndefaultInfo_chefName: \ndefaultInfo_phone: 053-963-3560\ndefaultInfo_openHours: \ndefaultInfo_closeHours: \ndefaultInfo_openHoursWeekend: \ndefaultInfo_closeHoursWeekend: \ndefaultInfo_dayOff: 비정기적 휴무\ndefaultInfo_app2Yn: False\nstatusInfo_parking: 가능\nstatusInfo_creditCard: n\nstatusInfo_visit: \nstatusInfo_menu: 생닭숯불구이, 옻닭, 백숙, 닭도리탕(각 7만원)\nstatusInfo_priceRange: 2~5만원대\nstatusInfo_openDate: \nstatusInfo_businessHours: 10:00~17:00(변동)\njuso_detailAddress: \njuso_roadAddrPart1: 대구광역시 동구 매여로 463-6\njuso_engAddr: 463-6, Maeyeo-ro, Dong-gu, Daegu\njuso_bdNm: \njuso_siNm: 대구광역시\njuso_sggNm: 동구\njuso_emdNm: 상매동\njuso_liNm: \njuso_rn: \njuso_buldMnnm: 463\njuso_buldSlno: 6\nreview_review: 산 속에서 숯불 닭구이를 먹을 수 있는 곳. 메뉴판이 따로 없으며, 닭한마리를 주문하면 양념된 닭을 숯불에 구워먹는 닭구이와 칼칼한 국물의 닭매운탕이 준비된다. 직접 기른 닭을 잡아 요리하기 때문에 예약은 필수며, 찾기가 어려워 아는 사람만 간다고 하는 곳이다. 식사는 실내 공간 또는 야외 평상에서 먹을 수 있으며, 계산은 현금만 가능하다.\nreview_reviewSimple: 산 속에서 숯불 닭구이를 먹을 수 있는 곳. 메뉴판이 따로 없으며, 닭한마리를 주문하면 양념된 닭을 숯불에 구워먹는 닭구이와 칼칼한 국물의 닭매운탕이 준비된다. 직접 기른 닭을 잡아 요리하기 때문에 예약은 필수며, 찾기가 어려워 아는 사람만 간다고 하는 곳이다. 식사는 실내 공간 또는 야외 평상에서 먹을 수 있으며, 계산은 현금만 가능하다.\nreview_readerAppraisal: \netcInfo_interior: \netcInfo_seat: \netcInfo_room: \netcInfo_head: \netcInfo_branch: \ndefaultInfo_website:'),
#  ...]

# %%
from pprint import pprint
pprint(docs[0].page_content)
# Out:
# ('foodDetailTypes: 일반중식\n'
#  'headerInfo_nameKR: 홍보각\n'
#  'headerInfo_nameEN: \n'
#  'headerInfo_nameCN: 紅寶閣\n'
#  'headerInfo_bookYear: 2025\n'
#  'headerInfo_ribbonType: 3.0\n'
#  'defaultInfo_chefName: 여경래\n'
#  'defaultInfo_phone: 02-531-6479\n'
#  'defaultInfo_openHours: \n'
#  'defaultInfo_closeHours: \n'
#  'defaultInfo_openHoursWeekend: \n'
#  'defaultInfo_closeHoursWeekend: \n'
#  'defaultInfo_dayOff: 연중무휴\n'
#  'defaultInfo_app2Yn: True\n'
#  'statusInfo_parking: 가능\n'
#  'statusInfo_creditCard: y\n'
#  'statusInfo_visit: \n'
#  'statusInfo_menu: 스페셜코스(1인 15만원), 디너코스(A 12만원, B 16만원), 고법불도장(13만원), 모자새우(소 '
#  '6만원, 대 10만원), 한알탕수육(소 4만8천원, 대 7만원), 특선냉채(2만8천원), 셰프특선수프(3만8천원), '
#  '셰프스페셜송이특찜(15만원)\n'
#  'statusInfo_priceRange: 10~15만원대\n'
#  'statusInfo_openDate: 2007년\n'
#  'statusInfo_businessHours: 12:00~15:00/18:00~21:30(마지막 주문 20:00)\n'
#  'juso_detailAddress: 노보텔앰배서더강남서울 LL층\n'
#  'juso_roadAddrPart1: 서울특별시 강남구 봉은사로 130\n'
#  'juso_engAddr: 130 Bongeunsa-ro, Gangnam-gu, Seoul\n'
#  'juso_bdNm: 노보텔 앰배서더 강남 서울\n'
#  'juso_siNm: 서울특별시\n'
#  'juso_sggNm: 강남구\n'
#  'juso_emdNm: 역삼동\n'
#  'juso_liNm: \n'
#  'juso_rn: 동호로\n'
#  'juso_buldMnnm: 130\n'
#  'juso_buldSlno: 0\n'
#  'review_review: 국내 중식의 대가인 여경래 셰프가 2023년 이전하여 오픈한 중식 파인 다이닝 레스토랑. 고급스러운 분위기의 '
#  '인테리어에서 정통 중식을 맛볼 수 있다. 여경래 셰프의 시그니처 메뉴인 불도장, 모자새우 등을 선보인다.\n'
#  'review_reviewSimple: 국내 중식의 대가인 여경래 셰프가 2023년 이전하여 오픈한 중식 파인 다이닝 레스토랑. 고급스러운 '
#  '분위기의 인테리어에서 정통 중식을 맛볼 수 있다. 여경래 셰프의 시그니처 메뉴인 불도장, 모자새우 등을 선보인다.\n'
#  'review_readerAppraisal: \n'
#  'etcInfo_interior: \n'
#  'etcInfo_seat: 64\n'
#  'etcInfo_room: 6개(2, 3, 4, 6, 8, 12석)\n'
#  'etcInfo_head: \n'
#  'etcInfo_branch: \n'
#  'defaultInfo_website: https://www.instagram.com/hongbogak_official/')

# %% [markdown]
# ## 평가

# %%
import random
total_sampes = 5    # 추출할 샘플 개수
eval_context_list = []  # Sample들을 담을 리스트
while len(eval_context_list) < 5:
    _context = docs[random.randint(0, len(docs)-1)].page_content
    if len(_context) < 100: # 글자수가 너무 적으면 질문을 생성 못하기 때문에 글자수 체크
        continue
    eval_context_list.append(_context)

# %%
# Chain을 이용해서 LLM에게 질문-답 생성을 요청
from langchain.prompts import PromptTemplate
from langchain_core.output_parsers import JsonOutputParser
from pydantic import BaseModel, Field
from textwrap import dedent

# JSONOutputParser에서 사용할 스키마 생성
class EvaluationDatasetSchema(BaseModel):
    user_input:str=Field(...,description="질문(Question)")
    retrieved_contexts:list[str] = Field(...,description="LLM이 답변할 때 참조할 context")
    reference:str = Field(...,description="정답(ground truth)")

parser = JsonOutputParser(pydantic_object=EvaluationDatasetSchema)
# print(parser.get_format_instructions())

prompt_template = PromptTemplate.from_template(
    template=dedent("""
        당신은 RAG 평가를 위해 질문과 정답 쌍을 생성하는 인공지능 비서입니다.
        다음 [Context] 에 문서가 주어지면 해당 문서를 기반으로 {num_questions}개의 질문을 생성하세요. 
        
        질문과 정답을 생성한 후 아래의 출력 형식 GUIDE 에 맞게 생성합니다.
        질문은 반드시 [context] 문서에 있는 정보를 바탕으로 생성해야 합니다. [context]에 없는 내용을 가지고 질문-답변을 절대 만들면 안됩니다.
        질문은 간결하게 작성합니다.
        하나의 질문에는 한 가지씩만 내용만 작성합니다. 
        질문을 만들 때 "제공된 문맥에서", "문서에 설명된 대로", "주어진 문서에 따라" 또는 이와 유사한 말을 하지 마세요.
        정답은 반드시 [context]에 있는 정보를 바탕으로 작성합니다. 없는 내용을 추가하지 않습니다.
        질문과 답변을 만들고 그 내용이 [context] 에 있는 항목인지 다시 한번 확인합니다.
        생성된 질문-답변 쌍은 반드시 dictionary 형태로 정의하고 list로 묶어서 반환해야합니다.
        질문-답변 쌍은 반드시 {num_questions}개를 만들어주십시오.
                                
        출력 형식: {format_instructions}
                    
        [Context]
        {context}
        """
    ),
    partial_variables={"format_instructions":parser.get_format_instructions()}
)

model = ChatOpenAI(model='gpt-4o')
dataset_generator_chain = prompt_template | model | parser

# %%
c = eval_context_list[0]
qa = dataset_generator_chain.invoke({"context":c,"num_questions":5})

# %%
qa
# Out:
# [{'user_input': '호호닭발의 영업 시간은?',
#   'retrieved_contexts': ['defaultInfo_openHours: 15:00',
#    'defaultInfo_closeHours: 03:00',
#    'statusInfo_businessHours: 15:00~03:00(익일)'],
#   'reference': '호호닭발의 영업 시간은 오후 3시부터 다음 날 오전 3시까지입니다.'},
#  {'user_input': '호호닭발의 가격대는?',
#   'retrieved_contexts': ['statusInfo_priceRange: 1~2만원대'],
#   'reference': '호호닭발의 가격대는 1~2만원대입니다.'},
#  {'user_input': '호호닭발에서 주차가 가능한가요?',
#   'retrieved_contexts': ['statusInfo_parking: 불가'],
#   'reference': '호호닭발에서는 주차가 불가능합니다.'},
#  {'user_input': '호호닭발에서 인기 있는 메뉴는?',
#   'retrieved_contexts': ['statusInfo_menu: 뼈있는닭발(1만8천원), 뼈없는닭발(1만9천원), 국물닭발(뼈있는닭발 2만원, 뼈없는닭발 2만1천원), 오돌뼈(1만5천원)'],
#   'reference': '호호닭발에서는 뼈있는 닭발, 뼈없는 닭발, 국물 닭발 등이 인기 메뉴입니다.'},
#  {'user_input': '호호닭발에 어떻게 가나요?',
#   'retrieved_contexts': ['statusInfo_visit: 건대입구역 1번 출구 앞 골목으로 270m 직진'],
#   'reference': '호호닭발은 건대입구역 1번 출구 앞 골목으로 270m 직진하면 됩니다.'}]

# %%
# 확인 후 retrieved_contexts를 context로 변경
for d in qa:
    d['retrieved_contexts'] = c
qa
# Out:
# [{'user_input': '호호닭발의 영업 시간은?',
#   'retrieved_contexts': 'foodDetailTypes: 닭발\nheaderInfo_nameKR: 호호닭발\nheaderInfo_nameEN: \nheaderInfo_nameCN: \nheaderInfo_bookYear: \nheaderInfo_ribbonType: \ndefaultInfo_chefName: \ndefaultInfo_phone: 02-465-3455\ndefaultInfo_openHours: 15:00\ndefaultInfo_closeHours: 03:00\ndefaultInfo_openHoursWeekend: \ndefaultInfo_closeHoursWeekend: \ndefaultInfo_dayOff: 연중무휴\ndefaultInfo_app2Yn: False\nstatusInfo_parking: 불가\nstatusInfo_creditCard: \nstatusInfo_visit: 건대입구역 1번 출구 앞 골목으로 270m 직진\nstatusInfo_menu: 뼈있는닭발(1만8천원), 뼈없는닭발(1만9천원), 국물닭발(뼈있는닭발 2만원, 뼈없는닭발 2만1천원), 오돌뼈(1만5천원)\nstatusInfo_priceRange: 1~2만원대\nstatusInfo_openDate: \nstatusInfo_businessHours: 15:00~03:00(익일)\njuso_detailAddress: \njuso_roadAddrPart1: 서울특별시 광진구 동일로24길 96\njuso_engAddr: 96, Dongil-ro 24-gil, Gwangjin-gu, Seoul\njuso_bdNm: \njuso_siNm: 서울특별시\njuso_sggNm: 광진구\njuso_emdNm: 화양동\njuso_liNm: \njuso_rn: 동일로24길\njuso_buldMnnm: 96\njuso_buldSlno: 0\nreview_review: 닭발로 유명한 곳. 닭발은 매콤하며 쫄깃쫄깃하다. 닭발에 불 향이 배어있으며, 닭 특유의 냄새도 닭발에서 나지 않는다. 뼈있는닭발이 무뼈닭발보다 훨씬 매운 편.\nreview_reviewSimple: 닭발로 유명한 곳. 닭발은 매콤하며 쫄깃쫄깃하다. 닭발에 불 향이 배어있으며, 닭 특유의 냄새도 닭발에서 나지 않는다. 뼈있는닭발이 무뼈닭발보다 훨씬 매운 편.\nreview_readerAppraisal: \netcInfo_interior: \netcInfo_seat: \netcInfo_room: \netcInfo_head: \netcInfo_branch: \ndefaultInfo_website:',
#   'reference': '호호닭발의 영업 시간은 오후 3시부터 다음 날 오전 3시까지입니다.'},
#  {'user_input': '호호닭발의 가격대는?',
#   'retrieved_contexts': 'foodDetailTypes: 닭발\nheaderInfo_nameKR: 호호닭발\nheaderInfo_nameEN: \nheaderInfo_nameCN: \nheaderInfo_bookYear: \nheaderInfo_ribbonType: \ndefaultInfo_chefName: \ndefaultInfo_phone: 02-465-3455\ndefaultInfo_openHours: 15:00\ndefaultInfo_closeHours: 03:00\ndefaultInfo_openHoursWeekend: \ndefaultInfo_closeHoursWeekend: \ndefaultInfo_dayOff: 연중무휴\ndefaultInfo_app2Yn: False\nstatusInfo_parking: 불가\nstatusInfo_creditCard: \nstatusInfo_visit: 건대입구역 1번 출구 앞 골목으로 270m 직진\nstatusInfo_menu: 뼈있는닭발(1만8천원), 뼈없는닭발(1만9천원), 국물닭발(뼈있는닭발 2만원, 뼈없는닭발 2만1천원), 오돌뼈(1만5천원)\nstatusInfo_priceRange: 1~2만원대\nstatusInfo_openDate: \nstatusInfo_businessHours: 15:00~03:00(익일)\njuso_detailAddress: \njuso_roadAddrPart1: 서울특별시 광진구 동일로24길 96\njuso_engAddr: 96, Dongil-ro 24-gil, Gwangjin-gu, Seoul\njuso_bdNm: \njuso_siNm: 서울특별시\njuso_sggNm: 광진구\njuso_emdNm: 화양동\njuso_liNm: \njuso_rn: 동일로24길\njuso_buldMnnm: 96\njuso_buldSlno: 0\nreview_review: 닭발로 유명한 곳. 닭발은 매콤하며 쫄깃쫄깃하다. 닭발에 불 향이 배어있으며, 닭 특유의 냄새도 닭발에서 나지 않는다. 뼈있는닭발이 무뼈닭발보다 훨씬 매운 편.\nreview_reviewSimple: 닭발로 유명한 곳. 닭발은 매콤하며 쫄깃쫄깃하다. 닭발에 불 향이 배어있으며, 닭 특유의 냄새도 닭발에서 나지 않는다. 뼈있는닭발이 무뼈닭발보다 훨씬 매운 편.\nreview_readerAppraisal: \netcInfo_interior: \netcInfo_seat: \netcInfo_room: \netcInfo_head: \netcInfo_branch: \ndefaultInfo_website:',
#   'reference': '호호닭발의 가격대는 1~2만원대입니다.'},
#  {'user_input': '호호닭발에서 주차가 가능한가요?',
#   'retrieved_contexts': 'foodDetailTypes: 닭발\nheaderInfo_nameKR: 호호닭발\nheaderInfo_nameEN: \nheaderInfo_nameCN: \nheaderInfo_bookYear: \nheaderInfo_ribbonType: \ndefaultInfo_chefName: \ndefaultInfo_phone: 02-465-3455\ndefaultInfo_openHours: 15:00\ndefaultInfo_closeHours: 03:00\ndefaultInfo_openHoursWeekend: \ndefaultInfo_closeHoursWeekend: \ndefaultInfo_dayOff: 연중무휴\ndefaultInfo_app2Yn: False\nstatusInfo_parking: 불가\nstatusInfo_creditCard: \nstatusInfo_visit: 건대입구역 1번 출구 앞 골목으로 270m 직진\nstatusInfo_menu: 뼈있는닭발(1만8천원), 뼈없는닭발(1만9천원), 국물닭발(뼈있는닭발 2만원, 뼈없는닭발 2만1천원), 오돌뼈(1만5천원)\nstatusInfo_priceRange: 1~2만원대\nstatusInfo_openDate: \nstatusInfo_businessHours: 15:00~03:00(익일)\njuso_detailAddress: \njuso_roadAddrPart1: 서울특별시 광진구 동일로24길 96\njuso_engAddr: 96, Dongil-ro 24-gil, Gwangjin-gu, Seoul\njuso_bdNm: \njuso_siNm: 서울특별시\njuso_sggNm: 광진구\njuso_emdNm: 화양동\njuso_liNm: \njuso_rn: 동일로24길\njuso_buldMnnm: 96\njuso_buldSlno: 0\nreview_review: 닭발로 유명한 곳. 닭발은 매콤하며 쫄깃쫄깃하다. 닭발에 불 향이 배어있으며, 닭 특유의 냄새도 닭발에서 나지 않는다. 뼈있는닭발이 무뼈닭발보다 훨씬 매운 편.\nreview_reviewSimple: 닭발로 유명한 곳. 닭발은 매콤하며 쫄깃쫄깃하다. 닭발에 불 향이 배어있으며, 닭 특유의 냄새도 닭발에서 나지 않는다. 뼈있는닭발이 무뼈닭발보다 훨씬 매운 편.\nreview_readerAppraisal: \netcInfo_interior: \netcInfo_seat: \netcInfo_room: \netcInfo_head: \netcInfo_branch: \ndefaultInfo_website:',
#   'reference': '호호닭발에서는 주차가 불가능합니다.'},
#  {'user_input': '호호닭발에서 인기 있는 메뉴는?',
#   'retrieved_contexts': 'foodDetailTypes: 닭발\nheaderInfo_nameKR: 호호닭발\nheaderInfo_nameEN: \nheaderInfo_nameCN: \nheaderInfo_bookYear: \nheaderInfo_ribbonType: \ndefaultInfo_chefName: \ndefaultInfo_phone: 02-465-3455\ndefaultInfo_openHours: 15:00\ndefaultInfo_closeHours: 03:00\ndefaultInfo_openHoursWeekend: \ndefaultInfo_closeHoursWeekend: \ndefaultInfo_dayOff: 연중무휴\ndefaultInfo_app2Yn: False\nstatusInfo_parking: 불가\nstatusInfo_creditCard: \nstatusInfo_visit: 건대입구역 1번 출구 앞 골목으로 270m 직진\nstatusInfo_menu: 뼈있는닭발(1만8천원), 뼈없는닭발(1만9천원), 국물닭발(뼈있는닭발 2만원, 뼈없는닭발 2만1천원), 오돌뼈(1만5천원)\nstatusInfo_priceRange: 1~2만원대\nstatusInfo_openDate: \nstatusInfo_businessHours: 15:00~03:00(익일)\njuso_detailAddress: \njuso_roadAddrPart1: 서울특별시 광진구 동일로24길 96\njuso_engAddr: 96, Dongil-ro 24-gil, Gwangjin-gu, Seoul\njuso_bdNm: \njuso_siNm: 서울특별시\njuso_sggNm: 광진구\njuso_emdNm: 화양동\njuso_liNm: \njuso_rn: 동일로24길\njuso_buldMnnm: 96\njuso_buldSlno: 0\nreview_review: 닭발로 유명한 곳. 닭발은 매콤하며 쫄깃쫄깃하다. 닭발에 불 향이 배어있으며, 닭 특유의 냄새도 닭발에서 나지 않는다. 뼈있는닭발이 무뼈닭발보다 훨씬 매운 편.\nreview_reviewSimple: 닭발로 유명한 곳. 닭발은 매콤하며 쫄깃쫄깃하다. 닭발에 불 향이 배어있으며, 닭 특유의 냄새도 닭발에서 나지 않는다. 뼈있는닭발이 무뼈닭발보다 훨씬 매운 편.\nreview_readerAppraisal: \netcInfo_interior: \netcInfo_seat: \netcInfo_room: \netcInfo_head: \netcInfo_branch: \ndefaultInfo_website:',
#   'reference': '호호닭발에서는 뼈있는 닭발, 뼈없는 닭발, 국물 닭발 등이 인기 메뉴입니다.'},
#  {'user_input': '호호닭발에 어떻게 가나요?',
#   'retrieved_contexts': 'foodDetailTypes: 닭발\nheaderInfo_nameKR: 호호닭발\nheaderInfo_nameEN: \nheaderInfo_nameCN: \nheaderInfo_bookYear: \nheaderInfo_ribbonType: \ndefaultInfo_chefName: \ndefaultInfo_phone: 02-465-3455\ndefaultInfo_openHours: 15:00\ndefaultInfo_closeHours: 03:00\ndefaultInfo_openHoursWeekend: \ndefaultInfo_closeHoursWeekend: \ndefaultInfo_dayOff: 연중무휴\ndefaultInfo_app2Yn: False\nstatusInfo_parking: 불가\nstatusInfo_creditCard: \nstatusInfo_visit: 건대입구역 1번 출구 앞 골목으로 270m 직진\nstatusInfo_menu: 뼈있는닭발(1만8천원), 뼈없는닭발(1만9천원), 국물닭발(뼈있는닭발 2만원, 뼈없는닭발 2만1천원), 오돌뼈(1만5천원)\nstatusInfo_priceRange: 1~2만원대\nstatusInfo_openDate: \nstatusInfo_businessHours: 15:00~03:00(익일)\njuso_detailAddress: \njuso_roadAddrPart1: 서울특별시 광진구 동일로24길 96\njuso_engAddr: 96, Dongil-ro 24-gil, Gwangjin-gu, Seoul\njuso_bdNm: \njuso_siNm: 서울특별시\njuso_sggNm: 광진구\njuso_emdNm: 화양동\njuso_liNm: \njuso_rn: 동일로24길\njuso_buldMnnm: 96\njuso_buldSlno: 0\nreview_review: 닭발로 유명한 곳. 닭발은 매콤하며 쫄깃쫄깃하다. 닭발에 불 향이 배어있으며, 닭 특유의 냄새도 닭발에서 나지 않는다. 뼈있는닭발이 무뼈닭발보다 훨씬 매운 편.\nreview_reviewSimple: 닭발로 유명한 곳. 닭발은 매콤하며 쫄깃쫄깃하다. 닭발에 불 향이 배어있으며, 닭 특유의 냄새도 닭발에서 나지 않는다. 뼈있는닭발이 무뼈닭발보다 훨씬 매운 편.\nreview_readerAppraisal: \netcInfo_interior: \netcInfo_seat: \netcInfo_room: \netcInfo_head: \netcInfo_branch: \ndefaultInfo_website:',
#   'reference': '호호닭발은 건대입구역 1번 출구 앞 골목으로 270m 직진하면 됩니다.'}]

# %%
import pandas as pd
pd.DataFrame(qa)
# Out:
#           user_input                                 retrieved_contexts  \
# 0      호호닭발의 영업 시간은?  foodDetailTypes: 닭발\nheaderInfo_nameKR: 호호닭발\n...
# 1        호호닭발의 가격대는?  foodDetailTypes: 닭발\nheaderInfo_nameKR: 호호닭발\n...
# 2  호호닭발에서 주차가 가능한가요?  foodDetailTypes: 닭발\nheaderInfo_nameKR: 호호닭발\n...
# 3  호호닭발에서 인기 있는 메뉴는?  foodDetailTypes: 닭발\nheaderInfo_nameKR: 호호닭발\n...
# 4     호호닭발에 어떻게 가나요?  foodDetailTypes: 닭발\nheaderInfo_nameKR: 호호닭발\n...
#
#                                     reference
# 0       호호닭발의 영업 시간은 오후 3시부터 다음 날 오전 3시까지입니다.
# 1                       호호닭발의 가격대는 1~2만원대입니다.
# 2                         호호닭발에서는 주차가 불가능합니다.
# 3  호호닭발에서는 뼈있는 닭발, 뼈없는 닭발, 국물 닭발 등이 인기 메뉴입니다.
# 4     호호닭발은 건대입구역 1번 출구 앞 골목으로 270m 직진하면 됩니다.

# %%
### 전체 context sample들로 qa dataset을 생성
eval_data_list = []
num_questions = 5   # context당 k(5)개 QA 쌍 생성
for context in eval_context_list:
    _eval_data_list=dataset_generator_chain.invoke({"context":context,"num_questions":num_questions})
    # retrieve_contexts의 값을 변경
    for eval_data in _eval_data_list:
        eval_data['retrieved_contexts']=[context]
    eval_data_list.extend(_eval_data_list)

# %%
len(eval_data_list)
eval_data_list[:2]
# Out:
# [{'user_input': '호호닭발의 영업 시간은 언제인가요?',
#   'retrieved_contexts': ['foodDetailTypes: 닭발\nheaderInfo_nameKR: 호호닭발\nheaderInfo_nameEN: \nheaderInfo_nameCN: \nheaderInfo_bookYear: \nheaderInfo_ribbonType: \ndefaultInfo_chefName: \ndefaultInfo_phone: 02-465-3455\ndefaultInfo_openHours: 15:00\ndefaultInfo_closeHours: 03:00\ndefaultInfo_openHoursWeekend: \ndefaultInfo_closeHoursWeekend: \ndefaultInfo_dayOff: 연중무휴\ndefaultInfo_app2Yn: False\nstatusInfo_parking: 불가\nstatusInfo_creditCard: \nstatusInfo_visit: 건대입구역 1번 출구 앞 골목으로 270m 직진\nstatusInfo_menu: 뼈있는닭발(1만8천원), 뼈없는닭발(1만9천원), 국물닭발(뼈있는닭발 2만원, 뼈없는닭발 2만1천원), 오돌뼈(1만5천원)\nstatusInfo_priceRange: 1~2만원대\nstatusInfo_openDate: \nstatusInfo_businessHours: 15:00~03:00(익일)\njuso_detailAddress: \njuso_roadAddrPart1: 서울특별시 광진구 동일로24길 96\njuso_engAddr: 96, Dongil-ro 24-gil, Gwangjin-gu, Seoul\njuso_bdNm: \njuso_siNm: 서울특별시\njuso_sggNm: 광진구\njuso_emdNm: 화양동\njuso_liNm: \njuso_rn: 동일로24길\njuso_buldMnnm: 96\njuso_buldSlno: 0\nreview_review: 닭발로 유명한 곳. 닭발은 매콤하며 쫄깃쫄깃하다. 닭발에 불 향이 배어있으며, 닭 특유의 냄새도 닭발에서 나지 않는다. 뼈있는닭발이 무뼈닭발보다 훨씬 매운 편.\nreview_reviewSimple: 닭발로 유명한 곳. 닭발은 매콤하며 쫄깃쫄깃하다. 닭발에 불 향이 배어있으며, 닭 특유의 냄새도 닭발에서 나지 않는다. 뼈있는닭발이 무뼈닭발보다 훨씬 매운 편.\nreview_readerAppraisal: \netcInfo_interior: \netcInfo_seat: \netcInfo_room: \netcInfo_head: \netcInfo_branch: \ndefaultInfo_website:'],
#   'reference': '호호닭발의 영업 시간은 오후 3시부터 다음 날 새벽 3시까지입니다.'},
#  {'user_input': '호호닭발의 위치는 어디인가요?',
#   'retrieved_contexts': ['foodDetailTypes: 닭발\nheaderInfo_nameKR: 호호닭발\nheaderInfo_nameEN: \nheaderInfo_nameCN: \nheaderInfo_bookYear: \nheaderInfo_ribbonType: \ndefaultInfo_chefName: \ndefaultInfo_phone: 02-465-3455\ndefaultInfo_openHours: 15:00\ndefaultInfo_closeHours: 03:00\ndefaultInfo_openHoursWeekend: \ndefaultInfo_closeHoursWeekend: \ndefaultInfo_dayOff: 연중무휴\ndefaultInfo_app2Yn: False\nstatusInfo_parking: 불가\nstatusInfo_creditCard: \nstatusInfo_visit: 건대입구역 1번 출구 앞 골목으로 270m 직진\nstatusInfo_menu: 뼈있는닭발(1만8천원), 뼈없는닭발(1만9천원), 국물닭발(뼈있는닭발 2만원, 뼈없는닭발 2만1천원), 오돌뼈(1만5천원)\nstatusInfo_priceRange: 1~2만원대\nstatusInfo_openDate: \nstatusInfo_businessHours: 15:00~03:00(익일)\njuso_detailAddress: \njuso_roadAddrPart1: 서울특별시 광진구 동일로24길 96\njuso_engAddr: 96, Dongil-ro 24-gil, Gwangjin-gu, Seoul\njuso_bdNm: \njuso_siNm: 서울특별시\njuso_sggNm: 광진구\njuso_emdNm: 화양동\njuso_liNm: \njuso_rn: 동일로24길\njuso_buldMnnm: 96\njuso_buldSlno: 0\nreview_review: 닭발로 유명한 곳. 닭발은 매콤하며 쫄깃쫄깃하다. 닭발에 불 향이 배어있으며, 닭 특유의 냄새도 닭발에서 나지 않는다. 뼈있는닭발이 무뼈닭발보다 훨씬 매운 편.\nreview_reviewSimple: 닭발로 유명한 곳. 닭발은 매콤하며 쫄깃쫄깃하다. 닭발에 불 향이 배어있으며, 닭 특유의 냄새도 닭발에서 나지 않는다. 뼈있는닭발이 무뼈닭발보다 훨씬 매운 편.\nreview_readerAppraisal: \netcInfo_interior: \netcInfo_seat: \netcInfo_room: \netcInfo_head: \netcInfo_branch: \ndefaultInfo_website:'],
#   'reference': '호호닭발은 서울특별시 광진구 동일로24길 96에 위치해 있으며, 건대입구역 1번 출구 앞 골목으로 270미터 직진하면 됩니다.'}]

# %%
eval_df = pd.DataFrame(eval_data_list)
eval_df.shape
# Out:
# (25, 3)

# %%
eval_df.head()
eval_df.tail()
# Out:
#               user_input                                 retrieved_contexts  \
# 20    삼송빵집의 영업시간은 언제인가요?  [foodDetailTypes: 베이커리\nheaderInfo_nameKR: 삼송빵...
# 21   삼송빵집의 인기 메뉴는 무엇인가요?  [foodDetailTypes: 베이커리\nheaderInfo_nameKR: 삼송빵...
# 22      삼송빵집의 위치는 어디인가요?  [foodDetailTypes: 베이커리\nheaderInfo_nameKR: 삼송빵...
# 23      삼송빵집의 주차 가능 여부는?  [foodDetailTypes: 베이커리\nheaderInfo_nameKR: 삼송빵...
# 24  삼송빵집의 명절 휴무일은 언제인가요?  [foodDetailTypes: 베이커리\nheaderInfo_nameKR: 삼송빵...
#
#                                             reference
# 20  삼송빵집의 영업시간은 오전 8시부터 오후 10시까지입니다. 재료가 소진되면 영업을 ...
# 21                      삼송빵집의 인기 메뉴는 통옥수수빵과 구운고로케입니다.
# 22                 삼송빵집은 대구광역시 중구 중앙대로 397에 위치해 있습니다.
# 23                                  삼송빵집은 주차가 불가능합니다.
# 24                                삼송빵집은 명절 당일에 휴무입니다.

# %%
eval_df['user_input']
# Out:
# 0         호호닭발의 영업 시간은 언제인가요?
# 1            호호닭발의 위치는 어디인가요?
# 2         호호닭발의 대표 메뉴는 무엇인가요?
# 3           호호닭발에서 주차가 가능한가요?
# 4          호호닭발의 전화번호는 무엇인가요?
# 5      모멘토스는 어떤 음식을 전문으로 하나요?
# 6          모멘토스의 전화번호는 무엇인가요?
# 7           모멘토스에서 주차가 가능한가요?
# 8         모멘토스의 추천 메뉴는 무엇인가요?
# 9            모멘토스의 주소는 어디인가요?
# 10       신림춘천집의 인기 메뉴는 무엇인가요?
# 11          신림춘천집의 주차 가능 여부는?
# 12     신림춘천집의 운영 시간은 어떻게 되나요?
# 13          신림춘천집의 주소는 어디인가요?
# 14         신림춘천집의 휴무일은 언제인가요?
# 15         진사향의 셰프 이름은 무엇인가요?
# 16    진사향의 주말 영업 시간은 어떻게 되나요?
# 17       진사향의 대표적인 메뉴는 무엇인가요?
# 18       진사향은 어느 호텔에 위치해 있나요?
# 19       진사향의 시그니처 메뉴는 무엇인가요?
# 20         삼송빵집의 영업시간은 언제인가요?
# 21        삼송빵집의 인기 메뉴는 무엇인가요?
# 22           삼송빵집의 위치는 어디인가요?
# 23           삼송빵집의 주차 가능 여부는?
# 24       삼송빵집의 명절 휴무일은 언제인가요?
# Name: user_input, dtype: object

# %%
from langchain_community.document_loaders import TextLoader
from langchain.text_splitter import RecursiveCharacterTextSplitter
from langchain_openai import OpenAIEmbeddings, ChatOpenAI
from langchain_chroma import Chroma
from langchain.prompts import ChatPromptTemplate, ChatMessagePromptTemplate, MessagesPlaceholder
from langchain_core.runnables import RunnablePassthrough, RunnableWithMessageHistory
from langchain_community.tools import TavilySearchResults
from langchain_core.documents import Document

# 평가 알로리즘 모듈
from langchain_core.output_parsers import JsonOutputParser,StrOutputParser
from langchain import hub
from langchain_core.runnables import RunnablePassthrough, RunnableLambda

from ragas import EvaluationDataset, RunConfig, evaluate
from ragas.metrics import LLMContextRecall, Faithfulness, LLMContextPrecisionWithReference, AnswerRelevancy

from ragas.llms import LangchainLLMWrapper
from ragas.embeddings import LangchainEmbeddingsWrapper

from pydantic import BaseModel, Field


# 메모리 관련 모듈
from langchain_core.chat_history import InMemoryChatMessageHistory

from langchain.chains import RetrievalQA
from langchain.schema import AIMessage, HumanMessage




from textwrap import dedent
from operator import itemgetter

from dotenv import load_dotenv
load_dotenv()

# %%
print(len(context_list), len(response_list))
# pprint(context_list[:2])
# pprint(response_list[:2])

# %%
response_list

# %%
eval_df["retrieved_contexts"] = context_list # context 추가
eval_df["response"] = response_list   # 정답 추가

# %%
# Dataframe으로 부터 EvalDataset 생성
eval_dataset = EvaluationDataset.from_pandas(eval_df)
eval_dataset

# %%
# HuggingFace에 업로드 -> dataets.Dataset으로 변환
eval_dataset.to_hf_dataset()#.push_to_hub()

# %%
# model_name = "gpt-4o"
model_name = "gpt-4o-mini"
model = ChatOpenAI(model=model_name)
eval_llm = LangchainLLMWrapper(model)

embedding_model = OpenAIEmbeddings(model="text-embedding-3-small")
eval_embedding = LangchainEmbeddingsWrapper(embedding_model)


## GPT-4o-mini 모델을 사용하여 평가 
metrics = [
    LLMContextRecall(llm=eval_llm),
    LLMContextPrecisionWithReference(llm=eval_llm),
    Faithfulness(llm=eval_llm),
    AnswerRelevancy(llm=eval_llm, embeddings=eval_embedding)
]
result = evaluate(dataset=eval_dataset, metrics=metrics)

# %%
result

# %%
# gpt-4o : 분당 토큰 리미트에 걸려 RateLimitError 가 발생할 수있다. gpt-40: 30,000 TPM, gpt-4o-mini: 200,000 TPM
# 또한 network 연결등 문제가 발생하면 timeout 이 되어 평가가 실패할 수 있다.
# LLM 연결과 관련해 timetout이나 ratelimiterror 발생시 metrics를 나눠서 실행, 설정 변경을 통해 해결한다.
## https://platform.openai.com/settings/organization/limits
run_config = RunConfig(
    timeout=360,     # LLM 호출 이후 최대 대기 시간. 지정한 초까지 응답을 기다린다. 
    max_retries=20, # API 호출시 지정한 횟수만큼 재시도 한다.
    max_wait=360,   # 재시도 대기 시간(초) 180초 기다린 후 재시도 한다.
    max_workers=1   # 병렬처리 worker 수. 1로 설정하면 순차적으로 처리한다. (default: 16)
)
metrics1 = [
    LLMContextRecall(llm=eval_llm),
]
metrics2 = [
    LLMContextPrecisionWithReference(llm=eval_llm),
]
metrics3 = [
    Faithfulness(llm=eval_llm),
]
metrics4 = [
    AnswerRelevancy(llm=eval_llm, embeddings=eval_embedding)
]

# %%
result1 = evaluate(dataset=eval_dataset, metrics=metrics1, run_config=run_config)
result1

# %%
result2 = evaluate(dataset=eval_dataset, metrics=metrics2, run_config=run_config)
result2

# %%
result3 = evaluate(dataset=eval_dataset, metrics=metrics3, run_config=run_config)
result3

# %%
result4 = evaluate(dataset=eval_dataset, metrics=metrics4, run_config=run_config)
result4
