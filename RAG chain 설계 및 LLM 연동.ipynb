# %% [markdown]
# # 1. RAG chain 구현 구문

# %%
# RAG chain 설계 및 LLM 연동을 위한 모듈
from langchain_community.document_loaders import TextLoader
from langchain.text_splitter import RecursiveCharacterTextSplitter
from langchain_openai import OpenAIEmbeddings, ChatOpenAI
from langchain_chroma import Chroma
from langchain.prompts import ChatPromptTemplate, ChatMessagePromptTemplate, MessagesPlaceholder
from langchain_core.runnables import RunnablePassthrough, RunnableWithMessageHistory
from langchain_community.tools import TavilySearchResults

# 평가 알로리즘 모듈
from langchain_core.output_parsers import JsonOutputParser,StrOutputParser
from langchain import hub
from langchain_core.runnables import RunnablePassthrough, RunnableLambda

from ragas import EvaluationDataset, RunConfig, evaluate
from ragas.metrics import LLMContextRecall, Faithfulness, LLMContextPrecisionWithReference, AnswerRelevancy

from ragas.llms import LangchainLLMWrapper
from ragas.embeddings import LangchainEmbeddingsWrapper

from pydantic import BaseModel, Field


# 메모리 관련 모듈
from langchain_core.chat_history import InMemoryChatMessageHistory



from textwrap import dedent
from operator import itemgetter
from pprint import pprint
import random
from dotenv import load_dotenv
load_dotenv()


# config
COLLECTION_NAME = "bluer_db_openai"
PERSIST_DIRECTORY = "vector_store/chroma/bluer_db"
EMBEDDING_MODEL_NAME = "text-embedding-3-small"
EMBEDDING_MODEL = OpenAIEmbeddings(model=EMBEDDING_MODEL_NAME)

# %%
########################################################
# vector_db에서 데이터 불러오기
########################################################

# vector store 연결
vector_store = Chroma(
    embedding_function=EMBEDDING_MODEL,
    collection_name=COLLECTION_NAME,
    persist_directory=PERSIST_DIRECTORY
)

# 저장된 데이터 내용 확인
documents = vector_store._collection.get()['documents']
metadatas = vector_store._collection.get()['metadatas']

print(f"Documents: {documents[:5]}") 
print(f"Metadatas: {metadatas[:5]}")
# Out:
# Documents: ['foodDetailTypes: 스시\nheaderInfo_nameKR: 스시조\nheaderInfo_nameEN: Sushi Cho\nheaderInfo_nameCN: \nheaderInfo_bookYear: 2025\nheaderInfo_ribbonType: 3\ndefaultInfo_chefName: \ndefaultInfo_phone: 02-317-0373\ndefaultInfo_openHours: \ndefaultInfo_closeHours: \ndefaultInfo_openHoursWeekend: \ndefaultInfo_closeHoursWeekend: \ndefaultInfo_dayOff: 연중무휴\ndefaultInfo_app2Yn: False\nstatusInfo_parking: 가능\nstatusInfo_creditCard: y\nstatusInfo_visit: 웨스틴조선호텔 20층\nstatusInfo_menu: 런치(Hall)(1인 15만5천원~20만5천원), 디너(Hall)(1인 19만4천원~33만원), 스시조회덮밥(10만원, 프리미엄 13만원), 복가라아게돌솥밥(12만원), 굴돌솥밥(7만8천원), 활새우튀김(11만원), 조리장특선모둠스시(14만5천원)\nstatusInfo_priceRange: 25만원 이상\nstatusInfo_openDate: 2008년\nstatusInfo_businessHours: 12:00~15:00/17:30~22:00(마지막 주문 21:30)\njuso_detailAddress: 웨스틴조선호텔 20층\njuso_roadAddrPart1: 서울특별시 중구 소공로 106\njuso_engAddr: 106, Sogong-ro, Jung-gu, Seoul\njuso_bdNm: 서울 웨스틴조선호텔\njuso_siNm: 서울특별시\njuso_sggNm: 중구\njuso_emdNm: 소공동\njuso_liNm: \njuso_rn: 소공로\njuso_buldMnnm: 106\njuso_buldSlno: 0\nreview_review: 서울 최고의 일식당 중 하나로 꼽히는 곳. 최상의 재료를 사용한 최고급 일본 요리를 맛볼 수 있다. 국내 최대 길이를 자랑하는 히노키 다이에서 맛보는 스시가 특히 인기가 높다. 신라호텔의 아리아께와 함께 우리나라 스시의 양대산맥을 이루고 있다. 최근에는 일본의 요시타케와 기술제휴로 적초샤리와 부드럽게 숙성된 네타를 사용하는 등 독특한 스타일을 선보이고 있다.\nreview_reviewSimple: 서울 최고의 일식당 중 하나로 꼽히는 곳. 최상의 재료를 사용한 최고급 일본 요리를 맛볼 수 있다. 국내 최대 길이를 자랑하는 히노키 다이에서 맛보는 스시가 특히 인기가 높다. 신라호텔의 아리아께와 함께 우리나라 스시의 양대산맥을 이루고 있다.\nreview_readerAppraisal: “단품 중에는 의외로 맛있는 고등어소바가 특미.” “신선한 1등급 제철 재료를 사용하는 스시조. 평생 잊지 못할 맛을 맛본 것 같습니다.” “최고급 호텔 내의 스시야인 만큼, 재료의 질과 다양성에서부터 큰 강점이 있음. 거기에 기본기도 탄탄하지만 여러 가지 변주도 가능한 손맛과 최고급 호텔다운 서비스까지 갖춤.” “가장 높은 층에 자리한 만큼 좋은 경치와 분위기를 자랑한다.” “스시집 중 최상의 맛과 서비스를 느낄 수 있다.” “중요한 접대가 필요한 비즈니스나 기념일에 스시가 생각난다면 한 번쯤 도전해볼 만한 최고급 식당.” “이런 집에서 맛을 논하면 바보거나 맛의 고수다.” “언제 가더라도 그 가격이 비싸지 않다는 것을 느끼게 해주는 최고의 스시집입니다.”\netcInfo_interior: 모던/스타일리시\netcInfo_seat: 97석, 스시카운터 9석\netcInfo_room: 8개(4~5석, 다다미방 2개, 8~14석), 별실 이용시 룸차지 3만원\netcInfo_head: \netcInfo_branch: \ndefaultInfo_website:', "foodDetailTypes: 프랑스식\nheaderInfo_nameKR: 레스쁘아\nheaderInfo_nameEN: L'Espoir du Hibou\nheaderInfo_nameCN: \nheaderInfo_bookYear: 2025\nheaderInfo_ribbonType: 3\ndefaultInfo_chefName: 임기학\ndefaultInfo_phone: 02-517-6034\ndefaultInfo_openHours: \ndefaultInfo_closeHours: \ndefaultInfo_openHoursWeekend: \ndefaultInfo_closeHoursWeekend: \ndefaultInfo_dayOff: 화요일, 명절 휴무\ndefaultInfo_app2Yn: False\nstatusInfo_parking: 발레 파킹\nstatusInfo_creditCard: y\nstatusInfo_visit: \nstatusInfo_menu: 런치코스(10만원), 클래식코스(18만원), 시즌코스(20만원)\nstatusInfo_priceRange: 15~25만원대\nstatusInfo_openDate: 2008년\nstatusInfo_businessHours: 12:00~15:00/17:30~22:00\njuso_detailAddress: \njuso_roadAddrPart1: 서울특별시 강남구 도산대로59길 16\njuso_engAddr: 16 Dosan-daero 59-gil, Gangnam-gu, Seoul\njuso_bdNm: \njuso_siNm: 서울특별시\njuso_sggNm: 강남구\njuso_emdNm: 청담동\njuso_liNm: \njuso_rn: 선릉로152길\njuso_buldMnnm: 16\njuso_buldSlno: 0\nreview_review: 비스트로를 표방하는 클래식 프렌치 레스토랑. 정통 프렌치 레시피를 기반으로 한국인의 입맛에 맞추어 내는 임기학 셰프의 노련한 솜씨를 맛볼 수 있다. 10종이 넘는 테린과 파테가 나오는 모둠샤퀴테리는 코스를 시작하기 전에 와인과 함께 즐기면 좋다. 코스 외에도 단품 메뉴가 많이 준비되어 있다. 봄과 가을에는 테라스 좌석의 분위기가 끝내준다.\nreview_reviewSimple: 비스트로를 표방하는 클래식 프렌치 레스토랑. 정통 프렌치 레시피를 기반으로 한국인의 입맛에 맞추어 내는 임기학 셰프의 노련한 솜씨를 맛볼 수 있다. 10종이 넘는 테린과 파테가 나오는 모둠샤퀴테리는 코스를 시작하기 전에 와인과 함께 즐기면 좋다. 코스 외에도 단품 메뉴가 많이 준비되어 있다. 봄과 가을에는 테라스 좌석의 분위기가 끝내준다.\nreview_readerAppraisal: “명실상부 최고의 비스트로.” “전채요리 하나하나에 빠짐이 없다.” “정말 맛있는 프렌치 요리를 즐기고 싶다면 반드시 가봐야 할 곳.” “요리 하나하나 힘이 있습니다. 빈틈없는 훌륭한 곳입니다. 서울에서 손꼽을 프렌치 레스토랑입니다.” “절정에 이르렀다는 표현이 이해가 되는 레스토랑. 맛도 맛이지만 다른 곳에 비해 양이 많다는 점도 가격 대비 만족도가 높은 이유.” “기본적인 어니언 수프가 참 맛있었습니다.” “가격 대비 이 정도의 프렌치를 가볍게 즐길 수 있는 곳은 많지 않다.” “재료 본연의 맛을 제대로 느끼게 해주었던, 다시 가고 싶게 만든 프렌치 비스트로.” “가격도 맛도 사로잡는 최고의 프렌치 비스트로다.” “아주 좋다.”\netcInfo_interior: \netcInfo_seat: 40\netcInfo_room: \netcInfo_head: \netcInfo_branch: \ndefaultInfo_website: https://www.instagram.com/lespoirduhibou/", 'foodDetailTypes: 소갈비, 소고기구이\nheaderInfo_nameKR: 낙원\nheaderInfo_nameEN: \nheaderInfo_nameCN: 樂源\nheaderInfo_bookYear: 2025\nheaderInfo_ribbonType: 3\ndefaultInfo_chefName: \ndefaultInfo_phone: 02-2660-9010\ ...
# Metadatas: [{'row': 0, 'source': 'data/cleaned_restaurants.csv'}, {'row': 1, 'source': 'data/cleaned_restaurants.csv'}, {'row': 2, 'source': 'data/cleaned_restaurants.csv'}, {'row': 3, 'source': 'data/cleaned_restaurants.csv'}, {'row': 4, 'source': 'data/cleaned_restaurants.csv'}]

# %%
# 데이터 로드 및 전처리
data = pd.read_csv(csv_path)
data.fillna("", inplace=True)  # NaN 값 처리

# 모든 데이터를 활용하도록 문서화
documents = []
for i, row in data.iterrows():
    # 텍스트 내용 (각 행 전체를 하나의 문서로 취급)
    page_content = "\n".join([f"{col}: {val}" for col, val in row.items()])
    
    # 메타데이터 생성 (필요 시 주요 컬럼만 선택 가능)
    metadata = row.to_dict()
    
    # Document 생성
    doc = Document(page_content=page_content, metadata=metadata)
    documents.append(doc)

print(f"총 {len(documents)}개의 문서가 생성되었습니다.")

# %%
from pprint import pprint 
pprint(documents)
# Out:
# ['foodDetailTypes: 스시\n'
#  'headerInfo_nameKR: 스시조\n'
#  'headerInfo_nameEN: Sushi Cho\n'
#  'headerInfo_nameCN: \n'
#  'headerInfo_bookYear: 2025\n'
#  'headerInfo_ribbonType: 3\n'
#  'defaultInfo_chefName: \n'
#  'defaultInfo_phone: 02-317-0373\n'
#  'defaultInfo_openHours: \n'
#  'defaultInfo_closeHours: \n'
#  'defaultInfo_openHoursWeekend: \n'
#  'defaultInfo_closeHoursWeekend: \n'
#  'defaultInfo_dayOff: 연중무휴\n'
#  'defaultInfo_app2Yn: False\n'
#  'statusInfo_parking: 가능\n'
#  'statusInfo_creditCard: y\n'
#  'statusInfo_visit: 웨스틴조선호텔 20층\n'
#  'statusInfo_menu: 런치(Hall)(1인 15만5천원~20만5천원), 디너(Hall)(1인 19만4천원~33만원), '
#  '스시조회덮밥(10만원, 프리미엄 13만원), 복가라아게돌솥밥(12만원), 굴돌솥밥(7만8천원), 활새우튀김(11만원), '
#  '조리장특선모둠스시(14만5천원)\n'
#  'statusInfo_priceRange: 25만원 이상\n'
#  'statusInfo_openDate: 2008년\n'
#  'statusInfo_businessHours: 12:00~15:00/17:30~22:00(마지막 주문 21:30)\n'
#  'juso_detailAddress: 웨스틴조선호텔 20층\n'
#  'juso_roadAddrPart1: 서울특별시 중구 소공로 106\n'
#  'juso_engAddr: 106, Sogong-ro, Jung-gu, Seoul\n'
#  'juso_bdNm: 서울 웨스틴조선호텔\n'
#  'juso_siNm: 서울특별시\n'
#  'juso_sggNm: 중구\n'
#  'juso_emdNm: 소공동\n'
#  'juso_liNm: \n'
#  'juso_rn: 소공로\n'
#  'juso_buldMnnm: 106\n'
#  'juso_buldSlno: 0\n'
#  'review_review: 서울 최고의 일식당 중 하나로 꼽히는 곳. 최상의 재료를 사용한 최고급 일본 요리를 맛볼 수 있다. 국내 최대 '
#  '길이를 자랑하는 히노키 다이에서 맛보는 스시가 특히 인기가 높다. 신라호텔의 아리아께와 함께 우리나라 스시의 양대산맥을 이루고 있다. '
#  '최근에는 일본의 요시타케와 기술제휴로 적초샤리와 부드럽게 숙성된 네타를 사용하는 등 독특한 스타일을 선보이고 있다.\n'
#  'review_reviewSimple: 서울 최고의 일식당 중 하나로 꼽히는 곳. 최상의 재료를 사용한 최고급 일본 요리를 맛볼 수 있다. '
#  '국내 최대 길이를 자랑하는 히노키 다이에서 맛보는 스시가 특히 인기가 높다. 신라호텔의 아리아께와 함께 우리나라 스시의 양대산맥을 이루고 '
#  '있다.\n'
#  'review_readerAppraisal: “단품 중에는 의외로 맛있는 고등어소바가 특미.” “신선한 1등급 제철 재료를 사용하는 '
#  '스시조. 평생 잊지 못할 맛을 맛본 것 같습니다.” “최고급 호텔 내의 스시야인 만큼, 재료의 질과 다양성에서부터 큰 강점이 있음. '
#  '거기에 기본기도 탄탄하지만 여러 가지 변주도 가능한 손맛과 최고급 호텔다운 서비스까지 갖춤.” “가장 높은 층에 자리한 만큼 좋은 경치와 '
#  '분위기를 자랑한다.” “스시집 중 최상의 맛과 서비스를 느낄 수 있다.” “중요한 접대가 필요한 비즈니스나 기념일에 스시가 생각난다면 한 '
#  '번쯤 도전해볼 만한 최고급 식당.” “이런 집에서 맛을 논하면 바보거나 맛의 고수다.” “언제 가더라도 그 가격이 비싸지 않다는 것을 '
#  '느끼게 해주는 최고의 스시집입니다.”\n'
#  'etcInfo_interior: 모던/스타일리시\n'
#  'etcInfo_seat: 97석, 스시카운터 9석\n'
#  'etcInfo_room: 8개(4~5석, 다다미방 2개, 8~14석), 별실 이용시 룸차지 3만원\n'
#  'etcInfo_head: \n'
#  'etcInfo_branch: \n'
#  'defaultInfo_website:',
#  'foodDetailTypes: 프랑스식\n'
#  'headerInfo_nameKR: 레스쁘아\n'
#  "headerInfo_nameEN: L'Espoir du Hibou\n"
#  'headerInfo_nameCN: \n'
#  'headerInfo_bookYear: 2025\n'
#  'headerInfo_ribbonType: 3\n'
#  'defaultInfo_chefName: 임기학\n'
#  'defaultInfo_phone: 02-517-6034\n'
#  'defaultInfo_openHours: \n'
#  'defaultInfo_closeHours: \n'
#  'defaultInfo_openHoursWeekend: \n'
#  'defaultInfo_closeHoursWeekend: \n'
#  'defaultInfo_dayOff: 화요일, 명절 휴무\n'
#  'defaultInfo_app2Yn: False\n'
#  'statusInfo_parking: 발레 파킹\n'
#  'statusInfo_creditCard: y\n'
#  'statusInfo_visit: \n'
#  'statusInfo_menu: 런치코스(10만원), 클래식코스(18만원), 시즌코스(20만원)\n'
#  'statusInfo_priceRange: 15~25만원대\n'
#  'statusInfo_openDate: 2008년\n'
#  'statusInfo_businessHours: 12:00~15:00/17:30~22:00\n'
#  'juso_detailAddress: \n'
#  'juso_roadAddrPart1: 서울특별시 강남구 도산대로59길 16\n'
#  'juso_engAddr: 16 Dosan-daero 59-gil, Gangnam-gu, Seoul\n'
#  'juso_bdNm: \n'
#  'juso_siNm: 서울특별시\n'
#  'juso_sggNm: 강남구\n'
#  'juso_emdNm: 청담동\n'
#  'juso_liNm: \n'
#  'juso_rn: 선릉로152길\n'
#  'juso_buldMnnm: 16\n'
#  'juso_buldSlno: 0\n'
#  'review_review: 비스트로를 표방하는 클래식 프렌치 레스토랑. 정통 프렌치 레시피를 기반으로 한국인의 입맛에 맞추어 내는 임기학 '
#  '셰프의 노련한 솜씨를 맛볼 수 있다. 10종이 넘는 테린과 파테가 나오는 모둠샤퀴테리는 코스를 시작하기 전에 와인과 함께 즐기면 좋다. '
#  '코스 외에도 단품 메뉴가 많이 준비되어 있다. 봄과 가을에는 테라스 좌석의 분위기가 끝내준다.\n'
#  'review_reviewSimple: 비스트로를 표방하는 클래식 프렌치 레스토랑. 정통 프렌치 레시피를 기반으로 한국인의 입맛에 맞추어 '
#  '내는 임기학 셰프의 노련한 솜씨를 맛볼 수 있다. 10종이 넘는 테린과 파테가 나오는 모둠샤퀴테리는 코스를 시작하기 전에 와인과 함께 '
#  '즐기면 좋다. 코스 외에도 단품 메뉴가 많이 준비되어 있다. 봄과 가을에는 테라스 좌석의 분위기가 끝내준다.\n'
#  'review_readerAppraisal: “명실상부 최고의 비스트로.” “전채요리 하나하나에 빠짐이 없다.” “정말 맛있는 프렌치 '
#  '요리를 즐기고 싶다면 반드시 가봐야 할 곳.” “요리 하나하나 힘이 있습니다. 빈틈없는 훌륭한 곳입니다. 서울에서 손꼽을 프렌치 '
#  '레스토랑입니다.” “절정에 이르렀다는 표현이 이해가 되는 레스토랑. 맛도 맛이지만 다른 곳에 비해 양이 많다는 점도 가격 대비 만족도가 '
#  '높은 이유.” “기본적인 어니언 수프가 참 맛있었습니다.” “가격 대비 이 정도의 프렌치를 가볍게 즐길 수 있는 곳은 많지 않다.” '
#  '“재료 본연의 맛을 제대로 느끼게 해주었던, 다시 가고 싶게 만든 프렌치 비스트로.” “가격도 맛도 사로잡는 최고의 프렌치 비스트로다.” '
#  '“아주 좋다.”\n'
#  'etcInfo_interior: \n'
#  'etcInfo_seat: 40\n'
#  'etcInfo_room: \n'
#  'etcInfo_head: \n'
#  'etcInfo_branch: \n'
#  'defaultInfo_website: https://www.instagram.com/lespoirduhibou/',
#  'foodDetailTypes: 소갈비, 소고기구이\n'
#  'headerInfo_nameKR: 낙원\n'
#  'headerInfo_nameEN: \n'
#  'headerInfo_nameCN: 樂源\n'
#  'headerInfo_bookYear: 2025\n'
#  'headerInfo_ribbonType: 3\n'
#  'defaultInfo_chefName: \n'
#  'defaultInfo_phone: 02-2660-9010\n'
#  'defaultInfo_openHours: \n'
#  'defaultInfo_closeHours: \n'
#  'defaultInfo_openHoursWeekend: \n'
#  'defaultInfo_closeHoursWeekend: \n'
#  'defaultInfo_dayOff: 연중무휴\n'
#  'defaultInfo_app2Yn: True\n'
#  'statusInfo_parking: 가능\n'
#  'statusInfo_creditCard: y\n'
#  'statusInfo_visit: 메이필드호텔 1층\n'
#  'statusInfo_menu: 특생대대갈비, 특양념대갈비(각 270g 15만원), 한우꽃등심(130g 9만5천원), '
#  '한우등심불고기(200g 5만5천원), 한우양념갈비구이정식(200g 11만원), 낙지볶음(5만원), 해물파전(3만5천원)\n'
#  'statusInfo_priceRange: 15~25만원대\n'
#  'statusInfo_openDate: 1983년\n'
#  'statusInfo_businessHours: 11:30~14:30(마지막 주문 13:30)/17:30~21:30(마지막 주문 '
#  '20:30)\n'
#  'juso_detailAddress: 메이필드호텔 1층\n'
#  'juso_roadAddrPart1: 서울특별시 강서구 방화대로 94\n'
#  'juso_engAddr: 94, Banghwa-daero, Gangseo-gu, Seoul\n'
#  'juso_bdNm: 메이필드호텔\n'
#  'juso_siNm: 서울특별시\n'
#  'juso_sggNm: 강서구\n'
#  'juso_emdNm: 외발산동\n'
#  'juso_liNm: \n'
#  'juso_rn: 방화대로\n'
#  'juso_buldMnnm: 94\n'
#  'juso_buldSlno: 0\n'
#  'review_review: 갈비를 비롯한 한우구이를 전문으로 하고 있으며 가격대가 높은 만큼 품격 있는 분위기와 서비스를 즐길 수 있다. '
#  '재료 본연의 맛을 살린 음식의 맛이 좋다. 룸이 여러 개 있어 비즈니스 미팅에도 좋다. 낙원 안쪽에는 한정식집 봉래헌이 있다.\n'
#  'review_reviewSimple: 갈비를 비롯한 한우구이를 전문으로 하고 있으며 가격대가 높은 만큼 품격 있는 분위기와 서비스를 즐길 '
#  '수 있다. 재료 본연의 맛을 살린 음식의 맛이 좋다. 룸이 여러 개 있어 비즈니스 미팅에도 좋다. 낙원 안쪽에는 한정식집 봉래헌이 '
#  '있다.\n'
#  'review_readerAppraisal: “분위기가 좋고 특별한 날에 가기 좋다.” “먹을 만한 한식집. 맛도 맛이지만 널찍한 정원 '
#  '안에서 먹는 분위기가 아주 좋은 곳.” “가격은 좀 비싼 편이나 분위기는 좋음.” “한우도 좋지만 곱창전골이 아주 훌륭하다.”\n'
#  'etcInfo_interior: 전통 한국식\n'
#  'etcInfo_seat: \n'
#  'etcInfo_room: \n'
#  'etcInfo_head: \n'
#  'etcInfo_branch: \n'
#  'defaultInfo_website: https://mayfield.co.kr/dining/nakwon.html, '
#  'https://www.instagram.com/mayfield_hotel/',
#  'foodDetailTypes: 일반중식\n'
#  'headerInfo_nameKR: 도림\n'
#  'headerInfo_nameEN: \n'
#  'headerInfo_nameCN: 挑林\n'
#  'headerInfo_bookYear: 2025\n'
#  'headerInfo_ribbonType: 3\n'
#  'defaultInfo_chefName: \n'
#  'defaultInfo_phone: 02-317-7101\n'
#  'defaultInfo_openHours: \n'
#  'defaultInfo_closeHours: \n'
#  'defaultInfo_openHoursWeekend: \n'
#  'defaultInfo_closeHoursWeekend: \n'
#  'defaultInfo_dayOff: 연중무휴\n'
#  'defaultInfo_app2Yn: False\n'
#  'statusInfo_parking: 발레 파킹\n'
#  'statusInfo_creditCard: y\n'
#  'statusInfo_visit: 소공동 서울롯데호텔 본관 37층\n'
#  'statusInfo_menu: 런치코스(복 15만원, 수 17만원, 강 19만원, 희 21만원), 디너코스(오룡 19만원, 은호 '
#  '23만원, 세작 33만원, 도림 55만원)\n'
#  'statusInfo_priceRange: 15~25만원대\n'
#  'statusInfo_openDate: 2006년\n'
#  'statusInfo_businessHours: 11:30~14:30(마지막 주문 14:00)/18:00~22:00(마지막 주문 '
#  '21:00)\n'
#  'juso_detailAddress: 롯데호텔서울 본관 37층\n'
#  'juso_roadAddrPart1: 서울특별시 중구 을지로 30\n'
#  'juso_engAddr: 30, Eulji-ro, Jung-gu, Seoul\n'
#  'juso_bdNm: 롯데호텔\n'
#  'juso_siNm: 서울특별시\n'
#  'juso_sggNm: 중구\n'
#  'juso_emdNm: 소공동\n'
#  'juso_liNm: \n'
#  'juso_rn: 을지로\n'
#  'juso_buldMnnm: 30\n'
#  'juso_buldSlno: 0\n'
#  'review_review: 모던한 분위기에서 품격 있게 중국요리를 즐길 수 있는 곳. 한국인의 입맛에 잘 맞는 중식을 고급스럽고 '
#  '현대적으로 풀어내고 있다. 롯데호텔 37층의 전망도 뛰어나다.\n'
#  'review_reviewSimple: 모던한 분위기에서 품격 있게 중국요리를 즐길 수 있는 곳. 한국인의 입맛에 잘 맞는 중식을 '
#  '고급스럽고 현대적으로 풀어내고 있다. 롯데호텔 37층의 전망도 뛰어나다.\n'
#  'review_readerAppraisal: “변함 없이 선사해주는 퀄리티. 과하지 않은 담백한 맛을 느낄 수 있어 언제나 먹어도 '
#  '좋습니다.” “정통 중식에 약간 모던한 베리에이션을 더했는데, 매우 맛있고 만족스럽습니다.” “분위기와 서비스가 우수함. 음식도 맛있는 '
#  '편.” “주말 특선 메뉴가 가격 대비 만족도가 아주 높다. 특히 샥스핀, 불도장 등이 포함된 코스의 만족도가 높다. 취향에 따라 채소류나 '
#  '어패류를 별도 주문하면 구성의 완성도가 더 높아진다.” “최고급 중식당임을 실감하기까기 긴 시간이 필요하지 않다.” “방에 앉아서 코스 '
#  '요리를 먹고 나면 잠시 부러울 게 없어진다.” “호텔에서 분위기를 낼 수 있는 최고의 식당.” “디너 분위기는 강북 최고인 것 같다.”\n'
#  'etcInfo_interior: \n'
#  'etcInfo_seat: 50석\n'
#  'etcInfo_room: 12개(2~50석)\n'
#  'etcInfo_head: \n'
#  'etcInfo_branch: 잠실롯데월드점(02-411-7800), 울산삼산동(052-960-4280)\n'
#  'defaultInfo_website: '
#  'https://www.lottehotel.com/global/ko/reservation/restaurant-step1.html?htlCd=LTSE&rstrCd=TL, '
#  'https://www.instagram.com/lottehotel_seoul/',
#  'foodDetailTypes: 일반중식\n'
#  'headerInfo_nameKR: 팔선\n'
#  'headerInfo_nameEN: \n'
#  'headerInfo_nameCN: 八仙\n'
#  'headerInfo_bookYear: 2025\n'
#  'headerInfo_ribbonType: 3\n'
#  'defaultInfo_chefName: \n'
#  'defaultInfo_phone: 02-2230-3366\n'
#  'defaultInfo_openHours: \n'
#  'defaultInfo_closeHours: \n'
#  'defaultInfo_openHoursWeekend: \n'
#  'defaultInfo_closeHoursWeekend: \n'
#  'defaultInfo_dayOff: 연중무휴\n'
#  'defaultInfo_app2Yn: True\n'
#  'statusInfo_parking: 가능\n'
#  'statusInfo_creditCard: y\n'
#  'statusInfo_visit: 장충동 서울신라호텔 2층\n'
#  'statusInfo_menu: 저녁코스(복 20만원, 록 23만원, 수 25만원, 관부연 28만원, 궁정연 33만원, 황제연 50만원), '
#  '점심코스(13만원~26만원), 삼선짬뽕(3만5천원), 불도장(1인 20만원), 고추닭고기(소 6만2천원, 대9만3천원)\n'
#  'statusInfo_priceRange: 25만원 이상\n'
#  'statusInfo_openDate: 1979년\n'
#  'statusInfo_businessHours: 12:00~14:30/17:30~21:30\n'
#  'juso_detailAddress: 서울신라호텔 2층\n'
#  'juso_roadAddrPart1: 서울특별시 중구 동호로 249\n'
#  'juso_engAddr: 249, Dongho-ro, Jung-gu, Seoul\n'
#  'juso_bdNm: \n'
#  'juso_siNm: 서울특별시\n'
#  'juso_sggNm: 중구\n'
#  'juso_emdNm: 장충동2가\n'
#  'juso_liNm: \n'
#  'juso_rn: 동호로\n'
#  'juso_buldMnnm: 249\n'
#  'juso_buldSlno: 0\n'
#  'review_review: 많은 사람들이 서울 최고의 중식당으로 꼽는 데 주저하지 않는 곳. 광동식을 비롯하여 사천, 북경요리 등 수백 '
#  '가지가 넘는 정통 중국요리를 해낼 수 있는 곳이다. 명성 만큼이나 맛, 분위기, 서비스 모두 좋다. 단골 손님이 되면 요리를 개개인의 '
#  '취향에 맞춰 주기도 한다.\n'
#  'review_reviewSimple: 많은 사람들이 서울 최고의 중식당으로 꼽는 데 주저하지 않는 곳. 광동식을 비롯하여 사천, 북경요리 '
#  '등 수백 가지가 넘는 정통 중국요리를 해낼 수 있는 곳이다. 명성 만큼이나 맛, 분위기, 서비스 모두 좋다. 단골 손님이 되면 요리를 '
#  '개개인의 취향에 맞춰 주기도 한다.\n'
#  'review_readerAppraisal: “명성이나 가격 모두 국내 최고의 중식당답게 전통적인 메뉴에서 빛이나는 곳. 시즌 메뉴의 '
#  '창의성도 돋보이는 곳” “워낙에 유명해서 평가가 무의미한 곳. 이곳의 탕수육이 주기적으로 생각난다.” “대한민국 탑3에 드는 최고의 '
#  '중식당으로, 요리부터 서비스까지 최고를 지향하는 중식당. 국내 불도장 시작의 원조.” “국내 최고의 중식당이라는 표현이 아까울 정도. '
#  '세계 최고급이다. 재료의 선도와 풍미가 압도적! 지나치거나 모자람이 없는 최고의 중식.” “트레디셔널 중식의 자부심을 세워줄 곳!! 중식 '
#  '특유의 향과 맛이 완벽한 조화를 이루어 머리부터 발끝까지 한 곳 흠잡을 데 없이 완벽히 코디한 우아한 레이디 같다!”\n'
#  'etcInfo_interior: 모던/스타일리시\n'
#  'etcInfo_seat: 160석\n'
#  'etcInfo_room: 11개(4~23석)\n'
#  'etcInfo_head: \n'
#  'etcInfo_branch: \n'
#  'defaultInfo_website: '
#  'https://www.shilla.net/seoul/dining/viewDining.do?contId=PAL#ad-image-0, '
#  'https://www.instagram.com/shillahotels/',
#  'foodDetailTypes: 일식, 스시\n'
#  'headerInfo_nameKR: 아리아께\n'
#  'headerInfo_nameEN: \n'
#  'headerInfo_nameCN: 有明\n'
#  'headerInfo_bookYear: 2025\n'
#  'headerInfo_ribbonType: 3\n'
#  'defaultInfo_chefName: 모리타\n'
#  'defaultInfo_phone: 02-2230-3356\n'
#  'defaultInfo_openHours: \n'
#  'defaultInfo_closeHours: \n'
#  'defaultInfo_openHoursWeekend: \n'
#  'defaultInfo_closeHoursWeekend: \n'
#  'defaultInfo_dayOff: 연중무휴\n'
#  'defaultInfo_app2Yn: False\n'
#  'statusInfo_parking: 가능\n'
#  'statusInfo_creditCard: y\n'
#  'statusInfo_visit: 장충동 서울신라호텔 2층\n'
#  'statusInfo_menu: 고쿠코스(16만5천원), 미야비코스(19만5천원), 사치코스(24만원), 신라코스(28만5천원)\n'
#  'statusInfo_priceRange: 25만원 이상\n'
#  'statusInfo_openDate: 1979년\n'
#  'statusInfo_businessHours: 12:00~14:30/17:30~21:30\n'
#  'juso_detailAddress: 서울신라호텔 2층\n'
#  'juso_roadAddrPart1: 서울특별시 중구 동호로 249\n'
#  'juso_engAddr: 249, Dongho-ro, Jung-gu, Seoul\n'
#  'juso_bdNm: \n'
#  'juso_siNm: 서울특별시\n'
#  'juso_sggNm: 중구\n'
#  'juso_emdNm: 장충동2가\n'
#  'juso_liNm: \n'
#  'juso_rn: 동호로\n'
#  'juso_buldMnnm: 249\n'
#  'juso_buldSlno: 0\n'
#  'review_review: 재료의 선도가 좋기로 유명한, 서울에서 손꼽히는 일식집 중 하나다. 담백하고 정갈한 90여 가지의 정통 관서 '
#  '지방의 요리를 선보인다. 스시의 퀄리티가 특히 독보적으로, 현재 우리나라 스시 분야는 아리아께 출신 조리장이 석권하고 있다고 해도 과언이 '
#  '아니다. 스시조와 함께 우리나라 스시의 양대 산맥으로 불린다. 일명 모리아께라고 불리는 모리타 상이 쥐어주는 스시를 맛보려면 치열한 예약 '
#  '경쟁을 치러야 한다. 스시 뿐만 아니라 가이세키도 훌륭하다.\n'
#  'review_reviewSimple: 재료의 선도가 좋기로 유명한, 서울에서 손꼽히는 일식집 중 하나다. 담백하고 정갈한 90여 가지의 '
#  '정통 관서 지방의 요리를 선보인다. 스시의 퀄리티가 특히 독보적으로, 현재 우리나라 스시 분야는 아리아께 출신 조리장이 석권하고 있다고 '
#  '해도 과언이 아니다. 스시조와 함께 우리나라 스시의 양대 산맥으로 불린다. 일명 모리아께라고 불리는 모리타 상이 쥐어주는 스시를 맛보려면 '
#  '치열한 예약 경쟁을 치러야 한다.\n'
#  'review_readerAppraisal: “한국 스시의 최고봉.” “일단 재료가 최고급이라는 느낌이 팍 오더군요. 뭐 말이 필요 없이 '
#  '리본 수에 동의합니다.”\n'
#  'etcInfo_interior: 모던/스타일리시\n'
#  'etcInfo_seat: 93석\n'
#  'etcInfo_room: 5개(6~8석)\n'
#  'etcInfo_head: \n'
#  'etcInfo_branch: \n'
#  'defaultInfo_website: '
#  'https://www.shilla.net/seoul/dining/viewDining.do?contId=ARI#ad-image-0',
#  'foodDetailTypes: 소갈비, 소고기구이, 한우오마카세\n'
#  'headerInfo_nameKR: 삼원가든\n'
#  'headerInfo_nameEN: \n'
#  'headerInfo_nameCN: \n'
#  'headerInfo_bookYear: 2025\n'
#  'headerInfo_ribbonType: 3\n'
#  'defaultInfo_chefName: \n'
#  'defaultInfo_phone: 02-548-3030\n'
#  'defaultInfo_openHours: \n'
#  'defaultInfo_closeHours: \n'
#  'defaultInfo_openHoursWeekend: \n'
#  'defaultInfo_closeHoursWeekend: \n'
#  'defaultInfo_dayOff: 연중무휴\n'
#  'defaultInfo_app2Yn: True\n'
#  'statusInfo_parking: 발레 파킹\n'
#  'statusInfo_creditCard: y\n'
#  'statusInfo_visit: 도산공원교차로에서 성수대교 방향으로 직진하면 좌측\n'
#  'statusInfo_menu: 전통양념갈비(200g 5만8천원), 한우양념/생갈비(각 200g 11만원), 한우특생갈비(200g '
#  '15만원), 한우등심생불고기(200g 5만5천원), 한우생등심(130g 8만원), 양념게장(7만5천원), 갈비찜(7만원)\n'
#  'statusInfo_priceRange: 15~25만원대\n'
#  'statusInfo_openDate: 1976년\n'
#  'statusInfo_businessHours: 11:30~15:00/17:00~22:00\n'
#  'juso_detailAddress: \n'
#  'juso_roadAddrPart1: 서울특별시 강남구 언주로 835\n'
#  'juso_engAddr: 835, Eonju-ro, Gangnam-gu, Seoul\n'
#  'juso_bdNm: 삼원가든\n'
#  'juso_siNm: 서울특별시\n'
#  'juso_sggNm: 강남구\n'
#  'juso_emdNm: 신사동\n'
#  'juso_liNm: \n'
#  'juso_rn: 언주로\n'
#  'juso_buldMnnm: 835\n'
#  'juso_buldSlno: 0\n'
#  'review_review: 50여 년 전통의 우리나라 대표 갈빗집. 대표 메뉴인 양념 갈비와 함께 나오는 반찬도 정갈하며 갈비 외에 '
#  '등심이나 불고기, 단품 요리도 수준급이다. 예약제로 운영되는 특실에서는 다양한 한정식과, 한우 모둠 구이가 나오는 차별화된 코스로 '
#  '진행된다. 특실 예약은 02-548-3037로 문의하면 된다.\n'
#  'review_reviewSimple: \n'
#  'review_readerAppraisal: “밑반찬은 약간 간간하지만 적절한 편. 예약하면 방에 갈 수 있기 때문에 모임 장소로도 '
#  '적합.” “강남 지역에서 가족과 함께 갈 만한 대표적인 외식장소.” “정말로 맛있다. 맛으로는 가격이 용서되는 집!!!” “질이 꽤 좋은 '
#  '고기들을 제공하며 룸이 많아 모임에 적합.” “강남 갈빗집의 터줏대감이 아닐까.”\n'
#  'etcInfo_interior: \n'
#  'etcInfo_seat: 1000석\n'
#  'etcInfo_room: 30개(6~180석)\n'
#  'etcInfo_head: \n'
#  'etcInfo_branch: \n'
#  'defaultInfo_website: http://www.samwongarden.com, '
#  'https://www.instagram.com/sg_dinehill/',
#  'foodDetailTypes: 한정식\n'
#  'headerInfo_nameKR: 봉래헌\n'
#  'headerInfo_nameEN: \n'
#  'headerInfo_nameCN: 逢萊軒\n'
#  'headerInfo_bookYear: 2025\n'
#  'headerInfo_ribbonType: 3\n'
#  'defaultInfo_chefName: \n'
#  'defaultInfo_phone: 02-2660-9020\n'
#  'defaultInfo_openHours: \n'
#  'defaultInfo_closeHours: \n'
#  'defaultInfo_openHoursWeekend: \n'
#  'defaultInfo_closeHoursWeekend: \n'
#  'defaultInfo_dayOff: 월요일 휴무\n'
#  'defaultInfo_app2Yn: False\n'
#  'statusInfo_parking: 가능\n'
#  'statusInfo_creditCard: y\n'
#  'statusInfo_visit: 김포 메이필드호텔 내\n'
#  'statusInfo_menu: 점심상차림(6만5천원), 코스(10만원~30만원)\n'
#  'statusInfo_priceRange: 10~15만원대\n'
#  'statusInfo_openDate: 2003년\n'
#  'statusInfo_businessHours: 11:30~14:30/18:00~21:30\n'
#  'juso_detailAddress: 메이필드호텔\n'
#  'juso_roadAddrPart1: 서울특별시 강서구 방화대로 94\n'
#  'juso_engAddr: 94, Banghwa-daero, Gangseo-gu, Seoul\n'
#  'juso_bdNm: 메이필드호텔\n'
#  'juso_siNm: 서울특별시\n'
#  'juso_sggNm: 강서구\n'
#  'juso_emdNm: 외발산동\n'
#  'juso_liNm: \n'
#  'juso_rn: 방화대로\n'
#  'juso_buldMnnm: 94\n'
#  'juso_buldSlno: 0\n'
#  'review_review: 정통 궁중 음식을 코스로 재현해 선보이는 한정식집이다. 경복궁 복원에 참여했던 문화재 기능자 이일구 대목수가 '
#  '전통 궁궐 양식으로 지은 한옥에 자리하고 있다. 작은 연못과 정원이 조화를 이루고 있어 고급스러운 분위기를 연출한다.\n'
#  'review_reviewSimple: 정통 궁중 음식을 코스로 재현해 선보이는 한정식집이다. 경복궁 복원에 참여했던 문화재 기능자 이일구 '
#  '대목수가 전통 궁궐 양식으로 지은 한옥에 자리하고 있다. 작은 연못과 정원이 조화를 이루고 있어 고급스러운 분위기를 연출한다.\n'
#  'review_readerAppraisal: “식사 후에 조경이 아름다운 메이필드호텔을 산책 겸 돌아볼 수 있는 것도 최고의 옵션이다.” '
#  '“다소 불편한 교통만 빼면 외국인 접대하는 데 서울에 이만한 곳 없음.”\n'
#  'etcInfo_interior: 전통 한국식\n'
#  'etcInfo_seat: \n'
#  'etcInfo_room: \n'
#  'etcInfo_head: \n'
#  'etcInfo_branch: \n'
#  'defaultInfo_website: http://www.mayfield.co.kr/',
#  'foodDetailTypes: 이탈리아식, 파스타\n'
#  'headerInfo_nameKR: 미피아체\n'
#  'headerInfo_nameEN: Mi Piace\n'
#  'headerInfo_nameCN: \n'
#  'headerInfo_bookYear: 2025\n'
#  'headerInfo_ribbonType: 3\n'
#  'defaultInfo_chefName: \n'
#  'defaultInfo_phone: 02-516-6317\n'
#  'defaultInfo_openHours: \n'
#  'defaultInfo_closeHours: \n'
#  'defaultInfo_openHoursWeekend: \n'
#  'defaultInfo_closeHoursWeekend: \n'
#  'defaultInfo_dayOff: 일요일, 명절 휴무\n'
#  'defaultInfo_app2Yn: False\n'
#  'statusInfo_parking: 발레 파킹\n'
#  'statusInfo_creditCard: y\n'
#  'statusInfo_visit: \n'
#  'statusInfo_menu: 런치세트(6만원), 디너코스(12만원), 한우안심스테이크(200g 15만원), '
#  '토마토라구소스파스타(3만4천원), 클래식카르보나라(3만원), 전복리조토(3만5천원)\n'
#  'statusInfo_priceRange: 10~15만원대\n'
#  'statusInfo_openDate: 2003년\n'
#  'statusInfo_businessHours: 12:00~15:00/18:00~21:30\n'
#  'juso_detailAddress: \n'
#  'juso_roadAddrPart1: 서울특별시 강남구 도산대로70길 34\n'
#  'juso_engAddr: 34 Dosan-daero 70-gil, Gangnam-gu, Seoul\n'
#  'juso_bdNm: \n'
#  'juso_siNm: 서울특별시\n'
#  'juso_sggNm: 강남구\n'
#  'juso_emdNm: 청담동\n'
#  'juso_liNm: \n'
#  'juso_rn: 압구정로80길\n'
#  'juso_buldMnnm: 34\n'
#  'juso_buldSlno: 0\n'
#  'review_review: 청담동에서 가장 오래된 레스토랑 중의 하나로, 20년 세월 동안 변함없는 맛을 유지하고 있다. 전채, 메인, '
#  '디저트 모두 손색없이 훌륭하며 계절에 따라, 트렌드에 따라 메뉴가 자주 바뀌어 다양한 즐거움을 준다. 미리 주문하면 맛볼 수 있는 '
#  '피오렌티나 스테이크도 명성이 자자하다. 2023년 8월 지금의 자리로 이전하여 분위기가 더욱 좋아졌다. 테라스 자리를 이용할 것을 '
#  '추천.\n'
#  'review_reviewSimple: 청담동에서 가장 오래된 레스토랑 중의 하나로, 20년 세월 동안 변함없는 맛을 유지하고 있다. '
#  '전채, 메인, 디저트 모두 손색없이 훌륭하며 계절에 따라, 트렌드에 따라 메뉴가 자주 바뀌어 다양한 즐거움을 준다. 미리 주문하면 맛볼 '
#  '수 있는 피오렌티나 스테이크도 명성이 자자하다. 2023년 8월 지금의 자리로 이전하여 분위기가 더욱 좋아졌다. 테라스 자리를 이용할 '
#  '것을 추천.\n'
#  'review_readerAppraisal: “분위기가 근사하고 개성 있는 요리.” “10년 넘게 처음 다시 갔는데, 예전 느낌 그대로, '
#  '좋은 느낌 그대로 입니다. 음식도 개선하시고, 서비스나 메뉴들도 맛이 좋습니다.” “제대로 만든 이탈리안.” “전통 있는 청담동의 '
#  '터줏대감. 맛있고 실패하지 않는 이탈리안 음식점을 찾는다면 이곳이 제격!” “모든 음식들이 완벽하다.” “가격 대비와 분위기도 그렇고 '
#  '만족스러운 식사를 할 수 있다. 오래 되었지만 전혀 뒤처지지 않는 곳.” “가족들이 모두 사랑하는 가게. 파스타는 최고인 듯.” '
#  '“분위기도 편안함과 클래식함을 동시에 느낄 수 있구요. 단골집이 되고 싶은 곳이지요.” “왜 리본 세 개를 받는지 잘 보여 주는 곳.” '
#  '“기본에 충실하고 특히 적절한 간이 최고의 장점이다. 가본 이탈리안 레스토랑 중에 톱클래스.” “가격 대비 만족도 최상.”\n'
#  'etcInfo_interior: 클래식한 유럽풍\n'
#  'etcInfo_seat: 1층 20석 / 2층 34석\n'
#  'etcInfo_room: 2개\n'
#  'etcInfo_head: \n'
#  'etcInfo_branch: \n'
#  'defaultInfo_website: https://www.instagram.com/mipiace_kitchen/',
#  'foodDetailTypes: 프랑스식\n'
#  'headerInfo_nameKR: 라미띠에\n'
#  "headerInfo_nameEN: L'Amitie\n"
#  'headerInfo_nameCN: \n'
#  'headerInfo_bookYear: 2025\n'
#  'headerInfo_ribbonType: 3\n'
#  'defaultInfo_chefName: 장명식\n'
#  'defaultInfo_phone: 02-546-9621\n'
#  'defaultInfo_openHours: \n'
#  'defaultInfo_closeHours: \n'
#  'defaultInfo_openHoursWeekend: \n'
#  'defaultInfo_closeHoursWeekend: 11:24\n'
#  'defaultInfo_dayOff: 화요일 휴무\n'
#  'defaultInfo_app2Yn: False\n'
#  'statusInfo_parking: 발레 파킹\n'
#  'statusInfo_creditCard: y\n'
#  'statusInfo_visit: 청담사거리에서 학동사거리 방향으로 직진. 몽중헌에서 우회전 후 직진하면 우측\n'
#  'statusInfo_menu: 런치코스(13만원), 디너코스(22만원)\n'
#  'statusInfo_priceRange: 15~25만원대\n'
#  'statusInfo_openDate: 2006년\n'
#  'statusInfo_businessHours: 12:00~15:00/18:00~22:00(마지막 주문 21:30)\n'
#  'juso_detailAddress: 2층\n'
#  'juso_roadAddrPart1: 서울특별시 강남구 도산대로67길 30\n'
#  'juso_engAddr: 30, Dosan-daero 67-gil, Gangnam-gu, Seoul\n'
#  'juso_bdNm: \n'
#  'juso_siNm: 서울특별시\n'
#  'juso_sggNm: 강남구\n'
#  'juso_emdNm: 청담동\n'
#  'juso_liNm: \n'
#  'juso_rn: 언주로153길\n'
#  'juso_buldMnnm: 30\n'
#  'juso_buldSlno: 0\n'
#  'review_review: 서울의 프렌치 레스토랑을 얘기할 때 빼놓을 수 없는 곳. 장명식 셰프가 클래식한 스타일에 자신만의 섬세한 '
#  '기법과 프레젠테이션을 가미하여 한층 모던하고 세련된 음식을 낸다.\n'
#  'review_reviewSimple: 서울의 프렌치 레스토랑을 얘기할 때 빼놓을 수 없는 곳. 장명식 셰프가 클래식한 스타일에 자신만의 '
#  '섬세한 기법과 프레젠테이션을 가미하여 한층 모던하고 세련된 음식을 낸다.\n'
#  'review_readerAppraisal: “지인에게 주저 없이 추천할 수 있는 프렌치 레스토랑.” “우리나라에서 손꼽히는 프렌치 '
#  '레스토랑이자 전통까지 있는 곳. 고급스러운 분위기와 그에 어울리는 고급진 맛을 느낄 수 있음” “맛을 보장하는 프렌치 레스토랑”\n'
#  'etcInfo_interior: 클래식한 유럽풍\n'
#  'etcInfo_seat: \n'
#  'etcInfo_room: \n'
#  'etcInfo_head: \n'
#  'etcInfo_branch: \n'
#  'defaultInfo_website: http://lamitie.modoo.at/, '
#  'https://www.instagram.com/restaurant_lamitie/',
#  'foodDetailTypes: 북경식중식, 일반중식\n'
#  'headerInfo_nameKR: 도원\n'
#  'headerInfo_nameEN: \n'
#  'headerInfo_nameCN: 桃園\n'
#  'headerInfo_bookYear: 2025\n'
#  'headerInfo_ribbonType: 3\n'
#  'defaultInfo_chefName: \n'
#  'defaultInfo_phone: 02-310-7300\n'
#  'defaultInfo_openHours: 11:30\n'
#  'defaultInfo_closeHours: 22:00\n'
#  'defaultInfo_openHoursWeekend: \n'
#  'defaultInfo_closeHoursWeekend: \n'
#  'defaultInfo_dayOff: 연중무휴\n'
#  'defaultInfo_app2Yn: False\n'
#  'statusInfo_parking: 가능\n'
#  'statusInfo_creditCard: y\n'
#  'statusInfo_visit: 시청 앞 더플라자호텔 3층\n'
#  'statusInfo_menu: 해황소스활해산물(20만원), 해황소스활바닷가재(19만원대), 북경오리(18만5천원), 런치코스(무릉 '
#  '15만원, 도원 17만원), 디너코스(귀빈 18만원, 영빈 25만원, 경화귀객 28만)\n'
#  'statusInfo_priceRange: 15~25만원대\n'
#  'statusInfo_openDate: 1976년\n'
#  'statusInfo_businessHours: 11:30~14:30/18:00~21:30\n'
#  'juso_detailAddress: 더플라자 3층\n'
#  'juso_roadAddrPart1: 서울특별시 중구 소공로 119\n'
#  'juso_engAddr: 119, Sogong-ro, Jung-gu, Seoul\n'
#  'juso_bdNm: 더 플라자\n'
#  'juso_siNm: 서울특별시\n'
#  'juso_sggNm: 중구\n'
#  'juso_emdNm: 태평로2가\n'
#  'juso_liNm: \n'
#  'juso_rn: 소공로\n'
#  'juso_buldMnnm: 119\n'
#  'juso_buldSlno: 0\n'
#  'review_review: 50년 가까운 역사의 호텔 중식당으로, 유명인들이 자주 찾는 곳으로도 유명하다. 분위기, 맛, 서비스 모두 '
#  '나무랄 데 없이 훌륭하다. 시대의 흐름에 맞추어 끊임없이 메뉴에 변화를 주고 있으며 전통적인 레시피에 기초한 모던한 중식을 선보이고 '
#  '있다. 기름기가 적은 산뜻한 맛의 중식을 즐길 수 있다.\n'
#  'review_reviewSimple: 50년 가까운 역사의 호텔 중식당으로, 유명인들이 자주 찾는 곳으로도 유명하다. 분위기, 맛, '
#  '서비스 모두 나무랄 데 없이 훌륭하다. 시대의 흐름에 맞추어 끊임없이 메뉴에 변화를 주고 있으며 전통적인 레시피에 기초한 모던한 중식을 '
#  '선보이고 있다. 기름기가 적은 산뜻한 맛의 중식을 즐길 수 있다.\n'
#  'review_readerAppraisal: “전통적인 중식당의 자리를 지켜주고 있어 감사한 집.” “음식들이 창의적이었던 거 같습니다.” '
#  '“호텔이다 보니 가격 부담이 상당하다. 베이징덕을 이곳만큼 하는 곳이 별로 없어 베이징덕과 식사를 즐기기에 아주 좋다.” “매번 방문할 '
#  '때마다 직원의 기분 좋은 서비스와 한결같이 고급스러운 맛에 감동합니다.” “오랜 역사를 간직한 만큼 맛도 서비스도 좋았습니다.” “전통과 '
#  '공존하는 도원만의 중식.” “독립적으로 이용할 수 있는 룸이 많아 편안한 식사를 할 수 있어서 좋다.”\n'
#  'etcInfo_interior: \n'
#  'etcInfo_seat: 150석\n'
#  'etcInfo_room: 15개(2~26석)\n'
#  'etcInfo_head: \n'
#  'etcInfo_branch: \n'
#  'defaultInfo_website: https://www.hoteltheplaza.com/kr/dining/taoyuen.jsp',
#  'foodDetailTypes: 프렌치비스트로, 프랑스식\n'
#  'headerInfo_nameKR: 메종루블랑\n'
#  'headerInfo_nameEN: MAISON LOUPBLANC\n'
#  'headerInfo_nameCN: \n'
#  'headerInfo_bookYear: 2025\n'
#  'headerInfo_ribbonType: 2\n'
#  'defaultInfo_chefName: 신민섭\n'
#  'defaultInfo_phone: 070-8849-2040\n'
#  'defaultInfo_openHours: \n'
#  'defaultInfo_closeHours: \n'
#  'defaultInfo_openHoursWeekend: \n'
#  'defaultInfo_closeHoursWeekend: \n'
#  'defaultInfo_dayOff: 월요일 휴무\n'
#  'defaultInfo_app2Yn: True\n'
#  'statusInfo_parking: 가능\n'
#  'statusInfo_creditCard: y\n'
#  'statusInfo_visit: \n'
#  'statusInfo_menu: 뵈프부르기뇽, 수비드삼겹살(각 3만원), 채끝등심스테이크(150G 2만6천원, 300g 5만원), '
#  '오리콩피(3만원), 생면라구스파게티(2만5천원), 모렐버섯리조토(2만7천원), 비스크소스뇨키(2만5천원)\n'
#  'statusInfo_priceRange: 5~10만원대\n'
#  'statusInfo_openDate: 2014년\n'
#  'statusInfo_businessHours: 11:30~14:00/17:00~22:00\n'
#  'juso_detailAddress: \n'
#  'juso_roadAddrPart1: 서울특별시 용산구 한강대로15길 19-22\n'
#  'juso_engAddr: 19-22 Hangang-daero 15-gil, Yongsan-gu, Seoul\n'
#  'juso_bdNm: \n'
#  'juso_siNm: 서울특별시\n'
#  'juso_sggNm: 용산구\n'
#  'juso_emdNm: 한강로3가\n'
#  'juso_liNm: \n'
#  'juso_rn: 와우산로25길\n'
#  'juso_buldMnnm: 19\n'
#  'juso_buldSlno: 22\n'
#  'review_review: 프렌치비스트로로, 아늑한 분우기에서 와인과 함께 프렌치 요리를 즐길 수 있다. 인기 메뉴는 수비드한 훈제 '
#  '삼겹살과 오리다리콩피며 와인 안주로 좋은 치즈나 샤퀴테리, 파테를 비롯한 스몰플레이트도 여러 가지 준비되어 있다.\n'
#  'review_reviewSimple: \n'
#  'review_readerAppraisal: “프렌치 요리와 벨기에 맥주 그리고 와인을 합리적인 가격에 탁월한 퀄리티로 즐길 수 있는 '
#  '곳.” “프렌치 요리와 흔하지 않은 맥주, 와인과의 조합은 루블랑에 있는 내내 즐겁게 합니다.” “프랑스 요리의 맛이 아주 좋고 서비스도 '
#  '좋으며 바에 앉으면 셰프님과 소통이 가능하다. 맥주 맛도 일품이다.” “양보단 질을 맛보고 싶을 때 가는 곳.” “맛있는 프렌치 요리를 '
#  '캐주얼하게 즐길 수 있는 펍.” “맛, 분위기, 서비스 어느 하나 부족하지 않은 곳. 다양한 맥주를 맛볼 수 있는 것도 좋다.”\n'
#  'etcInfo_interior: \n'
#  'etcInfo_seat: \n'
#  'etcInfo_room: \n'
#  'etcInfo_head: \n'
#  'etcInfo_branch: \n'
#  'defaultInfo_website: https://www.instagram.com/maison_loupblanc/',
#  'foodDetailTypes: 뷔페\n'
#  'headerInfo_nameKR: 더파크뷰\n'
#  'headerInfo_nameEN: The Parkview\n'
#  'headerInfo_nameCN: \n'
#  'headerInfo_bookYear: 2024\n'
#  'headerInfo_ribbonType: 2\n'
#  'defaultInfo_chefName: \n'
#  'defaultInfo_phone: 064-735-5334\n'
#  'defaultInfo_openHours: \n'
#  'defaultInfo_closeHours: \n'
#  'defaultInfo_openHoursWeekend: \n'
#  'defaultInfo_closeHoursWeekend: \n'
#  'defaultInfo_dayOff: 연중무휴\n'
#  'defaultInfo_app2Yn: False\n'
#  'statusInfo_parking: 가능\n'
#  'statusInfo_creditCard: y\n'
#  'statusInfo_visit: 신라호텔3층\n'
#  'statusInfo_menu: 아침뷔페, 점심뷔페(각 7만원), 저녁뷔페(15만원)\n'
#  'statusInfo_priceRange: 10~15만원대\n'
#  'statusInfo_openDate: 2012년\n'
#  'statusInfo_businessHours: 07:30~22:00\n'
#  'juso_detailAddress: 신라호텔제주 3층\n'
#  'juso_roadAddrPart1: 제주특별자치도 서귀포시 중문관광로72번길 75\n'
#  'juso_engAddr: 75, Jungmungwangwang-ro 72beon-gil, Seogwipo-si, Jeju-do\n'
#  'juso_bdNm: \n'
#  'juso_siNm: 제주특별자치도\n'
#  'juso_sggNm: 서귀포시\n'
#  'juso_emdNm: 색달동\n'
#  'juso_liNm: \n'
#  'juso_rn: 중문관광로72번길\n'
#  'juso_buldMnnm: 75\n'
#  'juso_buldSlno: 0\n'
#  'review_review: 신라호텔내의 뷔페 식당으로, 신선한 제주산 해산물과 식재료를 이용한 자연주의 요리를 맛볼 수 있다. 전 섹션이 '
#  '조리 과정을 직접 볼 수 있는 오픈 키친으로 되어 있다. 뷔페임에도 레스토랑처럼 플레이팅 되어 나오는 완성도 높은 스테이크 요리와 생선 '
#  '요리가 훌륭하다.\n'
#  'review_reviewSimple: 신라호텔내의 뷔페 식당으로, 신선한 제주산 해산물과 식재료를 이용한 자연주의 요리를 맛볼 수 있다. '
#  '전 섹션이 조리 과정을 직접 볼 수 있는 오픈 키친으로 되어 있다. 뷔페임에도 레스토랑처럼 플레이팅 되어 나오는 완성도 높은 스테이크 '
#  '요리와 생선 요리가 훌륭하다.\n'
#  'review_readerAppraisal: “제주에서 뷔페를 먹으려면 여기에 가야 한다. 비싼 값을 한다.” “제주에선 단연 최고.”\n'
#  'etcInfo_interior: \n'
#  'etcInfo_seat: \n'
#  'etcInfo_room: \n'
#  'etcInfo_head: \n'
#  'etcInfo_branch: \n'
#  'defaultInfo_website: '
#  'https://www.shilla.net/jeju/dining/viewDining.do?contId=PAR#ad-image-0',
#  'foodDetailTypes: 다이닝바, 프랑스식, 와인바\n'
#  'headerInfo_nameKR: 블루바이필레터\n'
#  'headerInfo_nameEN: BLUE by. Filleter\n'
#  'headerInfo_nameCN: \n'
#  'headerInfo_bookYear: 2025\n'
#  'headerInfo_ribbonType: 2\n'
#  'defaultInfo_chefName: 정세욱\n'
#  'defaultInfo_phone: 0507-1350-0407\n'
#  'defaultInfo_openHours: \n'
#  'defaultInfo_closeHours: \n'
#  'defaultInfo_openHoursWeekend: \n'
#  'defaultInfo_closeHoursWeekend: \n'
#  'defaultInfo_dayOff: 일, 월요일 휴무\n'
#  'defaultInfo_app2Yn: False\n'
#  'statusInfo_parking: 발레 파킹\n'
#  'statusInfo_creditCard: \n'
#  'statusInfo_visit: \n'
#  'statusInfo_menu: 가리비(3만원), 문어(2만8천원), 가자미(3만2천원), 달고기(2만8천원), 민어(3만4천원), '
#  '닭(3만5천원)\n'
#  'statusInfo_priceRange: 5~10만원대\n'
#  'statusInfo_openDate: 2022년\n'
#  'statusInfo_businessHours: 17:30~24:00(마지막 주문 23:00)\n'
#  'juso_detailAddress: \n'
#  'juso_roadAddrPart1: 서울특별시 강남구 선릉로141길 4\n'
#  'juso_engAddr: 4 Seolleung-ro 141-gil, Gangnam-gu, Seoul\n'
#  'juso_bdNm: \n'
#  'juso_siNm: 서울특별시\n'
#  'juso_sggNm: 강남구\n'
#  'juso_emdNm: 논현동\n'
#  'juso_liNm: \n'
#  'juso_rn: \n'
#  'juso_buldMnnm: 4\n'
#  'juso_buldSlno: 0\n'
#  'review_review: 생선과 해산물을 전문으로 하는 와인바 겸 캐주얼 레스토랑. 전설의 프렌치펍 루이쌍끄 출신인 정세욱 셰프가 '
#  '프렌치 스타일로 조리한 다양한 해산물을 맛볼 수 있다. 2024년 5월, 필레터와 피라타가 합쳐져 블루 바이 필레터로 리뉴얼 '
#  '오픈하였다.\n'
#  'review_reviewSimple: \n'
#  'review_readerAppraisal: \n'
#  'etcInfo_interior: \n'
#  'etcInfo_seat: \n'
#  'etcInfo_room: \n'
#  'etcInfo_head: \n'
#  'etcInfo_branch: \n'
#  'defaultInfo_website: https://www.instagram.com/filleter.fish/',
#  'foodDetailTypes: 모던한식\n'
#  'headerInfo_nameKR: 블그레\n'
#  'headerInfo_nameEN: blgre\n'
#  'headerInfo_nameCN: \n'
#  'headerInfo_bookYear: 2025\n'
#  'headerInfo_ribbonType: 2\n'
#  'defaultInfo_chefName: 한휘민\n'
#  'defaultInfo_phone: 0507-1369-7940\n'
#  'defaultInfo_openHours: \n'
#  'defaultInfo_closeHours: \n'
#  'defaultInfo_openHoursWeekend: \n'
#  'defaultInfo_closeHoursWeekend: \n'
#  'defaultInfo_dayOff: 일, 월요일 휴무\n'
#  'defaultInfo_app2Yn: False\n'
#  'statusInfo_parking: 발레 파킹\n'
#  'statusInfo_creditCard: \n'
#  'statusInfo_visit: \n'
#  'statusInfo_menu: 쫄깃도토리묵탕평채(1만6천원), 제주고사리육회(7천원), 봄가리비관자타르트(6천원), '
#  '봄문어구이(2만6천원), 은대구구이(2만8천원), 새우냉이파스타(2만1천원)\n'
#  'statusInfo_priceRange: 2~5만원대\n'
#  'statusInfo_openDate: 2022년\n'
#  'statusInfo_businessHours: 17:00~24:00(마지막 주문 23:00)\n'
#  'juso_detailAddress: \n'
#  'juso_roadAddrPart1: 서울특별시 강남구 논현로175길 101-4\n'
#  'juso_engAddr: 101-4 Nonhyeon-ro 175-gil, Gangnam-gu, Seoul\n'
#  'juso_bdNm: \n'
#  'juso_siNm: 서울특별시\n'
#  'juso_sggNm: 강남구\n'
#  'juso_emdNm: 신사동\n'
#  'juso_liNm: \n'
#  'juso_rn: \n'
#  'juso_buldMnnm: 101\n'
#  'juso_buldSlno: 4\n'
#  'review_review: 화이트톤의 인테리어와 미디어 아트로 꾸민 모던 한식 레스토랑. 한국 음식에서 영감을 받은 타파스바를 지향하며, '
#  '다양한 와인와 전통주를 페어링할 수 있다.\n'
#  'review_reviewSimple: 화이트톤의 인테리어와 미디어 아트로 꾸민 모던 한식 레스토랑. 한국 음식에서 영감을 받은 타파스바를 '
#  '지향하며, 다양한 와인와 전통주를 페어링할 수 있다.\n'
#  'review_readerAppraisal: \n'
#  'etcInfo_interior: \n'
#  'etcInfo_seat: \n'
#  'etcInfo_room: \n'
#  'etcInfo_head: \n'
#  'etcInfo_branch: \n'
#  'defaultInfo_website: https://www.instagram.com/blgre.sinsa/',
#  'foodDetailTypes: 소불고기, 소고기구이\n'
#  'headerInfo_nameKR: 언양기와집불고기\n'
#  'headerInfo_nameEN: \n'
#  'headerInfo_nameCN: \n'
#  'headerInfo_bookYear: 2024\n'
#  'headerInfo_ribbonType: 2\n'
#  'defaultInfo_chefName: \n'
#  'defaultInfo_phone: 052-262-4884\n'
#  'defaultInfo_openHours: \n'
#  'defaultInfo_closeHours: \n'
#  'defaultInfo_openHoursWeekend: \n'
#  'defaultInfo_closeHoursWeekend: \n'
#  'defaultInfo_dayOff: 명절 전날, 당일 휴무\n'
#  'defaultInfo_app2Yn: False\n'
#  'statusInfo_parking: 가능\n'
#  'statusInfo_creditCard: y\n'
#  'statusInfo_visit: 남천교에서 남천교사거리 지나 직진하면 좌측\n'
#  'statusInfo_menu: 언양불고기(180g 2만2천원), 알등심(120g 3만원), 부채살(120g 3만2천원), 토시살, '
#  '새우살, 살치살(각 120g 3만5천원), 물, 비빔막국수(각 5천원)\n'
#  'statusInfo_priceRange: 2~5만원대\n'
#  'statusInfo_openDate: \n'
#  'statusInfo_businessHours: 11:00~20:50(마지막 주문 20:00)\n'
#  'juso_detailAddress: \n'
#  'juso_roadAddrPart1: 울산광역시 울주군 언양읍 헌양길 86\n'
#  'juso_engAddr: 86, Heonnyang-gil, Eonyang-eup, Ulju-gun, Ulsan\n'
#  'juso_bdNm: \n'
#  'juso_siNm: 울산광역시\n'
#  'juso_sggNm: 울주군\n'
#  'juso_emdNm: 언양읍\n'
#  'juso_liNm: 서부리\n'
#  'juso_rn: 헌양길\n'
#  'juso_buldMnnm: 86\n'
#  'juso_buldSlno: 0\n'
#  'review_review: 100년된 기와집을 개조해 만든 곳으로, 40여 년간 한우만을 다루고 있다. 불고기는 양념에 재워둔 소고기를 '
#  '석쇠에 구워 상에 낸다. 질기지 않고 부드러운 한우의 맛이 좋으며, 반찬과 고기는 모두 천연 옥으로 만든 그릇에 담아 나온다.\n'
#  'review_reviewSimple: 100년된 기와집을 개조해 만든 곳으로, 40여 년간 한우만을 다루고 있다. 불고기는 양념에 재워둔 '
#  '소고기를 석쇠에 구워 상에 낸다. 질기지 않고 부드러운 한우의 맛이 좋으며, 반찬과 고기는 모두 천연 옥으로 만든 그릇에 담아 나온다.\n'
#  'review_readerAppraisal: “불고기 구워 내오는 솜씨가 정말 뛰어나고 곁들여 주는 미나리도 싱싱함 그 자체. 반찬 '
#  '중에서는 콩잎절임이 일미다. 다른 언양불고기집보다 덜 소란스러운 분위기에서 음식을 즐길 수 있다.”\n'
#  'etcInfo_interior: \n'
#  'etcInfo_seat: \n'
#  'etcInfo_room: \n'
#  'etcInfo_head: \n'
#  'etcInfo_branch: \n'
#  'defaultInfo_website: https://blog.naver.com/boolgogi4884',
#  'foodDetailTypes: 고래\n'
#  'headerInfo_nameKR: 고래명가\n'
#  'headerInfo_nameEN: \n'
#  'headerInfo_nameCN: \n'
#  'headerInfo_bookYear: 2024\n'
#  'headerInfo_ribbonType: 2\n'
#  'defaultInfo_chefName: \n'
#  'defaultInfo_phone: 052-269-2361\n'
#  'defaultInfo_openHours: \n'
#  'defaultInfo_closeHours: \n'
#  'defaultInfo_openHoursWeekend: \n'
#  'defaultInfo_closeHoursWeekend: \n'
#  'defaultInfo_dayOff: 월요일 휴무\n'
#  'defaultInfo_app2Yn: False\n'
#  'statusInfo_parking: 가능\n'
#  'statusInfo_creditCard: y\n'
#  'statusInfo_visit: 장생포항에서 장생포고래문화마을 방향으로 직진하면 좌측\n'
#  'statusInfo_menu: 수육(소 5만원, 중 7만원, 대 10만원), 생우네, 오베기(각 5만원), 모둠(소 8만원, 중 '
#  '10만원, 대 15만원), 생고기, 육회(각 5만원), 찌개(소 2만원, 대 3만원)\n'
#  'statusInfo_priceRange: 2~5만원대\n'
#  'statusInfo_openDate: \n'
#  'statusInfo_businessHours: 10:00~22:00\n'
#  'juso_detailAddress: \n'
#  'juso_roadAddrPart1: 울산광역시 남구 장생포고래로 207\n'
#  'juso_engAddr: 207, Jangsaengpogorae-ro, Nam-gu, Ulsan\n'
#  'juso_bdNm: \n'
#  'juso_siNm: 울산광역시\n'
#  'juso_sggNm: 남구\n'
#  'juso_emdNm: 장생포동\n'
#  'juso_liNm: \n'
#  'juso_rn: 장생포고래로\n'
#  'juso_buldMnnm: 207\n'
#  'juso_buldSlno: 0\n'
#  'review_review: 다양한 부위의 고래고기를 먹을 수 있는 곳으로, 밍크고래만을 다룬다. 일행이 많다면 다양한 부위가 한 접시에 '
#  '나오는 모둠을 추천한다. 얼큰하게 끓여낸 고래찌개의 맛도 좋다는 평이다.\n'
#  'review_reviewSimple: 다양한 부위의 고래고기를 먹을 수 있는 곳으로, 밍크고래만을 다룬다. 일행이 많다면 다양한 부위가 '
#  '한 접시에 나오는 모둠을 추천한다. 얼큰하게 끓여낸 고래찌개의 맛도 좋다는 평이다.\n'
#  'review_readerAppraisal: \n'
#  'etcInfo_interior: \n'
#  'etcInfo_seat: \n'
#  'etcInfo_room: \n'
#  'etcInfo_head: \n'
#  'etcInfo_branch: \n'
#  'defaultInfo_website:',
#  'foodDetailTypes: 졸복\n'
#  'headerInfo_nameKR: 부일식당\n'
#  'headerInfo_nameEN: \n'
#  'headerInfo_nameCN: \n'
#  'headerInfo_bookYear: 2024\n'
#  'headerInfo_ribbonType: 2\n'
#  'defaultInfo_chefName: \n'
#  'defaultInfo_phone: 055-645-0842\n'
#  'defaultInfo_openHours: \n'
#  'defaultInfo_closeHours: \n'
#  'defaultInfo_openHoursWeekend: \n'
#  'defaultInfo_closeHoursWeekend: \n'
#  'defaultInfo_dayOff: 월요일 휴무\n'
#  'defaultInfo_app2Yn: False\n'
#  'statusInfo_parking: 가능(공영주차장 1시간 무료)\n'
#  'statusInfo_creditCard: \n'
#  'statusInfo_visit: 통영향여객선 터미널 맞은편. 남옥식당 뒷골목\n'
#  'statusInfo_menu: 복국(소 1만4천원, 대 1만6천원), 복매운탕(1만6천원), 복찜(소 5만원, 대 6만원)\n'
#  'statusInfo_priceRange: 1~2만원대\n'
#  'statusInfo_openDate: 1978년\n'
#  'statusInfo_businessHours: 06:00~15:30\n'
#  'juso_detailAddress: \n'
#  'juso_roadAddrPart1: 경상남도 통영시 서호시장길 45\n'
#  'juso_engAddr: 45, Seohosijang-gil, Tongyeong-si, Gyeongsangnam-do\n'
#  'juso_bdNm: 쌀나라유통, 금성공작소\n'
#  'juso_siNm: 경상남도\n'
#  'juso_sggNm: 통영시\n'
#  'juso_emdNm: 서호동\n'
#  'juso_liNm: \n'
#  'juso_rn: 서호시장길\n'
#  'juso_buldMnnm: 45\n'
#  'juso_buldSlno: 0\n'
#  'review_review: 통영산 졸복만을 사용하는 복국이 유명하다. 졸복과 복매운탕, 복수육 등을 맛볼 수 있다. 반찬으로 회를 비롯한 '
#  '여러 가지 해산물이 나온다. 50여 년의 역사를 자랑한다.\n'
#  'review_reviewSimple: 통영산 졸복만을 사용하는 복국이 유명하다. 졸복과 복매운탕, 복수육 등을 맛볼 수 있다. 반찬으로 '
#  '회를 비롯한 여러 가지 해산물이 나온다. 50여 년의 역사를 자랑한다.\n'
#  'review_readerAppraisal: \n'
#  'etcInfo_interior: \n'
#  'etcInfo_seat: \n'
#  'etcInfo_room: \n'
#  'etcInfo_head: \n'
#  'etcInfo_branch: \n'
#  'defaultInfo_website:',
#  'foodDetailTypes: 돼지국밥\n'
#  'headerInfo_nameKR: 설봉돼지국밥\n'
#  'headerInfo_nameEN: \n'
#  'headerInfo_nameCN: \n'
#  'headerInfo_bookYear: 2024\n'
#  'headerInfo_ribbonType: 2\n'
#  'defaultInfo_chefName: \n'
#  'defaultInfo_phone: 055-356-9555\n'
#  'defaultInfo_openHours: \n'
#  'defaultInfo_closeHours: \n'
#  'defaultInfo_openHoursWeekend: \n'
#  'defaultInfo_closeHoursWeekend: \n'
#  'defaultInfo_dayOff: 첫째, 셋째 수요일, 명절 휴무\n'
#  'defaultInfo_app2Yn: False\n'
#  'statusInfo_parking: 불가\n'
#  'statusInfo_creditCard: y\n'
#  'statusInfo_visit: 북성사거리에서 영생아파트 방향으로 직진. 새마을금고에서 좌회전 후 직진하면 좌측\n'
#  'statusInfo_menu: 돼지국밥, 내장국밥, 순대국밥(각 9천원), 수육백반(1만2천원), 돼지수육, 내장수육, 섞어수육(각 소 '
#  '2만5천원, 대 3만원), 암뽕수육(3만원)\n'
#  'statusInfo_priceRange: 1~2만원대\n'
#  'statusInfo_openDate: 2014년\n'
#  'statusInfo_businessHours: 10:00~21:30(마지막 주문 21:00) | 토, 일요일, 공휴일 '
#  '10:00~15:00/17:00~21:30(마지막 주문 21:00)\n'
#  'juso_detailAddress: \n'
#  'juso_roadAddrPart1: 경상남도 밀양시 노상하3길 9\n'
#  'juso_engAddr: 9, Nosangha 3-gil, Miryang-si, Gyeongsangnam-do\n'
#  'juso_bdNm: \n'
#  'juso_siNm: 경상남도\n'
#  'juso_sggNm: 밀양시\n'
#  'juso_emdNm: 내이동\n'
#  'juso_liNm: \n'
#  'juso_rn: 노상하3길\n'
#  'juso_buldMnnm: 9\n'
#  'juso_buldSlno: 0\n'
#  'review_review: 밀양에서 유명한 돼지국밥집 중 하나. 담백한 맛의 뽀얀 국물에 부추를 넣어 먹는 스타일이다. 독특한 풍미의 '
#  '암뽕수육도 먹을 수 있는 것이 특징.\n'
#  'review_reviewSimple: 밀양에서 유명한 돼지국밥집 중 하나. 담백한 맛의 뽀얀 국물에 부추를 넣어 먹는 스타일이다. 독특한 '
#  '풍미의 암뽕수육도 먹을 수 있는 것이 특징.\n'
#  'review_readerAppraisal: \n'
#  'etcInfo_interior: \n'
#  'etcInfo_seat: \n'
#  'etcInfo_room: \n'
#  'etcInfo_head: \n'
#  'etcInfo_branch: \n'
#  'defaultInfo_website:',
#  'foodDetailTypes: 멸치, 갈치\n'
#  'headerInfo_nameKR: 우리식당\n'
#  'headerInfo_nameEN: \n'
#  'headerInfo_nameCN: \n'
#  'headerInfo_bookYear: 2024\n'
#  'headerInfo_ribbonType: 2\n'
#  'defaultInfo_chefName: \n'
#  'defaultInfo_phone: 055-867-0074\n'
#  'defaultInfo_openHours: \n'
#  'defaultInfo_closeHours: \n'
#  'defaultInfo_openHoursWeekend: \n'
#  'defaultInfo_closeHoursWeekend: \n'
#  'defaultInfo_dayOff: 연중무휴\n'
#  'defaultInfo_app2Yn: False\n'
#  'statusInfo_parking: 가능\n'
#  'statusInfo_creditCard: y\n'
#  'statusInfo_visit: 남해삼동우체국 맞은편\n'
#  'statusInfo_menu: 멸치쌈밥(2인이상, 1인 1만3천원), 갈치찌개(2만원), 갈치구이(2만5천원), 갈치, 멸치회무침(각 소 '
#  '2만원, 중 3만원, 대 4만원)\n'
#  'statusInfo_priceRange: 1~2만원대\n'
#  'statusInfo_openDate: 1978년\n'
#  'statusInfo_businessHours: 08:30~20:00\n'
#  'juso_detailAddress: \n'
#  'juso_roadAddrPart1: 경상남도 남해군 삼동면 동부대로1876번길 7\n'
#  'juso_engAddr: 7, Dongbu-daero 1876beon-gil, Samdong-myeon, Namhae-gun, '
#  'Gyeongsangnam-do\n'
#  'juso_bdNm: \n'
#  'juso_siNm: 경상남도\n'
#  'juso_sggNm: 남해군\n'
#  'juso_emdNm: 삼동면\n'
#  'juso_liNm: 지족리\n'
#  'juso_rn: 동부대로1876번길\n'
#  'juso_buldMnnm: 7\n'
#  'juso_buldSlno: 0\n'
#  'review_review: 멸치로 유명한 죽방렴어구에 있는 식당. 갈치와 멸치요리를 잘하기로 유명하다. 멸치회, 멸치쌈밥이 많이 찾는 '
#  '메뉴. 멸치회는 뼈를 발라낸 후 막걸리로 버무려 양념해서 나온다. 40년이 넘는 전통을 자랑한다.\n'
#  'review_reviewSimple: 멸치로 유명한 죽방렴어구에 있는 식당. 갈치와 멸치요리를 잘하기로 유명하다. 멸치회, 멸치쌈밥이 '
#  '많이 찾는 메뉴. 멸치회는 뼈를 발라낸 후 막걸리로 버무려 양념해서 나온다. 40년이 넘는 전통을 자랑한다.\n'
#  'review_readerAppraisal: “멸치 쌈밥이랑 멸치회무침 맛있었다.” “마른 멸치도 찬으로 내주는데 그냥 먹어도 맛있다.” '
#  '“우거지를 함께 넣어 지진 멸치가 오동통하다. 시골의 맛을 느끼게 하는 멸치지짐을 쌈 싸먹는 맛이 일품.” “남해에 간다면 우리식당에 '
#  '들러 멸치 비린내가 전혀 나지 않는 멸치쌈밥을 맛보기를 추천한다. 그냥 지나친다면 남해 여행의 참맛이 줄어든다.”\n'
#  'etcInfo_interior: \n'
#  'etcInfo_seat: \n'
#  'etcInfo_room: \n'
#  'etcInfo_head: \n'
#  'etcInfo_branch: \n'
#  'defaultInfo_website:',
#  'foodDetailTypes: 굴\n'
#  'headerInfo_nameKR: 굴향토집\n'
#  'headerInfo_nameEN: \n'
#  'headerInfo_nameCN: \n'
#  'headerInfo_bookYear: 2024\n'
#  'headerInfo_ribbonType: 2\n'
#  'defaultInfo_chefName: \n'
#  'defaultInfo_phone: 055-645-4808\n'
#  'defaultInfo_openHours: \n'
#  'defaultInfo_closeHours: \n'
#  'defaultInfo_openHoursWeekend: \n'
#  'defaultInfo_closeHoursWeekend: \n'
#  'defaultInfo_dayOff: 연중무휴\n'
#  'defaultInfo_app2Yn: False\n'
#  'statusInfo_parking: 가능\n'
#  'statusInfo_creditCard: y\n'
#  'statusInfo_visit: 해변공원에서 통영우체국 가는길. 경남은행에서 좌회전하여 첫 번째 골목에서 우회전\n'
#  'statusInfo_menu: 향토코스(2만6천원), 굴코스(A 2만1천원, B 1만4천원), 굴찜(소 2만원, 중 2만5천원, 대 '
#  '3만원), 굴회(1만3천원), 굴튀김(1만5천원), 굴무침(2만4천원), 굴보쌈(4만원)\n'
#  'statusInfo_priceRange: 2~5만원대\n'
#  'statusInfo_openDate: 1993년\n'
#  'statusInfo_businessHours: 09:00~21:00│토,일요일 10:00~22:00\n'
#  'juso_detailAddress: \n'
#  'juso_roadAddrPart1: 경상남도 통영시 무전5길 37-41\n'
#  'juso_engAddr: 37-41, Mujeon 5-gil, Tongyeong-si, Gyeongsangnam-do\n'
#  'juso_bdNm: 향토집\n'
#  'juso_siNm: 경상남도\n'
#  'juso_sggNm: 통영시\n'
#  'juso_emdNm: 무전동\n'
#  'juso_liNm: \n'
#  'juso_rn: 무전5길\n'
#  'juso_buldMnnm: 37\n'
#  'juso_buldSlno: 41\n'
#  'review_review: 찜, 전, 국, 솥밥, 정식에 굴라면까지 다양한 굴요리가 있는 곳. 굴이 제철일 때는 짜지 않고 시원한 굴젓을 '
#  '맛볼 수 있다. 어느 요리에서든 굴 특유의 향기와 시원한 맛을 느낄 수 있다. 굴찜은 매콤함과 깔끔한 맛이 일품이다.\n'
#  'review_reviewSimple: 찜, 전, 국, 솥밥, 정식에 굴라면까지 다양한 굴요리가 있는 곳. 굴이 제철일 때는 짜지 않고 '
#  '시원한 굴젓을 맛볼 수 있다. 어느 요리에서든 굴 특유의 향기와 시원한 맛을 느낄 수 있다. 굴찜은 매콤함과 깔끔한 맛이 일품이다.\n'
#  'review_readerAppraisal: \n'
#  'etcInfo_interior: \n'
#  'etcInfo_seat: \n'
#  'etcInfo_room: \n'
#  'etcInfo_head: \n'
#  'etcInfo_branch: \n'
#  'defaultInfo_website:',
#  'foodDetailTypes: 비빔밥, 육회, 소불고기\n'
#  'headerInfo_nameKR: 천황식당\n'
#  'headerInfo_nameEN: \n'
#  'headerInfo_nameCN: \n'
#  'headerInfo_bookYear: 2024\n'
#  'headerInfo_ribbonType: 2\n'
#  'defaultInfo_chefName: \n'
#  'defaultInfo_phone: 055-741-2646\n'
#  'defaultInfo_openHours: \n'
#  'defaultInfo_closeHours: \n'
#  'defaultInfo_openHoursWeekend: \n'
#  'defaultInfo_closeHoursWeekend: \n'
#  'defaultInfo_dayOff: 연중무휴\n'
#  'defaultInfo_app2Yn: False\n'
#  'statusInfo_parking: 불가\n'
#  'statusInfo_creditCard: y\n'
#  'statusInfo_visit: 중앙광장교차로에서 진주중학교 방향으로 직진. 광미사거리에서 우회전 후 두번째 골목에서 좌회전\n'
#  'statusInfo_menu: 진주비빔밥(1만원), 석쇠불고기(250g 2만원), 육회(250g 3만원), 선지해장국, 콩나물국밥(각 '
#  '5천원)\n'
#  'statusInfo_priceRange: 1~2만원대\n'
#  'statusInfo_openDate: 1927년\n'
#  'statusInfo_businessHours: 06:00~21:00(마지막 주문 20:00)\n'
#  'juso_detailAddress: \n'
#  'juso_roadAddrPart1: 경상남도 진주시 촉석로207번길 3\n'
#  'juso_engAddr: 3, Chokseok-ro 207beon-gil, Jinju-si, Gyeongsangnam-do\n'
#  'juso_bdNm: \n'
#  'juso_siNm: 경상남도\n'
#  'juso_sggNm: 진주시\n'
#  'juso_emdNm: 대안동\n'
#  'juso_liNm: \n'
#  'juso_rn: 촉석로207번길\n'
#  'juso_buldMnnm: 3\n'
#  'juso_buldSlno: 0\n'
#  'review_review: 진주식 비빔밥 전문점. 고깃국물에 토렴한 밥에 호박나물, 무나물, 콩나물, 숙주나물, 시금치, 양배추, 무, '
#  '고사리 같은 부드러운 나물과 육회를 올려 낸다. 선짓국물이 같이 나오는 것도 진주비빔밥의 특징. 집에서 재래식으로 담근 간장과 된장, '
#  '고추장 등을 재료로 사용하는 것이 맛의 비결. 육회나 석쇠불고기를 곁들이면 더욱 좋다. 1927년 개업한 후, 3대째 가업을 이어 '
#  '한자리에서 비빔밥을 팔아온 전통과 관록을 자랑하는 맛집이다.\n'
#  'review_reviewSimple: 진주식 비빔밥 전문점. 고깃국물에 토렴한 밥에 호박나물, 무나물, 콩나물, 숙주나물, 시금치, '
#  '양배추, 무, 고사리 같은 부드러운 나물과 육회를 올려 낸다. 선짓국물이 같이 나오는 것도 진주비빔밥의 특징. 집에서 재래식으로 담근 '
#  '간장과 된장, 고추장 등을 재료로 사용하는 것이 맛의 비결. 육회나 석쇠불고기를 곁들이면 더욱 좋다. 1927년 개업한 후, 3대째 '
#  '가업을 이어 한자리에서 비빔밥을 팔아온 전통과 관록을 자랑하는 맛집이다.\n'
#  'review_readerAppraisal: "훌륭한 노포, 오래된 건물과 집기를 쓰지만 관리가 아주 잘 되어 있다. 접객 태도나 청결함을 '
#  '보면 오래도록 사랑받는 이유를 알 수 있다." “육회를 넣어서 만든 비빔밥은 한 끼 식사로 좋았다.” “비가 오는 날은 홀보다는 안쪽 '
#  '사랑채에서 드시기를 강추한다.” “대표적인 고향 맛집이다.” “비빔밥 고명이 화려한 집~”\n'
#  'etcInfo_interior: \n'
#  'etcInfo_seat: \n'
#  'etcInfo_room: \n'
#  'etcInfo_head: \n'
#  'etcInfo_branch: \n'
#  'defaultInfo_website: https://www.instagram.com/pnixresto/',
#  'foodDetailTypes: 프랑스식\n'
#  'headerInfo_nameKR: 화이트크리스마스\n'
#  'headerInfo_nameEN: White Christmas\n'
#  'headerInfo_nameCN: \n'
#  'headerInfo_bookYear: 2024\n'
#  'headerInfo_ribbonType: 2\n'
#  'defaultInfo_chefName: \n'
#  'defaultInfo_phone: 043-287-1225\n'
#  'defaultInfo_openHours: \n'
#  'defaultInfo_closeHours: \n'
#  'defaultInfo_openHoursWeekend: \n'
#  'defaultInfo_closeHoursWeekend: \n'
#  'defaultInfo_dayOff: 월요일 휴무\n'
#  'defaultInfo_app2Yn: False\n'
#  'statusInfo_parking: 가능\n'
#  'statusInfo_creditCard: y\n'
#  'statusInfo_visit: 복대중학교에서 청주현대병원 옆 골목으로 진입 후 직진하면 좌측\n'
#  'statusInfo_menu: 블루코스(25만원), 그린코스(32만원), 화이트코스(11만원)\n'
#  'statusInfo_priceRange: 25만원 이상\n'
#  'statusInfo_openDate: 2015년\n'
#  'statusInfo_businessHours: 12:00~15:300/17:30~22:00(마지막 주문 20:30)\n'
#  'juso_detailAddress: \n'
#  'juso_roadAddrPart1: 충청북도 청주시 흥덕구 비하로42번길 2\n'
#  'juso_engAddr: 2, Biha-ro 42beon-gil, Heungdeok-gu, Cheongju-si, '
#  'Chungcheongbuk-do\n'
#  'juso_bdNm: \n'
#  'juso_siNm: 충청북도\n'
#  'juso_sggNm: 청주시 흥덕구\n'
#  'juso_emdNm: 비하동\n'
#  'juso_liNm: \n'
#  'juso_rn: \n'
#  'juso_buldMnnm: 2\n'
#  'juso_buldSlno: 0\n'
#  'review_review: 충북을 대표하는 파인 다이닝 프렌치 레스토랑. 2000년 충주에서 시작하여 2015년에 청주로 옮겨 문을 '
#  '열었다. 정통 프렌치 요리를 코스로 즐길 수 있는 곳으로, 맛과 분위기에 대한 평이 모두 좋다. 고풍스러운 인테리어와 소품에서 오너의 '
#  '애정이 느껴진다. 10세 이하의 어린이는 출입할 수 없으며, 드레스코드는 포멀 슈트, 비즈니스 캐주얼, 스마트 캐주얼이다.\n'
#  'review_reviewSimple: 충북을 대표하는 파인 다이닝 프렌치 레스토랑. 2000년 충주에서 시작하여 2015년에 청주로 옮겨 '
#  '문을 열었다. 정통 프렌치 요리를 코스로 즐길 수 있는 곳으로, 맛과 분위기에 대한 평이 모두 좋다. 고풍스러운 인테리어와 소품에서 '
#  '오너의 애정이 느껴진다. 10세 이하의 어린이는 출입할 수 없으며, 드레스코드는 포멀 슈트, 비즈니스 캐주얼, 스마트 캐주얼이다.\n'
#  'review_readerAppraisal: \n'
#  'etcInfo_interior: \n'
#  'etcInfo_seat: \n'
#  'etcInfo_room: \n'
#  'etcInfo_head: \n'
#  'etcInfo_branch: \n'
#  'defaultInfo_website: https://www.instagram.com/whitechristmas_restaurant/',
#  'foodDetailTypes: 민물매운탕, 민물생선찜\n'
#  'headerInfo_nameKR: 괴산매운탕\n'
#  'headerInfo_nameEN: \n'
#  'headerInfo_nameCN: \n'
#  'headerInfo_bookYear: 2024\n'
#  'headerInfo_ribbonType: 2\n'
#  'defaultInfo_chefName: \n'
#  'defaultInfo_phone: 043-832-2838\n'
#  'defaultInfo_openHours: \n'
#  'defaultInfo_closeHours: \n'
#  'defaultInfo_openHoursWeekend: \n'
#  'defaultInfo_closeHoursWeekend: \n'
#  'defaultInfo_dayOff: 셋째 주 월요일 휴무\n'
#  'defaultInfo_app2Yn: False\n'
#  'statusInfo_parking: 가능\n'
#  'statusInfo_creditCard: y\n'
#  'statusInfo_visit: 괴강삼거리에서 괴강교 건너 직진하면 좌측\n'
#  'statusInfo_menu: 메기매운탕(각 소 4만원, 중 5만원, 대 6만원), 잡고기매운탕, 모래무지(각 소 5만원, 중 6만원, '
#  '대 7만원), 빠가사리매운탕(각 소 5만5천원, 중 6만5천원, 대 7만5천원)\n'
#  'statusInfo_priceRange: 2~5만원대\n'
#  'statusInfo_openDate: \n'
#  'statusInfo_businessHours: 09:00~20:30(마지막 주문 19:30)\n'
#  'juso_detailAddress: \n'
#  'juso_roadAddrPart1: 충청북도 괴산군 괴산읍 괴강로 248\n'
#  'juso_engAddr: 248, Goegang-ro, Goesan-eup, Goesan-gun, Chungcheongbuk-do\n'
#  'juso_bdNm: 괴산매운탕\n'
#  'juso_siNm: 충청북도\n'
#  'juso_sggNm: 괴산군\n'
#  'juso_emdNm: 괴산읍\n'
#  'juso_liNm: 대덕리\n'
#  'juso_rn: 괴강로\n'
#  'juso_buldMnnm: 248\n'
#  'juso_buldSlno: 0\n'
#  'review_review: 다양한 종류의 민물매운탕을 전문으로 하는 곳. 싱싱한 민물고기에서 우러 나오는 맛이 좋으며 팽이버섯과 채소도 '
#  '푸짐하게 올라간다. 자작하게 쪄서 나오는 쏘가리, 모래무지찜도 맛있기로 유명하다. 실내도 넓은 편.\n'
#  'review_reviewSimple: 다양한 종류의 민물매운탕을 전문으로 하는 곳. 싱싱한 민물고기에서 우러 나오는 맛이 좋으며 '
#  '팽이버섯과 채소도 푸짐하게 올라간다. 자작하게 쪄서 나오는 쏘가리, 모래무지찜도 맛있기로 유명하다. 실내도 넓은 편.\n'
#  'review_readerAppraisal: \n'
#  'etcInfo_interior: \n'
#  'etcInfo_seat: \n'
#  'etcInfo_room: \n'
#  'etcInfo_head: \n'
#  'etcInfo_branch: \n'
#  'defaultInfo_website:',
#  'foodDetailTypes: 민물매운탕, 민물생선찜\n'
#  'headerInfo_nameKR: 오십년할머니집\n'
#  'headerInfo_nameEN: \n'
#  'headerInfo_nameCN: \n'
#  'headerInfo_bookYear: 2024\n'
#  'headerInfo_ribbonType: 2\n'
#  'defaultInfo_chefName: \n'
#  'defaultInfo_phone: 043-832-2974\n'
#  'defaultInfo_openHours: \n'
#  'defaultInfo_closeHours: \n'
#  'defaultInfo_openHoursWeekend: \n'
#  'defaultInfo_closeHoursWeekend: \n'
#  'defaultInfo_dayOff: 연중무휴\n'
#  'defaultInfo_app2Yn: False\n'
#  'statusInfo_parking: 가능\n'
#  'statusInfo_creditCard: y\n'
#  'statusInfo_visit: 괴강삼거리에서 괴강교 건넌 후 좌측 길로 진입하면 우측\n'
#  'statusInfo_menu: 메기매운탕(2인 4만원, 3인 5만원, 4인 6만원), 빠가사리매운탕(2인 5만5천원, 3인 6만5천원, '
#  '4인 7만5천원), 쏘가리매운탕(2인 9만원, 3인 11만원, 4인 13만원)\n'
#  'statusInfo_priceRange: 2~5만원대\n'
#  'statusInfo_openDate: \n'
#  'statusInfo_businessHours: 08:00~20:00(마지막 주문 19:00)\n'
#  'juso_detailAddress: \n'
#  'juso_roadAddrPart1: 충청북도 괴산군 괴산읍 괴강로느티울길 8-1\n'
#  'juso_engAddr: 8-1, Goegang-ro neutiul-gil, Goesan-eup, Goesan-gun, '
#  'Chungcheongbuk-do\n'
#  'juso_bdNm: 괴강매운탕\n'
#  'juso_siNm: 충청북도\n'
#  'juso_sggNm: 괴산군\n'
#  'juso_emdNm: 괴산읍\n'
#  'juso_liNm: 대덕리\n'
#  'juso_rn: 괴강로느티울길\n'
#  'juso_buldMnnm: 8\n'
#  'juso_buldSlno: 1\n'
#  'review_review: 최고의 민물매운탕집으로 손꼽히는 유명한 곳. 생선조림도 유명했지만, 현재는 매운탕만 맛볼 수 있다. 주방은 '
#  '작지만 깔끔하며 탕에 들어가는 우거지는 직접 말려서 사용한다.\n'
#  'review_reviewSimple: 최고의 민물매운탕집으로 손꼽히는 유명한 곳. 생선조림도 유명했지만, 현재는 매운탕만 맛볼 수 있다. '
#  '주방은 작지만 깔끔하며 탕에 들어가는 우거지는 직접 말려서 사용한다.\n'
#  'review_readerAppraisal: “매운탕은 빠가사리, 조림은 쏘가리가 좋은데 조림은 시간이 많이 걸리니 미리 주문해 두는 게 '
#  '요령.”\n'
#  'etcInfo_interior: \n'
#  'etcInfo_seat: \n'
#  'etcInfo_room: \n'
#  'etcInfo_head: \n'
#  'etcInfo_branch: \n'
#  'defaultInfo_website:',
#  'foodDetailTypes: 닭볶음탕, 민물매운탕, 민물새우\n'
#  'headerInfo_nameKR: 중앙탑초가집\n'
#  'headerInfo_nameEN: \n'
#  'headerInfo_nameCN: \n'
#  'headerInfo_bookYear: 2024\n'
#  'headerInfo_ribbonType: 2\n'
#  'defaultInfo_chefName: \n'
#  'defaultInfo_phone: 043-845-6789\n'
#  'defaultInfo_openHours: 10:00\n'
#  'defaultInfo_closeHours: 21:00\n'
#  'defaultInfo_openHoursWeekend: \n'
#  'defaultInfo_closeHoursWeekend: \n'
#  'defaultInfo_dayOff: 수요일 휴무\n'
#  'defaultInfo_app2Yn: False\n'
#  'statusInfo_parking: 가능\n'
#  'statusInfo_creditCard: y\n'
#  'statusInfo_visit: 루암교차로에서 중앙탑사적공원 방향으로 직진하면 우측\n'
#  'statusInfo_menu: 새뱅이매운탕(소 3만5천원, 중 4만5천원, 대 5만5천원), 쏘가리매운탕(시가), 빠가매운탕(소 5만원, '
#  '중 6만원, 대 7만원), 메기매운탕(소 4만5천원, 중 5만5천원, 대 6만5천원), 오리주물럭(500g 4만5천원, 800g '
#  '6만5천원), 한방토종닭볶음탕(6만5천원)\n'
#  'statusInfo_priceRange: 2~5만원대\n'
#  'statusInfo_openDate: 2003년\n'
#  'statusInfo_businessHours: 11:00~21:00(마지막 주문 20:00) | 토, 일요일 '
#  '11:00~15:00/17:00~21:00(마지막 주문 20:00)\n'
#  'juso_detailAddress: \n'
#  'juso_roadAddrPart1: 충청북도 충주시 중앙탑면 중앙탑길 10\n'
#  'juso_engAddr: 10, Jungangtap-gil, Jungangtap-myeon, Chungju-si, '
#  'Chungcheongbuk-do\n'
#  'juso_bdNm: \n'
#  'juso_siNm: 충청북도\n'
#  'juso_sggNm: 충주시\n'
#  'juso_emdNm: 중앙탑면\n'
#  'juso_liNm: 루암리\n'
#  'juso_rn: 중앙탑길\n'
#  'juso_buldMnnm: 10\n'
#  'juso_buldSlno: 0\n'
#  'review_review: 매운탕과 닭볶음탕이 유명한 집. 한방 재료를 넣어 끓인 닭백숙을 비롯해 민물새우의 일종인 새뱅이매운탕이 대표 '
#  '메뉴로 통한다. 충주호를 둘러싼 중앙공원 내에 있는 200년 된 초가집에 위치했으나 초가집이 유형문화재로 지정되면서 공원 밖으로 '
#  '이전하였다.\n'
#  'review_reviewSimple: 매운탕과 닭볶음탕이 유명한 집. 한방 재료를 넣어 끓인 닭백숙을 비롯해 민물새우의 일종인 '
#  '새뱅이매운탕이 대표 메뉴로 통한다. 충주호를 둘러싼 중앙공원 내에 있는 200년 된 초가집에 위치했으나 초가집이 유형문화재로 지정되면서 '
#  '공원 밖으로 이전하였다.\n'
#  'review_readerAppraisal: \n'
#  'etcInfo_interior: \n'
#  'etcInfo_seat: \n'
#  'etcInfo_room: \n'
#  'etcInfo_head: \n'
#  'etcInfo_branch: \n'
#  'defaultInfo_website:',
#  'foodDetailTypes: 소떡갈비\n'
#  'headerInfo_nameKR: 청풍떡갈비\n'
#  'headerInfo_nameEN: \n'
#  'headerInfo_nameCN: \n'
#  'headerInfo_bookYear: 2024\n'
#  'headerInfo_ribbonType: 2\n'
#  'defaultInfo_chefName: \n'
#  'defaultInfo_phone: 043-644-1600\n'
#  'defaultInfo_openHours: 09:30\n'
#  'defaultInfo_closeHours: 20:00\n'
#  'defaultInfo_openHoursWeekend: \n'
#  'defaultInfo_closeHoursWeekend: \n'
#  'defaultInfo_dayOff: 연중무휴\n'
#  'defaultInfo_app2Yn: False\n'
#  'statusInfo_parking: 가능\n'
#  'statusInfo_creditCard: y\n'
#  'statusInfo_visit: 청풍랜드에서 청풍리조트레이크호텔 지나 직진하면 우측\n'
#  'statusInfo_menu: 숯불한우떡갈비(230g 2만6천원), 숯불마늘한우떡갈비(230g 2만9천원), 두부김치, 도토리묵무침(각 '
#  '1만7천원)\n'
#  'statusInfo_priceRange: 2~5만원대\n'
#  'statusInfo_openDate: \n'
#  'statusInfo_businessHours: 09:30~20:00 | 토, 일요일 10:00~20:00(마지막 주문 19:00)\n'
#  'juso_detailAddress: \n'
#  'juso_roadAddrPart1: 충청북도 제천시 금성면 청풍호로 1643\n'
#  'juso_engAddr: 1643, Cheongpungho-ro, Geumseong-myeon, Jecheon-si, '
#  'Chungcheongbuk-do\n'
#  'juso_bdNm: \n'
#  'juso_siNm: 충청북도\n'
#  'juso_sggNm: 제천시\n'
#  'juso_emdNm: 금성면\n'
#  'juso_liNm: 성내리\n'
#  'juso_rn: 청풍호로\n'
#  'juso_buldMnnm: 1643\n'
#  'juso_buldSlno: 0\n'
#  'review_review: 제천 일대에서 떡갈비로 유명한 집. 철판에 구워 내오는 떡갈비를 비롯해 제천 황기와 한약재로 숙성한 양념을 '
#  '사용하는 한방떡갈비, 단양 마늘을 사용하는 마늘떡갈비 등을 선보인다. 떡갈비와 함께 구수한 된장찌개와 맛깔스러운 반찬이 나오며 기본 2인 '
#  '이상 주문해야 한다.\n'
#  'review_reviewSimple: 제천 일대에서 떡갈비로 유명한 집. 철판에 구워 내오는 떡갈비를 비롯해 제천 황기와 한약재로 숙성한 '
#  '양념을 사용하는 한방떡갈비, 단양 마늘을 사용하는 마늘떡갈비 등을 선보인다. 떡갈비와 함께 구수한 된장찌개와 맛깔스러운 반찬이 나오며 '
#  '기본 2인 이상 주문해야 한다.\n'
#  'review_readerAppraisal: \n'
#  'etcInfo_interior: \n'
#  'etcInfo_seat: \n'
#  'etcInfo_room: \n'
#  'etcInfo_head: \n'
#  'etcInfo_branch: \n'
#  'defaultInfo_website:',
#  'foodDetailTypes: 민물매운탕\n'
#  'headerInfo_nameKR: 박쏘가리\n'
#  'headerInfo_nameEN: \n'
#  'headerInfo_nameCN: \n'
#  'headerInfo_bookYear: 2024\n'
#  'headerInfo_ribbonType: 2\n'
#  'defaultInfo_chefName: \n'
#  'defaultInfo_phone: 043-421-8825\n'
#  'defaultInfo_openHours: 10:00\n'
#  'defaultInfo_closeHours: 21:00\n'
#  'defaultInfo_openHoursWeekend: \n'
#  'defaultInfo_closeHoursWeekend: \n'
#  'defaultInfo_dayOff: 연중무휴\n'
#  'defaultInfo_app2Yn: False\n'
#  'statusInfo_parking: 가능\n'
#  'statusInfo_creditCard: y\n'
#  'statusInfo_visit: 단양시외버스공용터미널에서 GS칼텍스 자동세차장 옆길로 직진하면 좌측\n'
#  'statusInfo_menu: 쏘가리회(1kg 20만원), 쏘가리매운탕(2인 8만원, 3인 11만원, 4인 13만원), 빠가사리매운탕, '
#  '잡고기매운탕(2인 6만원, 3인 7만원, 4인 8만원), 메기매운탕(2인 5만원, 3인 6만원, 4인 7만원), 떡갈비정식(2인 이상, '
#  '1인 2만원)\n'
#  'statusInfo_priceRange: 2~5만원대\n'
#  'statusInfo_openDate: \n'
#  'statusInfo_businessHours: 10:00~21:00(마지막 주문 19:30)\n'
#  'juso_detailAddress: \n'
#  'juso_roadAddrPart1: 충청북도 단양군 단양읍 수변로 85\n'
#  'juso_engAddr: 85, Subyeon-ro, Danyang-eup, Danyang-gun, Chungcheongbuk-do\n'
#  'juso_bdNm: 박쏘가리\n'
#  'juso_siNm: 충청북도\n'
#  'juso_sggNm: 단양군\n'
#  'juso_emdNm: 단양읍\n'
#  'juso_liNm: 도전리\n'
#  'juso_rn: 수변로\n'
#  'juso_buldMnnm: 85\n'
#  'juso_buldSlno: 0\n'
#  'review_review: 민물매운탕을 전문으로 하며 쏘가리매운탕이 유명하다. 남한강에서 잡은 쏘가리를 사용하며 쏘가리가 있는지 미리 '
#  '확인해 보고 가는 것이 좋다. 남한강변을 바라보며 먹는 매운탕 맛이 일품. 단양마늘을 사용한 떡갈비도 맛이 좋다.\n'
#  'review_reviewSimple: 민물매운탕을 전문으로 하며 쏘가리매운탕이 유명하다. 남한강에서 잡은 쏘가리를 사용하며 쏘가리가 '
#  '있는지 미리 확인해 보고 가는 것이 좋다. 남한강변을 바라보며 먹는 매운탕 맛이 일품. 단양마늘을 사용한 떡갈비도 맛이 좋다.\n'
#  'review_readerAppraisal: “단양마늘떡갈비 맛이 좋아요.” “맛도 맛인데 사장님이 서비스에 많이 신경쓰는 느낌이 들었다. '
#  '사장님이 그러니 종업원도 모두 친절.” “정말 끝내주는 맛이더군요, 국물 한 방울 남김없이 다 먹고 나왔습니다. 민물매운탕을 좋아하여 '
#  '여러 곳 다녀봤지만 최고의 쏘가리매운탕입니다.”\n'
#  'etcInfo_interior: \n'
#  'etcInfo_seat: \n'
#  'etcInfo_room: \n'
#  'etcInfo_head: \n'
#  'etcInfo_branch: \n'
#  'defaultInfo_website:',
#  'foodDetailTypes: 게장, 꽃게\n'
#  'headerInfo_nameKR: 장수꽃게장\n'
#  'headerInfo_nameEN: \n'
#  'headerInfo_nameCN: \n'
#  'headerInfo_bookYear: 2024\n'
#  'headerInfo_ribbonType: 2\n'
#  'defaultInfo_chefName: \n'
#  'defaultInfo_phone: 041-355-3014\n'
#  'defaultInfo_openHours: 11:00\n'
#  'defaultInfo_closeHours: 21:00\n'
#  'defaultInfo_openHoursWeekend: \n'
#  'defaultInfo_closeHoursWeekend: \n'
#  'defaultInfo_dayOff: 둘째, 넷째 주 월요일 휴무\n'
#  'defaultInfo_app2Yn: False\n'
#  'statusInfo_parking: 가능\n'
#  'statusInfo_creditCard: \n'
#  'statusInfo_visit: 파크빌아파트 맞은편\n'
#  'statusInfo_menu: 꽃게장(1인 3만원), 꽃게무침(3만1천원), 꽃게탕(소 5만8천원, 중 6만8천원, 대 8만원), '
#  '꽃게찜, 낙지볶음(각 시가)\n'
#  'statusInfo_priceRange: 2~5만원대\n'
#  'statusInfo_openDate: \n'
#  'statusInfo_businessHours: 11:00~15:00/17:00~21:00\n'
#  'juso_detailAddress: \n'
#  'juso_roadAddrPart1: 충청남도 당진시 당진중앙2로 344\n'
#  'juso_engAddr: 344, Dangjinjungang 2-ro, Dangjin-si, Chungcheongnam-do\n'
#  'juso_bdNm: 장수꽃게장전문점\n'
#  'juso_siNm: 충청남도\n'
#  'juso_sggNm: 당진시\n'
#  'juso_emdNm: 원당동\n'
#  'juso_liNm: \n'
#  'juso_rn: 당진중앙2로\n'
#  'juso_buldMnnm: 344\n'
#  'juso_buldSlno: 0\n'
#  'review_review: 꽃게장이 맛있는 집으로 현지인에게 많이 알려져 있다. 양파, 대파, 청양고추 등을 넣은 채소 육수와 '
#  '까나리액젓, 간장 등을 이용해 간장게장을 담근다. 채소 육수가 많이 들어가 게장이 짜지 않은 것이 특징이다. 이외에도 꽃게탕, 꽃게찜, '
#  '꽃게범벅 등 다양한 꽃게 요리를 선보인다.\n'
#  'review_reviewSimple: 꽃게장이 맛있는 집으로 현지인에게 많이 알려져 있다. 양파, 대파, 청양고추 등을 넣은 채소 육수와 '
#  '까나리액젓, 간장 등을 이용해 간장게장을 담근다. 채소 육수가 많이 들어가 게장이 짜지 않은 것이 특징이다. 이외에도 꽃게탕, 꽃게찜, '
#  '꽃게범벅 등 다양한 꽃게 요리를 선보인다.\n'
#  'review_readerAppraisal: \n'
#  'etcInfo_interior: \n'
#  'etcInfo_seat: \n'
#  'etcInfo_room: \n'
#  'etcInfo_head: \n'
#  'etcInfo_branch: \n'
#  'defaultInfo_website:',
#  'foodDetailTypes: 페이스트리\n'
#  'headerInfo_nameKR: 크레미엘\n'
#  'headerInfo_nameEN: PATISSERIE CREMIEL\n'
#  'headerInfo_nameCN: \n'
#  'headerInfo_bookYear: 2025\n'
#  'headerInfo_ribbonType: 2\n'
#  'defaultInfo_chefName: 지수정, 미카엘\n'
#  'defaultInfo_phone: \n'
#  'defaultInfo_openHours: \n'
#  'defaultInfo_closeHours: \n'
#  'defaultInfo_openHoursWeekend: \n'
#  'defaultInfo_closeHoursWeekend: \n'
#  'defaultInfo_dayOff: 화, 수요일 휴무\n'
#  'defaultInfo_app2Yn: False\n'
#  'statusInfo_parking: 가능(협소, 건물 뒤편 15분 이용 가능)\n'
#  'statusInfo_creditCard: y\n'
#  'statusInfo_visit: \n'
#  'statusInfo_menu: 크루아상, 초코브리오슈(각 5천5백원), 팽오쇼콜라(6천원), 아몬드크루아상(7천원), 퀸아망(5천원), '
#  '카늘레(4천원)\n'
#  'statusInfo_priceRange: 1만원 미만\n'
#  'statusInfo_openDate: 2022년\n'
#  'statusInfo_businessHours: 11:00~19:00\n'
#  'juso_detailAddress: 디와이빌딩\n'
#  'juso_roadAddrPart1: 서울특별시 서초구 양재천로21길 3\n'
#  'juso_engAddr: 3, Yangjaecheon-ro 21-gil, Seocho-gu, Seoul\n'
#  'juso_bdNm: 디와이빌딩\n'
#  'juso_siNm: 서울특별시\n'
#  'juso_sggNm: 서초구\n'
#  'juso_emdNm: 양재동\n'
#  'juso_liNm: \n'
#  'juso_rn: \n'
#  'juso_buldMnnm: 3\n'
#  'juso_buldSlno: 0\n'
#  'review_review: 프랑스인 남편과 한국인 아내의 파티시에 부부가 운영하는 파티세리 숍. 프랑스인이 직접 만든 페이스트리 종류를 '
#  '선보인다. 시그니처인 크루아상은 시트를 직접 반죽하여 구우며, 무항생제 달걀, 프랑스산 밀가루와 버터 등 고급 원재료를 사용하기 때문에 '
#  '가격대가 있는 편이다.\n'
#  'review_reviewSimple: 프랑스인 남편과 한국인 아내의 파티시에 부부가 운영하는 파티세리 숍. 프랑스인이 직접 만든 '
#  '페이스트리 종류를  선보인다. 시그니처인 크루아상은 시트를 직접 반죽하여 구우며, 무항생제 달걀, 프랑스산 밀가루와 버터 등 고급 '
#  '원재료를 사용하기 때문에 가격대가 있는 편이다.\n'
#  'review_readerAppraisal: \n'
#  'etcInfo_interior: \n'
#  'etcInfo_seat: \n'
#  'etcInfo_room: \n'
#  'etcInfo_head: \n'
#  'etcInfo_branch: \n'
#  'defaultInfo_website:']

# %%
model = ChatOpenAI(model="gpt-4o-mini")


#########################################################
# InMemoryVectorStore 생성
#########################################################

store = {} 
# key : session_id, value : InMemoryChatMessageHistory ( session id별로 저장하는 기능이 없다.)

def get_session_history(session_id):
    '''
    ChatMessageHistory 객체를 반환하는 함수
    store에서 session_id의 History객체를 찾아서 반환, 없으면 생성해서 store 저장
    '''     
    
    if session_id not in store:
        store[session_id] = InMemoryChatMessageHistory()
    
    return store[session_id]



runnable = prompt_template | model

# Chain + ChatMessageHJistory => 대화 + 메세지 저장관리
chain = RunnableWithMessageHistory(
    runnable= runnable, # chain 객체(RunnableSequence)
    get_session_history=get_session_history, # session_id의 ChatMessageHistory객체를 반환하는 함수.
    input_messages_key= 'query',    # prompt_template에 입력 내용을 넣을 변수명.
    history_messages_key='history'  # prompt_template에 대화내역을 넣어줄 변수명.
)

########################################
# 질문을 Embedding Vector로 변환
########################################

query = "How much the bus ticket price?"
embedding_query = embedding_model.embed_query(query) # 한문장 변환.
print(type(embedding_query), len(embedding_query))


############################################################
# retriever
############################################################


# Retriever 생성 - "Map Reduce" 방식
retriever = vector_store.as_retriever(
    search_type="mmr",
    search_kwargs={"k":5, "fetch_k":10, "lambda_mult":0.5, "filter":{"source":"data/bluer.txt"} }
)


map_doc_prompt = ChatPromptTemplate.from_messages([
    ("system",  """
Use the following portion of a long document to see if any of the text is relevant to answer the question. 
Return any relevant text verbatim. If there is no relevant text, return : ''
-------
{context}
"""),
    ("human", "{question}"),
])



# 질문 - 문서 관련성을 비교하는 체인
map_doc_chain = map_doc_prompt | model
# map_doc_chain.invoke({"context":"사과는 맛있어요?", "question":"올림픽 종목에 대해 설명해줘."})
# map_doc_chain.invoke({"context":"올림픽에는 300개의 종목이 있습니다.", "question":"올림픽 종목에 대해 설명해줘."})

## retriever로 문서 조회 -> map_doc_chain으로 관련문서를 찾기 
def map_doc(inputs):
    """
    Runnable로 정의할 함수. 
    retriever가 조회한 문서들과 question을 받아서 map_doc_chain을 이용해 관련성을 확인한다.
    관련된 문서 내용만 모아서 반환.
    parameter
        inputs: dict[documents: list[Document], question:질문]. {"documents":retriever, "question":RunnablePassthrough()}
    """
    docs = inputs["documents"]   # list[Document, Document, Document, ...]
    question= inputs["question"] # str
    context = "" # 질문과 관련된 내용들만 모아 놓을 변수.
    for doc in docs:
        # Document와 question을 map_doc_chain에 전달해서 관련된 내용인지 확인.
        res = map_doc_chain.invoke({"context":doc.page_content, "question":question})
        context += res.content+"\n\n" # AIMessage.content

    return context

map_reduce_chain = {"documents":retriever, "question":RunnablePassthrough()} | RunnableLambda(map_doc)

# %% [markdown]
# #### Map_reduce 확인

# %%
r = map_reduce_chain.invoke("리본 두개 이상인 서울 한식집을 알려주세요.")
print(r)

# %% [markdown]
# #### 최종 답변

# %%
final_prompt = ChatPromptTemplate.from_messages(
    [
        (
            "system",
            """
            Given the following extracted parts of a long document and a question, create a final answer. 
            If you don't know the answer, just say that you don't know. Don't try to make up an answer.
            ------
            {context}
            """,
        ),
        ("human", "{question}"),
    ]
)

chain = ({"context":map_reduce_chain, "question":RunnablePassthrough()} 
        | final_prompt
        | model
        | StrOutputParser())
