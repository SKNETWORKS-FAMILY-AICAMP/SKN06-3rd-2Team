# %% [markdown]
# # 1. RAG chain 구현 구문

# %%
from langchain_community.document_loaders import TextLoader
from langchain.text_splitter import RecursiveCharacterTextSplitter
from langchain_openai import OpenAIEmbeddings, ChatOpenAI
from langchain_chroma import Chroma
from langchain.prompts import ChatPromptTemplate, ChatMessagePromptTemplate, MessagesPlaceholder
from langchain_core.runnables import RunnablePassthrough, RunnableWithMessageHistory
from langchain_community.tools import TavilySearchResults
from langchain_core.documents import Document

# 평가 알로리즘 모듈
from langchain_core.output_parsers import JsonOutputParser,StrOutputParser
from langchain import hub
from langchain_core.runnables import RunnablePassthrough, RunnableLambda

from ragas import EvaluationDataset, RunConfig, evaluate
from ragas.metrics import LLMContextRecall, Faithfulness, LLMContextPrecisionWithReference, AnswerRelevancy

from ragas.llms import LangchainLLMWrapper
from ragas.embeddings import LangchainEmbeddingsWrapper

from pydantic import BaseModel, Field


# 메모리 관련 모듈
from langchain_core.chat_history import InMemoryChatMessageHistory

from langchain.chains import RetrievalQA
from langchain.schema import AIMessage, HumanMessage




from textwrap import dedent
from operator import itemgetter

from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %%
########################################################
# config 목록
########################################################
COLLECTION_NAME = "bluer_db_openai"
PERSIST_DIRECTORY = "vector_store/chroma/bluer_db"
EMBEDDING_MODEL_NAME = "text-embedding-3-small"
embedding_model = OpenAIEmbeddings(model=EMBEDDING_MODEL_NAME)
MODEL_NAME = 'gpt-4o-mini'


########################################################
# vector_db에서 데이터 불러오기
########################################################

# vector store 연결
vector_store = Chroma(
    embedding_function=embedding_model,
    collection_name=COLLECTION_NAME,
    persist_directory=PERSIST_DIRECTORY
)

# 저장된 데이터 내용 확인
documents = vector_store._collection.get()['documents']
metadatas = vector_store._collection.get()['metadatas']

print(f"Documents: {documents[:5]}") 
print(f"Metadatas: {metadatas[:5]}")
# Out:
# Documents: ['foodDetailTypes: 스시\nheaderInfo_nameKR: 스시조\nheaderInfo_nameEN: Sushi Cho\nheaderInfo_nameCN: \nheaderInfo_bookYear: 2025\nheaderInfo_ribbonType: 3\ndefaultInfo_chefName: \ndefaultInfo_phone: 02-317-0373\ndefaultInfo_openHours: \ndefaultInfo_closeHours: \ndefaultInfo_openHoursWeekend: \ndefaultInfo_closeHoursWeekend: \ndefaultInfo_dayOff: 연중무휴\ndefaultInfo_app2Yn: False\nstatusInfo_parking: 가능\nstatusInfo_creditCard: y\nstatusInfo_visit: 웨스틴조선호텔 20층\nstatusInfo_menu: 런치(Hall)(1인 15만5천원~20만5천원), 디너(Hall)(1인 19만4천원~33만원), 스시조회덮밥(10만원, 프리미엄 13만원), 복가라아게돌솥밥(12만원), 굴돌솥밥(7만8천원), 활새우튀김(11만원), 조리장특선모둠스시(14만5천원)\nstatusInfo_priceRange: 25만원 이상\nstatusInfo_openDate: 2008년\nstatusInfo_businessHours: 12:00~15:00/17:30~22:00(마지막 주문 21:30)\njuso_detailAddress: 웨스틴조선호텔 20층\njuso_roadAddrPart1: 서울특별시 중구 소공로 106\njuso_engAddr: 106, Sogong-ro, Jung-gu, Seoul\njuso_bdNm: 서울 웨스틴조선호텔\njuso_siNm: 서울특별시\njuso_sggNm: 중구\njuso_emdNm: 소공동\njuso_liNm: \njuso_rn: 소공로\njuso_buldMnnm: 106\njuso_buldSlno: 0\nreview_review: 서울 최고의 일식당 중 하나로 꼽히는 곳. 최상의 재료를 사용한 최고급 일본 요리를 맛볼 수 있다. 국내 최대 길이를 자랑하는 히노키 다이에서 맛보는 스시가 특히 인기가 높다. 신라호텔의 아리아께와 함께 우리나라 스시의 양대산맥을 이루고 있다. 최근에는 일본의 요시타케와 기술제휴로 적초샤리와 부드럽게 숙성된 네타를 사용하는 등 독특한 스타일을 선보이고 있다.\nreview_reviewSimple: 서울 최고의 일식당 중 하나로 꼽히는 곳. 최상의 재료를 사용한 최고급 일본 요리를 맛볼 수 있다. 국내 최대 길이를 자랑하는 히노키 다이에서 맛보는 스시가 특히 인기가 높다. 신라호텔의 아리아께와 함께 우리나라 스시의 양대산맥을 이루고 있다.\nreview_readerAppraisal: “단품 중에는 의외로 맛있는 고등어소바가 특미.” “신선한 1등급 제철 재료를 사용하는 스시조. 평생 잊지 못할 맛을 맛본 것 같습니다.” “최고급 호텔 내의 스시야인 만큼, 재료의 질과 다양성에서부터 큰 강점이 있음. 거기에 기본기도 탄탄하지만 여러 가지 변주도 가능한 손맛과 최고급 호텔다운 서비스까지 갖춤.” “가장 높은 층에 자리한 만큼 좋은 경치와 분위기를 자랑한다.” “스시집 중 최상의 맛과 서비스를 느낄 수 있다.” “중요한 접대가 필요한 비즈니스나 기념일에 스시가 생각난다면 한 번쯤 도전해볼 만한 최고급 식당.” “이런 집에서 맛을 논하면 바보거나 맛의 고수다.” “언제 가더라도 그 가격이 비싸지 않다는 것을 느끼게 해주는 최고의 스시집입니다.”\netcInfo_interior: 모던/스타일리시\netcInfo_seat: 97석, 스시카운터 9석\netcInfo_room: 8개(4~5석, 다다미방 2개, 8~14석), 별실 이용시 룸차지 3만원\netcInfo_head: \netcInfo_branch: \ndefaultInfo_website:', "foodDetailTypes: 프랑스식\nheaderInfo_nameKR: 레스쁘아\nheaderInfo_nameEN: L'Espoir du Hibou\nheaderInfo_nameCN: \nheaderInfo_bookYear: 2025\nheaderInfo_ribbonType: 3\ndefaultInfo_chefName: 임기학\ndefaultInfo_phone: 02-517-6034\ndefaultInfo_openHours: \ndefaultInfo_closeHours: \ndefaultInfo_openHoursWeekend: \ndefaultInfo_closeHoursWeekend: \ndefaultInfo_dayOff: 화요일, 명절 휴무\ndefaultInfo_app2Yn: False\nstatusInfo_parking: 발레 파킹\nstatusInfo_creditCard: y\nstatusInfo_visit: \nstatusInfo_menu: 런치코스(10만원), 클래식코스(18만원), 시즌코스(20만원)\nstatusInfo_priceRange: 15~25만원대\nstatusInfo_openDate: 2008년\nstatusInfo_businessHours: 12:00~15:00/17:30~22:00\njuso_detailAddress: \njuso_roadAddrPart1: 서울특별시 강남구 도산대로59길 16\njuso_engAddr: 16 Dosan-daero 59-gil, Gangnam-gu, Seoul\njuso_bdNm: \njuso_siNm: 서울특별시\njuso_sggNm: 강남구\njuso_emdNm: 청담동\njuso_liNm: \njuso_rn: 선릉로152길\njuso_buldMnnm: 16\njuso_buldSlno: 0\nreview_review: 비스트로를 표방하는 클래식 프렌치 레스토랑. 정통 프렌치 레시피를 기반으로 한국인의 입맛에 맞추어 내는 임기학 셰프의 노련한 솜씨를 맛볼 수 있다. 10종이 넘는 테린과 파테가 나오는 모둠샤퀴테리는 코스를 시작하기 전에 와인과 함께 즐기면 좋다. 코스 외에도 단품 메뉴가 많이 준비되어 있다. 봄과 가을에는 테라스 좌석의 분위기가 끝내준다.\nreview_reviewSimple: 비스트로를 표방하는 클래식 프렌치 레스토랑. 정통 프렌치 레시피를 기반으로 한국인의 입맛에 맞추어 내는 임기학 셰프의 노련한 솜씨를 맛볼 수 있다. 10종이 넘는 테린과 파테가 나오는 모둠샤퀴테리는 코스를 시작하기 전에 와인과 함께 즐기면 좋다. 코스 외에도 단품 메뉴가 많이 준비되어 있다. 봄과 가을에는 테라스 좌석의 분위기가 끝내준다.\nreview_readerAppraisal: “명실상부 최고의 비스트로.” “전채요리 하나하나에 빠짐이 없다.” “정말 맛있는 프렌치 요리를 즐기고 싶다면 반드시 가봐야 할 곳.” “요리 하나하나 힘이 있습니다. 빈틈없는 훌륭한 곳입니다. 서울에서 손꼽을 프렌치 레스토랑입니다.” “절정에 이르렀다는 표현이 이해가 되는 레스토랑. 맛도 맛이지만 다른 곳에 비해 양이 많다는 점도 가격 대비 만족도가 높은 이유.” “기본적인 어니언 수프가 참 맛있었습니다.” “가격 대비 이 정도의 프렌치를 가볍게 즐길 수 있는 곳은 많지 않다.” “재료 본연의 맛을 제대로 느끼게 해주었던, 다시 가고 싶게 만든 프렌치 비스트로.” “가격도 맛도 사로잡는 최고의 프렌치 비스트로다.” “아주 좋다.”\netcInfo_interior: \netcInfo_seat: 40\netcInfo_room: \netcInfo_head: \netcInfo_branch: \ndefaultInfo_website: https://www.instagram.com/lespoirduhibou/", 'foodDetailTypes: 소갈비, 소고기구이\nheaderInfo_nameKR: 낙원\nheaderInfo_nameEN: \nheaderInfo_nameCN: 樂源\nheaderInfo_bookYear: 2025\nheaderInfo_ribbonType: 3\ndefaultInfo_chefName: \ndefaultInfo_phone: 02-2660-9010\ ...
# Metadatas: [{'row': 0, 'source': 'data/cleaned_restaurants.csv'}, {'row': 1, 'source': 'data/cleaned_restaurants.csv'}, {'row': 2, 'source': 'data/cleaned_restaurants.csv'}, {'row': 3, 'source': 'data/cleaned_restaurants.csv'}, {'row': 4, 'source': 'data/cleaned_restaurants.csv'}]

# %%
QUERY = " 강남구 근처에 가족이나 연인과 함께 가기 좋은 음식점 세 곳만 추천해줘"  


# embedding_model = OpenAIEmbeddings(model=EMBEDDING_MODEL_NAME)


vector_store = Chroma(
    embedding_function=embedding_model,
    collection_name=COLLECTION_NAME,
    persist_directory=PERSIST_DIRECTORY
)


# GPT Model 생성
model = ChatOpenAI(
    model=MODEL_NAME,
    temperature=0 
)


# Retriever 생성 - "Map Reduce" 방식 - 더 정확한 답변
retriever = vector_store.as_retriever(
    search_type="mmr",
    search_kwargs={"k":5, "fetch_k":10, "lambda_mult":0.5}
)


# Prompt Template 생성
prompt_template = ChatPromptTemplate.from_messages([
    ("system", "당신은 한국의 블루리본 서베이 전문가입니다. 질문에 자세히 답해주세요."),
    ("human", "{question}")
])


#########################################
# Chain 생성
#########################################

retrieval_qa = RetrievalQA.from_chain_type(
    llm=model,
    retriever=retriever,
    return_source_documents=True,  # Include source documents in response
)


response = retrieval_qa({"query": QUERY})

print("응답:", response["result"])
# Out:
# 응답: 강남구 근처에 가족이나 연인과 함께 가기 좋은 음식점 세 곳은 다음과 같습니다:
#
# 1. **고메고메**
#    - 주소: 서울특별시 강남구 삼성로85길 38
#    - 전화: 02-555-9567
#    - 특징: 참숯을 넣은 항아리에 숙성한 고기를 구워 먹는 곳으로, 모던한 인테리어와 함께 다양한 고기 메뉴를 즐길 수 있습니다.
#
# 2. **상하이**
#    - 주소: 서울특별시 강남구 논현로 508 (GS강남타워 B1층)
#    - 전화: 02-2005-1003
#    - 특징: 1930년대 상하이의 고급 레스토랑 분위기를 콘셉트로 하며, 광동식과 매콤한 사천식 요리를 주로 선보입니다. 고급스러운 분위기에서 중식을 즐길 수 있습니다.
#
# 3. **소호정**
#    - 주소: 서울특별시 서초구 논현로 27
#    - 전화: 02-579-7282
#    - 특징: 경상도 안동 지방의 반가 음식인 안동 국시를 맛볼 수 있는 곳으로, 다양한 한식 메뉴가 있어 가족과 함께 가기 좋습니다.
#
# 이 세 곳은 모두 가족이나 연인과 함께 즐기기에 적합한 분위기와 메뉴를 제공합니다.

# %%
#########################################################
# InMemoryVectorStore 구문 추가 코드 - 미완성
#########################################################
QUERY = " 강남구 근처에 가족이나 연인과 함께 가기 좋은 음식점 세 곳만 추천해줘"  


# embedding_model = OpenAIEmbeddings(model=EMBEDDING_MODEL_NAME)


vector_store = Chroma(
    embedding_function=embedding_model,
    collection_name=COLLECTION_NAME,
    persist_directory=PERSIST_DIRECTORY
)


# GPT Model 생성
model = ChatOpenAI(
    model=MODEL_NAME,
    temperature=0 
)


# Retriever 생성 - "Map Reduce" 방식 - 더 정확한 답변
retriever = vector_store.as_retriever(
    search_type="mmr",
    search_kwargs={"k":5, "fetch_k":10, "lambda_mult":0.5}
)


# Prompt Template 생성
prompt_template = ChatPromptTemplate(
    [
        ("system", "당신은 한국의 블루리본 서베이 전문가입니다. 질문에 자세히 답해주세요."),
        MessagesPlaceholder("history"), 
        ("human", "{query}")
    ]
)

prompt_template = ChatPromptTemplate.from_messages([
    ("system", "당신은 한국의 블루리본 서베이 전문가입니다. 질문에 자세히 답해주세요."),
    ("human", "{question}")
])


#########################################
# Chain 생성
#########################################

retrieval_qa = RetrievalQA.from_chain_type(
    llm=model,
    retriever=retriever,
    return_source_documents=True,  # Include source documents in response
)


response = retrieval_qa({"query": QUERY})

print("응답:", response["result"])
# Out:
# <class 'list'> 1536

# %%
documents = retriever.get_relevant_documents("리본 두개 이상인 서울 한식집을 알려주세요.")
print(f"Retrieved {len(documents)} documents")
for doc in documents:
    print(doc.page_content)
# Out:
# Retrieved 5 documents
# id: 6364
# createdDate: 1304147828000
# bookStatus: APPROVAL
# chefName: 박승재
# closeHours: nan
# closeHoursWeekend: nan
# dayOff: 일, 월, 화요일 휴무
# openHours: nan
# openHoursWeekend: nan
# phone: 010-5538-3973
# website: nan
# gps_latitude: 37.552014
# gps_longitude: 126.927861
# ribbonType: nan
# juso_detailAddress: nan
# juso_roadAddrPart1: 서울특별시 마포구 와우산로30길 80
# review_text: 한식 주점의 정석과도 같은 곳. 손맛 좋은 오너 겸 셰프가 내는 한식을 안주로 삼아 저녁때 술 한잔 즐기기 좋다. 소갈비찜과 스팸골뱅이는 빼놓지 말고 주문해야 하는 메뉴. 그날의 신선한 재료로 만드는 요리도 매번 기대하게 하는 메뉴다.
# review_simple: 한식 주점의 정석과도 같은 곳. 손맛 좋은 오너 겸 셰프가 내는 한식을 안주로 삼아 저녁때 술 한잔 즐기기 좋다. 소갈비찜과 스팸골뱅이는 빼놓지 말고 주문해야 하는 메뉴. 그날의 신선한 재료로 만드는 요리도 매번 기대하게 하는 메뉴다.
# statusInfo_businessHours: 18:00~23:00(마지막 주문 22:00)
# statusInfo_creditCard: y
# statusInfo_menu: 미로소갈비찜(3만2천원), 닭튀김(2만원), 양념돼지목살구이(2만5천원), 골뱅이무침과스팸구이(2만2천원), 해물부추전, 애호박감자채전(각 1만8천원)
# foodType_1: 한식(일반한식)
# foodDetailType_1: 모던한식
# foodType_2: 모던한식
# foodDetailType_2: 한식주점
# foodType_3: 한식주점
# foodDetailType_3: nan
# foodType_4: nan
# foodDetailType_4: nan
# foodType_5: nan
# foodDetailType_5: nan
# foodType_6: nan
# foodDetailType_6: nan
# foodType_7: nan
# foodDetailType_7: nan
# foodType_8: nan
# foodDetailType_8: nan
# foodType_9: nan
# foodDetailType_9: nan
# foodType_10: nan
# foodDetailType_10: nan
# restaurant_id: 6364.0
# feature: 연인과 같이 가면 좋은
# id: 21510
# createdDate: 1369666800000
# bookStatus: APPROVAL
# chefName: nan
# closeHours: nan
# closeHoursWeekend: nan
# dayOff: 명절 당일 휴무
# openHours: nan
# openHoursWeekend: nan
# phone: 02-792-2022
# website: https://www.parcseoul.com/
# gps_latitude: 37.53746
# gps_longitude: 126.9997
# ribbonType: nan
# juso_detailAddress: 2층
# juso_roadAddrPart1: 서울특별시 용산구 이태원로55가길 26-5
# review_text: 모던한 분위기의 한정식집. 수수한 간판에 카페처럼 깔끔하게 꾸민 외관이 인상적이다. 메뉴는 주기적으로 바뀌며, 다양한 메뉴 중 하나를 선택하면 그날의 국과 반찬 3가지가 함께 정갈하게 차려져서 나온다. 밥과 반찬은 원하는 만큼 추가해 먹을 수 있다.
# review_simple: 모던한 분위기의 한정식집. 수수한 간판에 카페처럼 깔끔하게 꾸민 외관이 인상적이다. 메뉴는 주기적으로 바뀌며, 다양한 메뉴 중 하나를 선택하면 그날의 국과 반찬 3가지가 함께 정갈하게 차려져서 나온다. 밥과 반찬은 원하는 만큼 추가해 먹을 수 있다.
# statusInfo_businessHours: 11:30~15:20/17:30~21:00(마지막 주문 20:15)
# statusInfo_creditCard: y
# statusInfo_menu: 세트(2인 이상, 1인 3만4천원), 도토리묵말랭이들깨버무리(1만7천원), 조선호박과바지락새우찜(2만3천원), 매콤소꼬리찜(3만원), 미국산블랙앵거스LA갈비구이(3만8천5백원), 수란&베이컨을올린묵은지볶음밥(1만6천원)
# foodType_1: 한식(일반한식)
# foodDetailType_1: 한정식
# foodType_2: 한정식
# foodDetailType_2: nan
# foodType_3: nan
# foodDetailType_3: nan
# foodType_4: nan
# foodDetailType_4: nan
# foodType_5: nan
# foodDetailType_5: nan
# foodType_6: nan
# foodDetailType_6: nan
# foodType_7: nan
# foodDetailType_7: nan
# foodType_8: nan
# foodDetailType_8: nan
# foodType_9: nan
# foodDetailType_9: nan
# foodType_10: nan
# foodDetailType_10: nan
# restaurant_id: 21510.0
# feature: 연인과 같이 가면 좋은
# id: 29464
# createdDate: 1537054437000
# bookStatus: APPROVAL
# chefName: 조은희, 박성배
# closeHours: nan
# closeHoursWeekend: nan
# dayOff: 토, 일, 월요일, 공휴일 휴무
# openHours: nan
# openHoursWeekend: nan
# phone: 02-6952-0024
# website: nan
# gps_latitude: 37.5804948296674
# gps_longitude: 126.9733908253081
# ribbonType: nan
# juso_detailAddress: 4층
# juso_roadAddrPart1: 서울특별시 종로구 효자로 49
# review_text: 서울을 대표하는 한식 레스토랑 중의 하나로, 정통 한식에 기반한 모던 한식을 파인 다이닝으로 즐길 수 있다. 조은희 주방장과 박성배 수석 연구원이 전국 각지에서 나는 제철 식재료를 연구해 한 가지 코스로 정갈하게 풀어낸다.
# review_simple: 서울을 대표하는 한식 레스토랑 중의 하나로, 정통 한식에 기반한 모던 한식을 파인 다이닝으로 즐길 수 있다. 조은희 주방장과 박성배 수석 연구원이 전국 각지에서 나는 제철 식재료를 연구해 한 가지 코스로 정갈하게 풀어낸다.
# statusInfo_businessHours: 12:00~15:00/18:00~22:00(마지막 주문 20:00)
# statusInfo_creditCard: y
# statusInfo_menu: 점심코스(17만원), 저녁코스(25만원)
# foodType_1: 한식(일반한식)
# foodDetailType_1: 모던한식
# foodType_2: 모던한식
# foodDetailType_2: nan
# foodType_3: nan
# foodDetailType_3: nan
# foodType_4: nan
# foodDetailType_4: nan
# foodType_5: nan
# foodDetailType_5: nan
# foodType_6: nan
# foodDetailType_6: nan
# foodType_7: nan
# foodDetailType_7: nan
# foodType_8: nan
# foodDetailType_8: nan
# foodType_9: nan
# foodDetailType_9: nan
# foodType_10: nan
# foodDetailType_10: nan
# restaurant_id: 29464.0
# feature: 전통주 리스트가 좋은
# id: 37768
# createdDate: 1708965977000
# bookStatus: INACTIVE
# chefName: 송정재 or 신현석or윤도식
# closeHours: nan
# closeHoursWeekend: nan
# dayOff: 연중무휴
# openHours: nan
# openHoursWeekend: nan
# phone: 010-4055-2074
# website: nan
# gps_latitude: 37.5624620903158
# gps_longitude: 127.064533081493
# ribbonType: nan
# juso_detailAddress: 형인타워
# juso_roadAddrPart1: 서울특별시 동대문구 한천로2길 107
# review_text: 한식, 양식, 일식을 즐길 수 있는 술집. 한식으로는 곱도리탕, 꼬막, 일식으로는 세이로무시, 스키야키, 그리고 양식으로는 파스타 등 다양한 시그니처 메뉴를 갖추고 있다. 주류는 하이볼을 많이 찾으며 단체 이용도 가능해서 다양한 연령대가 모임하기에도 좋으며, 가족 모임으로도 많이 찾는다.
# review_simple: nan
# statusInfo_businessHours: 11:30~01:00(익일)
# statusInfo_creditCard: nan
# statusInfo_menu: 한우육회비빔밥, 꼬막비빔밥(점심, 각 1만2천원), 꼬막무침(2만5천원), 혼마구로사시미(5만5천원),숙성모듬사시미(4만5천원),후토마끼(2만5천원), 스키야키(3만원), 세이로무시(3만5천원), 곱도리탕(4만원)
# foodType_1: 한식주점
# foodDetailType_1: 무국적술집
# foodType_2: 무국적술집
# foodDetailType_2: nan
# foodType_3: nan
# foodDetailType_3: nan
# foodType_4: nan
# foodDetailType_4: nan
# foodType_5: nan
# foodDetailType_5: nan
# foodType_6: nan
# foodDetailType_6: nan
# foodType_7: nan
# foodDetailType_7: nan
# foodType_8: nan
# foodDetailType_8: nan
# foodType_9: nan
# foodDetailType_9: nan
# foodType_10: nan
# foodDetailType_10: nan
# restaurant_id: 37768.0
# feature: 술 한잔하기 좋은
# id: 16248
# createdDate: 1355842800000
# bookStatus: APPROVAL
# chefName: nan
# closeHours: nan
# closeHoursWeekend: nan
# dayOff: 연중무휴
# openHours: nan
# openHoursWeekend: nan
# phone: 02-733-3276
# website: http://www.seoulgaon.co.kr/
# gps_latitude: 37.57262064091815
# gps_longitude: 126.97572100551191
# ribbonType: nan
# juso_detailAddress: 세종문화회관 지하 1층
# juso_roadAddrPart1: 서울특별시 종로구 세종대로 175
# review_text: 서울의 중심부란 뜻을 가진 식당 이름만큼이나 한정식의 수준도 훌륭하다. 깔끔한 맛의 한정식 코스를 조용한 분위기에서 맛보기 좋은 곳이다. 돌잔치나 상견례 장소로도 유명하다.
# review_simple: 서울의 중심부란 뜻을 가진 식당 이름만큼이나 한정식의 수준도 훌륭하다. 깔끔한 맛의 한정식 코스를 조용한 분위기에서 맛보기 좋은 곳이다. 돌잔치나 상견례 장소로도 유명하다.
# statusInfo_businessHours: 11:30~15:00/17:00~21:30(마지막 주문 20:30)
# statusInfo_creditCard: y
# statusInfo_menu: 한정식코스(4만5천원, 5만5천원, 6만5천원, 7만5천원, 9만5천원), 채식코스(6만8천원)
# foodType_1: 한식(일반한식)
# foodDetailType_1: 한정식
# foodType_2: 한정식
# foodDetailType_2: nan
# foodType_3: nan
# foodDetailType_3: nan
# foodType_4: nan
# foodDetailType_4: nan
# foodType_5: nan
# foodDetailType_5: nan
# foodType_6: nan
# foodDetailType_6: nan
# foodType_7: nan
# foodDetailType_7: nan
# foodType_8: nan
# foodDetailType_8: nan
# foodType_9: nan
# foodDetailType_9: nan
# foodType_10: nan
# foodDetailType_10: nan
# restaurant_id: 16248.0
# feature: 가족과 외식하기 좋은

# %%
for doc in docs:
    print("Context:", doc.page_content)
    print("Question:", question)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[17], line 1
# ----> 1 for doc in docs:
#       2     print("Context:", doc.page_content)
#       3     print("Question:", question)
#
# NameError: name 'docs' is not defined

# %% [markdown]
# #### Map_reduce 확인

# %%
r = map_reduce_chain.invoke("리본 두개 이상인 서울 한식집을 알려주세요.")
print(r)
# Out:
# ''
#
# ''
#
# ''
#
# ''
#
# ''

# %% [markdown]
# #### 최종 답변

# %%
final_prompt = ChatPromptTemplate.from_messages(
    [
        (
            "system",
            """
            Given the following extracted parts of a long document and a question, create a final answer. 
            If you don't know the answer, just say that you don't know. Don't try to make up an answer.
            ------
            {context}
            """,
        ),
        ("human", "{question}"),
    ]
)

chain = ({"context":map_reduce_chain, "question":RunnablePassthrough()} 
        | final_prompt
        | model
        | StrOutputParser())

# %%
#

# %% [markdown]
# ## 기록

# %% [markdown]
# ```python
# # # Retriever 생성 - 성능이 안좋음: 부정확한 답변
# # retriever = vector_store.as_retriever(
# #     search_type="similarity",
# #     search_kwargs={"k": 5},
# # )
#
# ```

# %% [markdown]
# ## 데이터 검토를 위한 코드들

# %%
# Retriever를 통해 관련 문서 가져오기
documents = retriever.get_relevant_documents(QUERY)

# 관련 문서 출력
for idx, doc in enumerate(documents):
    print(f"문서 {idx + 1}:")
    print("Metadata:", doc.metadata)
    print("Content:", doc.page_content)
    print("------")
# Out:
# 문서 1:
# Metadata: {}
# Content: id: 4091
# createdDate: 1216620773000
# bookStatus: INACTIVE
# chefName: nan
# closeHours: nan
# closeHoursWeekend: nan
# dayOff: 명절 휴무
# openHours: nan
# openHoursWeekend: nan
# phone: 02-307-9979
# website: nan
# gps_latitude: 37.57189
# gps_longitude: 126.934353
# ribbonType: nan
# juso_detailAddress: nan
# juso_roadAddrPart1: 서울특별시 서대문구 연희로25길 31-3
# review_text: 가정집을 개조한 아늑한 분위기의 한정식집. 떡갈비와 간장게장이 인기 메뉴며 반찬도 정갈하다. 가정집에 초대받아 음식을 대접받는 기분으로 식사를 즐길 수 있다. 가격 대비 만족도도 높은 편이다.
# review_simple: 가정집을 개조한 아늑한 분위기의 한정식집. 떡갈비와 간장게장이 인기 메뉴며 반찬도 정갈하다. 가정집에 초대받아 음식을 대접받는 기분으로 식사를 즐길 수 있다. 가격 대비 만족도도 높은 편이다.
# statusInfo_businessHours: 11:30~15:00/17:00~21:00
# statusInfo_creditCard: y
# statusInfo_menu: 떡갈비정식(2만1천원), 간장게장정식(3만8천원), 보리굴비정식(2만6천원), 수빈정식세트(4인 7만8천원~10만9천원)
# foodType_1: 한식(일반한식)
# foodDetailType_1: 한정식
# foodType_2: 한정식
# foodDetailType_2: 게장
# foodType_3: 한식(어패류)
# foodDetailType_3: nan
# foodType_4: 게장
# foodDetailType_4: nan
# foodType_5: nan
# foodDetailType_5: nan
# foodType_6: nan
# foodDetailType_6: nan
# foodType_7: nan
# foodDetailType_7: nan
# foodType_8: nan
# foodDetailType_8: nan
# foodType_9: nan
# foodDetailType_9: nan
# foodType_10: nan
# foodDetailType_10: nan
# restaurant_id: 4091.0
# feature: 연인과 같이 가면 좋은
# ------
# 문서 2:
# Metadata: {}
# Content: id: 511
# createdDate: 1143903600000
# bookStatus: APPROVAL
# chefName: nan
# closeHours: nan
# closeHoursWeekend: nan
# dayOff: 명절 당일 휴무
# openHours: nan
# openHoursWeekend: nan
# phone: 02-579-7282
# website: http://www.sohojung.com/
# gps_latitude: 37.473216
# gps_longitude: 127.048669
# ribbonType: nan
# juso_detailAddress: nan
# juso_roadAddrPart1: 서울특별시 서초구 논현로 27
# review_text: 경상도 안동 지방의 반가 음식인 안동 국시의 맛을 느껴볼 수 있는 곳이다. 국시 외에도 다양한 한식 메뉴가 있다. 고기와 묵, 전, 국수까지 조금씩 모두 맛볼 수 있는 특선 정식이 실속 있다.
# review_simple: 경상도 안동 지방의 반가 음식인 안동 국시의 맛을 느껴볼 수 있는 곳이다. 국시 외에도 다양한 한식 메뉴가 있다. 고기와 묵, 전, 국수까지 조금씩 모두 맛볼 수 있는 특선 정식이 실속 있다.
# statusInfo_businessHours: 11:00~21:00
# statusInfo_creditCard: y
# statusInfo_menu: 안동국시, 국밥(각 1만5천원), 수육(소 4만3천원, 대 5만8천원), 전(소 3만4천원, 대 3만9천원), 참문어(소 4만2천원, 대 5만1천원), 메밀묵(소 2만5천원, 대 2만9천원), 정식(2만9천원, 3만3천원, 4만2천원)
# foodType_1: 한식(면류)
# foodDetailType_1: 칼국수
# foodType_2: 칼국수
# foodDetailType_2: 수육
# foodType_3: 한식(육류)
# foodDetailType_3: nan
# foodType_4: 수육
# foodDetailType_4: nan
# foodType_5: nan
# foodDetailType_5: nan
# foodType_6: nan
# foodDetailType_6: nan
# foodType_7: nan
# foodDetailType_7: nan
# foodType_8: nan
# foodDetailType_8: nan
# foodType_9: nan
# foodDetailType_9: nan
# foodType_10: nan
# foodDetailType_10: nan
# restaurant_id: 511.0
# feature: 연인과 같이 가면 좋은
# ------
# 문서 3:
# Metadata: {}
# Content: id: 6814
# createdDate: 1327821145000
# bookStatus: APPROVAL
# chefName: nan
# closeHours: nan
# closeHoursWeekend: nan
# dayOff: 수요일, 1월1일, 명절 휴무
# openHours: nan
# openHoursWeekend: nan
# phone: 070-4407-5130
# website: nan
# gps_latitude: 37.565147
# gps_longitude: 126.924014
# ribbonType: nan
# juso_detailAddress: nan
# juso_roadAddrPart1: 서울특별시 마포구 성미산로 161-8
# review_text: 연남동에서 태국 음식의 신화를 쓴 곳. 현지에 가까운 맛을 내며 가격대도 합리적인 편이어서 큰 인기를 끌고 있다. 자극성이 강한 태국 요리와 맥주 등의 술을 즐기기에 좋은 태국식 주점으로도 이용된다.
# review_simple: 연남동에서 태국 음식의 신화를 쓴 곳. 현지에 가까운 맛을 내며 가격대도 합리적인 편이어서 큰 인기를 끌고 있다. 자극성이 강한 태국 요리와 맥주 등의 술을 즐기기에 좋은 태국식 주점으로도 이용된다.
# statusInfo_businessHours: 11:00~15:20/17:00~21:00 (마지막 주문 20:20) | 토요일, 일요일 11:30~16:00/17:00~21:00 (마지막 주문 20:20)
# statusInfo_creditCard: y
# statusInfo_menu: 연남갈비국수(1만3천5백원), 팟타이꿍, 팟크라파오무쌉덮밥(각 1만4천원), 똠얌꿍(1만8천원), 그린커리(1만7천원), 솜땀, 얌운센(각 1만3천원), 뿌님팟퐁커리(3만1천원)
# foodType_1: 아시아식
# foodDetailType_1: 태국식
# foodType_2: 태국식
# foodDetailType_2: nan
# foodType_3: nan
# foodDetailType_3: nan
# foodType_4: nan
# foodDetailType_4: nan
# foodType_5: nan
# foodDetailType_5: nan
# foodType_6: nan
# foodDetailType_6: nan
# foodType_7: nan
# foodDetailType_7: nan
# foodType_8: nan
# foodDetailType_8: nan
# foodType_9: nan
# foodDetailType_9: nan
# foodType_10: nan
# foodDetailType_10: nan
# restaurant_id: 6814.0
# feature: 가족과 외식하기 좋은
# ------
# 문서 4:
# Metadata: {}
# Content: id: 46
# createdDate: 1143903600000
# bookStatus: APPROVAL
# chefName: nan
# closeHours: nan
# closeHoursWeekend: nan
# dayOff: 연중무휴
# openHours: nan
# openHoursWeekend: nan
# phone: 02-555-9567
# website: https://thegomegome.modoo.at/
# gps_latitude: 37.504361
# gps_longitude: 127.054333
# ribbonType: nan
# juso_detailAddress: nan
# juso_roadAddrPart1: 서울특별시 강남구 삼성로85길 38
# review_text: 참숯을 넣은 항아리에 숙성한 고기를 구워 먹는 곳. 생삼겹, 오리, 꽃등심 등을 즐길 수 있으며 주메뉴는 물론 반찬에도 한약재를 넣어 한의학의 기본 이론인 음양오행의 원리를 음식 속에 담았다. 모던한 인테리어가 돋보인다.
# review_simple: 참숯을 넣은 항아리에 숙성한 고기를 구워 먹는 곳. 생삼겹, 오리, 꽃등심 등을 즐길 수 있으며 주메뉴는 물론 반찬에도 한약재를 넣어 한의학의 기본 이론인 음양오행의 원리를 음식 속에 담았다. 모던한 인테리어가 돋보인다.
# statusInfo_businessHours: 11:30~23:00
# statusInfo_creditCard: y
# statusInfo_menu: 삼겹한항아리(600g 4만2천원), 통항정살(300g 2만7천원), 돼지갈비(200g 1만6천원), 갈비한항아리(700g 4만8천원), 냉면(1만원)
# foodType_1: 한식(육류)
# foodDetailType_1: 소고기구이
# foodType_2: 소고기구이
# foodDetailType_2: 삼겹살
# foodType_3: 삼겹살
# foodDetailType_3: nan
# foodType_4: nan
# foodDetailType_4: nan
# foodType_5: nan
# foodDetailType_5: nan
# foodType_6: nan
# foodDetailType_6: nan
# foodType_7: nan
# foodDetailType_7: nan
# foodType_8: nan
# foodDetailType_8: nan
# foodType_9: nan
# foodDetailType_9: nan
# foodType_10: nan
# foodDetailType_10: nan
# restaurant_id: 46.0
# feature: 가족과 외식하기 좋은
# ------
# 문서 5:
# Metadata: {}
# Content: id: 7332
# createdDate: 1339340400000
# bookStatus: APPROVAL
# chefName: nan
# closeHours: nan
# closeHoursWeekend: nan
# dayOff: 토, 일요일 휴무
# openHours: nan
# openHoursWeekend: nan
# phone: 02-2005-1003
# website: nan
# gps_latitude: 37.501898
# gps_longitude: 127.037291
# ribbonType: nan
# juso_detailAddress: GS강남타워 B1층
# juso_roadAddrPart1: 서울특별시 강남구 논현로 508
# review_text: 1930년대 상하이의 고급 레스토랑 분위기를 콘셉트로 하는 곳. 광동식과 매콤한 사천식 요리를 주로 선보인다. 고급스러운 분위기에서 친절한 서비스를 받으며 중식을 즐길 수 있다.
# review_simple: 1930년대 상하이의 고급 레스토랑 분위기를 콘셉트로 하는 곳. 광동식과 매콤한 사천식 요리를 주로 선보인다. 고급스러운 분위기에서 친절한 서비스를 받으며 중식을 즐길 수 있다.
# statusInfo_businessHours: 11:30~14:30/17:30~21:30
# statusInfo_creditCard: y
# statusInfo_menu: 비즈니스코스(5만5천원), 점심코스(8만5천원, 9만5천원), 디너코스(11만원, 13만5천원), 삼선자장면(1만3천원), 삼선짬뽕(1만5천원), XO게살볶음밥(1만9천원), 어향가지덮밥(1만7천원), 탕수육(3만7천원)
# foodType_1: 중식
# foodDetailType_1: 일반중식
# foodType_2: 일반중식
# foodDetailType_2: nan
# foodType_3: nan
# foodDetailType_3: nan
# foodType_4: nan
# foodDetailType_4: nan
# foodType_5: nan
# foodDetailType_5: nan
# foodType_6: nan
# foodDetailType_6: nan
# foodType_7: nan
# foodDetailType_7: nan
# foodType_8: nan
# foodDetailType_8: nan
# foodType_9: nan
# foodDetailType_9: nan
# foodType_10: nan
# foodDetailType_10: nan
# restaurant_id: 7332.0
# feature: 가족과 외식하기 좋은
# ------
